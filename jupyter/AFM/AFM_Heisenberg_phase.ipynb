# %%
import numpy as np
import sys
import itertools as itertools
import time
sys.path.append("..")
sys.path.append("../..")

import matplotlib.pyplot as plt
from python.Heisenberg import *
from python.DMRG import DMRG
from python.Zippers import MPO_to_Hamiltonian, contract_MPS
from python.Canonical_Form import get_Neumann_entropy
from python.Backend import Backend

# %%
n_sites = 50
XY_coupling = 1.0

# %%
device = "numpy"
# device = "torch"

bk = Backend(device)

NKeep = 50
NSweep = 20
Krylov_bases = 5 #* 5 is usually enough
Lanczos_cutoff = 1e-2
iterative_diag = True
two_site = True
verbose = True

# %%
import numpy.typing as npt
import pickle
from dataclasses import dataclass, field, asdict, replace
from copy import deepcopy
from typing import Any, Optional
from pathlib import Path


@dataclass
class Params:
    L: int
    XY: float
    ZZ: float
    h: float
    NKeep: int
    NSweep: int
    diag: bool
    Krylov: int
    cutoff: float
    two: bool
    
    def to_log(self) -> str:
        log_dict = asdict(self)
        
        log_dict['XY'] = round(self.XY, 2)
        log_dict['ZZ'] = round(self.ZZ, 2)
        log_dict['h'] = round(self.h, 2)
        log_dict['cutoff'] = round(self.cutoff, 3)
        
        # Filter out keys where the value is None
        filtered_log_dict = {key: log for key, log in log_dict.items() if log is not None}
        
        # Create log string
        return "_".join(
            f"{key}={log}" for key, log in filtered_log_dict.items()
        )

@dataclass
class Results:
    ground_MPS: list[npt.NDArray]
    ground_state_energy: float
    Neumann_entropy: float
    ground_energies: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    spin_z: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    spin_correlations: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    
    
    def to_array(self):
        return replace(
            self, **{field: np.array(getattr(self, field))
            if isinstance(getattr(self, field), list) else getattr(self, field)
            for field in asdict(self)}
        )
        
    def self_destruct(self):
        for field_name in self.__dataclass_fields__:
            field_value = getattr(self, field_name)
            if isinstance(field_value, list):
                field_value.clear()  # Clear list contents
            else:
                setattr(self, field_name, None)  # Set to None if not a list

# %%
ZZ_coupling_start = -5
ZZ_coupling_end = 5
delta_ZZ = 0.1

ZZ_couplings = bk.arange(ZZ_coupling_start, ZZ_coupling_end+delta_ZZ, delta_ZZ)

magnetic_field_start = -10
magnetic_field_end = -5
delta_h = 0.1

magnetic_fields = bk.arange(magnetic_field_start, magnetic_field_end+delta_h, delta_h)

# %%
for it1, ZZ_coupling in enumerate(ZZ_couplings):
    for it2, magnetic_field in enumerate(magnetic_fields):
        
        if verbose:
            print(f"ZZ={round(ZZ_coupling,2)} | h={round(magnetic_field,2)}")
        
        Hamiltonian = XXZ_model(
            bk=bk, n_sites=n_sites, ZZ_coupling=ZZ_coupling,
            XY_coupling=XY_coupling, magnetic_field=magnetic_field,
        )
        
        ground_energies, ground_times, ground_MPS = DMRG(
            bk = bk,
            Hamiltonian = Hamiltonian,
            NKeep = NKeep,
            NSweep = NSweep,
            Krylov_bases = Krylov_bases,
            Lanczos_cutoff = Lanczos_cutoff,
            iterative_diag = True,
            two_site = two_site,
            verbose = verbose,
            tol = 1e-8,
        )
        
        param = Params(
            L = n_sites,
            XY = XY_coupling,
            ZZ = ZZ_coupling,
            h = magnetic_field,
            NKeep = NKeep,
            NSweep = NSweep,
            diag = iterative_diag,
            Krylov = Krylov_bases,
            cutoff = Lanczos_cutoff,
            two = two_site
        )
        
        # dir_name = Path(f"data")
        dir_name = Path(f"{device}/data")
        dir_name.mkdir(parents=True, exist_ok=True)
        
        filename = f"{param.to_log()}"
        ground_state_energy = ground_energies[-1]
        Neumann_entropy = get_Neumann_entropy(ground_MPS, bk=bk)
        spin_z = get_spin_z(ground_MPS, bk)
        
        if verbose:
            print(f"computing spin correlations: ", end="")
            now = time.perf_counter()
        spin_correlations = get_spin_correlations(ground_MPS, bk)
        if verbose:
            print(f"{round(time.perf_counter()-now,3)}s")
        
        result = Results(
            ground_MPS = [],
            ground_state_energy = ground_state_energy,
            ground_energies = ground_energies,
            Neumann_entropy = Neumann_entropy,
            spin_z = spin_z,
            spin_correlations = spin_correlations,
        )
        
        output: dict[str, Any] = {}
        output.update(asdict(param))
        output.update(asdict(result))
        
        with open(dir_name / f"{filename}.pkl", "wb") as file:
            pickle.dump(output, file)
# Out:
# ZZ=-5.0 | h=-10.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-311.25 | time=0js
# iter=1 | energy=(-311.24999999999875+0j) | time=0.17854542203713208s
# computing spin correlations: 2.149s
# ZZ=-5.0 | h=-9.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-308.75 | time=0js
# iter=1 | energy=(-308.74999999999864+0j) | time=0.20096199202816933s
# computing spin correlations: 2.147s
# ZZ=-5.0 | h=-9.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-306.25 | time=0js
# iter=1 | energy=(-306.2499999999986+0j) | time=0.16575199295766652s
# computing spin correlations: 2.195s
# ZZ=-5.0 | h=-9.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-303.75 | time=0js
# iter=1 | energy=(-303.74999999999875+0j) | time=0.17516369302757084s
# computing spin correlations: 2.149s
# ZZ=-5.0 | h=-9.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-301.25 | time=0js
# iter=1 | energy=(-301.24999999999915+0j) | time=0.17613596899900585s
# computing spin correlations: 2.182s
# ZZ=-5.0 | h=-9.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-298.75 | time=0js
# iter=1 | energy=(-298.7499999999996+0j) | time=0.12130189599702135s
# computing spin correlations: 2.151s
# ZZ=-5.0 | h=-9.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-296.25 | time=0js
# iter=1 | energy=(-296.24999999999915+0j) | time=0.13120886002434418s
# computing spin correlations: 2.21s
# ZZ=-5.0 | h=-9.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-293.75 | time=0js
# iter=1 | energy=(-293.7499999999986+0j) | time=0.15025876800063998s
# computing spin correlations: 2.203s
# ZZ=-5.0 | h=-9.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-291.25 | time=0js
# iter=1 | energy=(-291.249999999999+0j) | time=0.15463140403153375s
# computing spin correlations: 2.214s
# ZZ=-5.0 | h=-9.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-288.75 | time=0js
# iter=1 | energy=(-288.7499999999986+0j) | time=0.1324337249970995s
# computing spin correlations: 2.189s
# ZZ=-5.0 | h=-9.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-286.25 | time=0js
# iter=1 | energy=(-286.2499999999994+0j) | time=0.11588692100485787s
# computing spin correlations: 2.168s
# ZZ=-5.0 | h=-8.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-283.75 | time=0js
# iter=1 | energy=(-283.7499999999989+0j) | time=0.12022040598094463s
# computing spin correlations: 2.141s
# ZZ=-5.0 | h=-8.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-281.25 | time=0js
# iter=1 | energy=(-281.24999999999926+0j) | time=0.12109240697463974s
# computing spin correlations: 2.158s
# ZZ=-5.0 | h=-8.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-278.75 | time=0js
# iter=1 | energy=(-278.7499999999993+0j) | time=0.13385330804158002s
# computing spin correlations: 2.127s
# ZZ=-5.0 | h=-8.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-276.25 | time=0js
# iter=1 | energy=(-276.2499999999995+0j) | time=0.14782100898446515s
# computing spin correlations: 2.186s
# ZZ=-5.0 | h=-8.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-273.75 | time=0js
# iter=1 | energy=(-273.74999999999994+0j) | time=0.15391520998673514s
# computing spin correlations: 2.209s
# ZZ=-5.0 | h=-8.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-271.25 | time=0js
# iter=1 | energy=(-271.2499999999991+0j) | time=0.20548887504264712s
# computing spin correlations: 2.189s
# ZZ=-5.0 | h=-8.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-268.75 | time=0js
# iter=1 | energy=(-268.7499999999993+0j) | time=0.13534458400681615s
# computing spin correlations: 2.169s
# ZZ=-5.0 | h=-8.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-266.25 | time=0js
# iter=1 | energy=(-266.2499999999991+0j) | time=0.1736002949764952s
# computing spin correlations: 2.183s
# ZZ=-5.0 | h=-8.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-263.75 | time=0js
# iter=1 | energy=(-263.7499999999997+0j) | time=0.19346949900500476s
# computing spin correlations: 2.246s
# ZZ=-5.0 | h=-8.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-261.25 | time=0js
# iter=1 | energy=(-261.2499999999992+0j) | time=0.16981959104305133s
# computing spin correlations: 2.207s
# ZZ=-5.0 | h=-7.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-258.75 | time=0js
# iter=1 | energy=(-258.749999999999+0j) | time=0.13328399299643934s
# computing spin correlations: 2.209s
# ZZ=-5.0 | h=-7.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-256.25 | time=0js
# iter=1 | energy=(-256.24999999999926+0j) | time=0.12834099296014756s
# computing spin correlations: 2.157s
# ZZ=-5.0 | h=-7.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-253.75 | time=0js
# iter=1 | energy=(-253.74999999999946+0j) | time=0.13126440497580916s
# computing spin correlations: 2.149s
# ZZ=-5.0 | h=-7.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-251.25 | time=0js
# iter=1 | energy=(-251.2499999999992+0j) | time=0.16441000701161101s
# computing spin correlations: 2.141s
# ZZ=-5.0 | h=-7.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-248.75 | time=0js
# iter=1 | energy=(-248.74999999999974+0j) | time=0.12267282197717577s
# computing spin correlations: 2.131s
# ZZ=-5.0 | h=-7.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-246.25 | time=0js
# iter=1 | energy=(-246.24999999999935+0j) | time=0.11819452198687941s
# computing spin correlations: 2.153s
# ZZ=-5.0 | h=-7.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-243.75 | time=0js
# iter=1 | energy=(-243.74999999999966+0j) | time=0.12122210202505812s
# computing spin correlations: 2.183s
# ZZ=-5.0 | h=-7.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-241.25 | time=0js
# iter=1 | energy=(-241.24999999999952+0j) | time=0.11683419503970072s
# computing spin correlations: 2.155s
# ZZ=-5.0 | h=-7.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-238.75 | time=0js
# iter=1 | energy=(-238.74999999999895+0j) | time=0.11788789503043517s
# computing spin correlations: 2.102s
# ZZ=-5.0 | h=-7.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-236.25 | time=0js
# iter=1 | energy=(-236.24999999999918+0j) | time=0.1154177879798226s
# computing spin correlations: 2.121s
# ZZ=-5.0 | h=-6.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-233.75 | time=0js
# iter=1 | energy=(-233.74999999999915+0j) | time=0.14003638399299234s
# computing spin correlations: 2.088s
# ZZ=-5.0 | h=-6.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-231.25 | time=0js
# iter=1 | energy=(-231.24999999999878+0j) | time=0.117349486972671s
# computing spin correlations: 2.161s
# ZZ=-5.0 | h=-6.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-228.75 | time=0js
# iter=1 | energy=(-228.7499999999993+0j) | time=0.12794520996976644s
# computing spin correlations: 2.111s
# ZZ=-5.0 | h=-6.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-226.25 | time=0js
# iter=1 | energy=(-226.24999999999883+0j) | time=0.11889480898389593s
# computing spin correlations: 2.106s
# ZZ=-5.0 | h=-6.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-223.75 | time=0js
# iter=1 | energy=(-223.74999999999866+0j) | time=0.16111311299027875s
# computing spin correlations: 2.101s
# ZZ=-5.0 | h=-6.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-221.25 | time=0js
# iter=1 | energy=(-221.24999999999915+0j) | time=0.11756680399412289s
# computing spin correlations: 2.135s
# ZZ=-5.0 | h=-6.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-218.75 | time=0js
# iter=1 | energy=(-218.74999999999946+0j) | time=0.18613060598727316s
# computing spin correlations: 2.133s
# ZZ=-5.0 | h=-6.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-216.25 | time=0js
# iter=1 | energy=(-216.24999999999918+0j) | time=0.1628085040138103s
# computing spin correlations: 2.108s
# ZZ=-5.0 | h=-6.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-213.75 | time=0js
# iter=1 | energy=(-213.74999999999923+0j) | time=0.15150709601584822s
# computing spin correlations: 2.117s
# ZZ=-5.0 | h=-6.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-211.25 | time=0js
# iter=1 | energy=(-211.24999999999966+0j) | time=0.15408139600185677s
# computing spin correlations: 2.129s
# ZZ=-5.0 | h=-5.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-208.75 | time=0js
# iter=1 | energy=(-208.74999999999955+0j) | time=0.1748596010147594s
# computing spin correlations: 2.111s
# ZZ=-5.0 | h=-5.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-206.25 | time=0js
# iter=1 | energy=(-206.2499999999993+0j) | time=0.12762480200035498s
# computing spin correlations: 2.125s
# ZZ=-5.0 | h=-5.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-203.75 | time=0js
# iter=1 | energy=(-203.74999999999952+0j) | time=0.1552078010281548s
# computing spin correlations: 2.108s
# ZZ=-5.0 | h=-5.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-201.25 | time=0js
# iter=1 | energy=(-201.24999999999923+0j) | time=0.11896860104752705s
# computing spin correlations: 2.151s
# ZZ=-5.0 | h=-5.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-198.75 | time=0js
# iter=1 | energy=(-198.74999999999955+0j) | time=0.16732200200203806s
# computing spin correlations: 2.103s
# ZZ=-5.0 | h=-5.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-196.25 | time=0js
# iter=1 | energy=(-196.2499999999993+0j) | time=0.15759970201179385s
# computing spin correlations: 2.153s
# ZZ=-5.0 | h=-5.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-193.75 | time=0js
# iter=1 | energy=(-193.74999999999926+0j) | time=0.15773160196840763s
# computing spin correlations: 2.139s
# ZZ=-5.0 | h=-5.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-191.25 | time=0js
# iter=1 | energy=(-191.24999999999937+0j) | time=0.19422600197140127s
# computing spin correlations: 2.105s
# ZZ=-5.0 | h=-5.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-188.75 | time=0js
# iter=1 | energy=(-188.7499999999992+0j) | time=0.15578809700673446s
# computing spin correlations: 2.131s
# ZZ=-5.0 | h=-5.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-186.25 | time=0js
# iter=1 | energy=(-186.24999999999963+0j) | time=0.15586159704253078s
# computing spin correlations: 2.113s
# ZZ=-4.9 | h=-10.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-310.025 | time=0js
# iter=1 | energy=(-310.0249999999996+0j) | time=0.15822019701590762s
# computing spin correlations: 2.128s
# ZZ=-4.9 | h=-9.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-307.525 | time=0js
# iter=1 | energy=(-307.5249999999991+0j) | time=0.14664658496621996s
# computing spin correlations: 2.118s
# ZZ=-4.9 | h=-9.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-305.025 | time=0js
# iter=1 | energy=(-305.02499999999935+0j) | time=0.16063348401803523s
# computing spin correlations: 2.135s
# ZZ=-4.9 | h=-9.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-302.525 | time=0js
# iter=1 | energy=(-302.52499999999935+0j) | time=0.15872638404835016s
# computing spin correlations: 2.136s
# ZZ=-4.9 | h=-9.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-300.025 | time=0js
# iter=1 | energy=(-300.0249999999991+0j) | time=0.16336537699680775s
# computing spin correlations: 2.152s
# ZZ=-4.9 | h=-9.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-297.525 | time=0js
# iter=1 | energy=(-297.524999999999+0j) | time=0.16471227700822055s
# computing spin correlations: 2.11s
# ZZ=-4.9 | h=-9.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-295.025 | time=0js
# iter=1 | energy=(-295.0249999999991+0j) | time=0.12779979698825628s
# computing spin correlations: 2.128s
# ZZ=-4.9 | h=-9.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-292.525 | time=0js
# iter=1 | energy=(-292.5249999999996+0j) | time=0.16320389602333307s
# computing spin correlations: 2.104s
# ZZ=-4.9 | h=-9.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-290.025 | time=0js
# iter=1 | energy=(-290.0249999999982+0j) | time=0.15236069599632174s
# computing spin correlations: 2.134s
# ZZ=-4.9 | h=-9.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-287.525 | time=0js
# iter=1 | energy=(-287.52499999999856+0j) | time=0.15251699998043478s
# computing spin correlations: 2.131s
# ZZ=-4.9 | h=-9.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-285.025 | time=0js
# iter=1 | energy=(-285.02499999999947+0j) | time=0.1161448999773711s
# computing spin correlations: 2.153s
# ZZ=-4.9 | h=-8.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-282.525 | time=0js
# iter=1 | energy=(-282.5249999999988+0j) | time=0.1536549010197632s
# computing spin correlations: 2.118s
# ZZ=-4.9 | h=-8.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-280.025 | time=0js
# iter=1 | energy=(-280.024999999999+0j) | time=0.15581840300001204s
# computing spin correlations: 2.137s
# ZZ=-4.9 | h=-8.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-277.525 | time=0js
# iter=1 | energy=(-277.5249999999982+0j) | time=0.16358960297657177s
# computing spin correlations: 2.15s
# ZZ=-4.9 | h=-8.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-275.025 | time=0js
# iter=1 | energy=(-275.02499999999935+0j) | time=0.16366890299832448s
# computing spin correlations: 2.105s
# ZZ=-4.9 | h=-8.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-272.525 | time=0js
# iter=1 | energy=(-272.5249999999992+0j) | time=0.17033230402739719s
# computing spin correlations: 2.101s
# ZZ=-4.9 | h=-8.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-270.025 | time=0js
# iter=1 | energy=(-270.02499999999895+0j) | time=0.16330070397816598s
# computing spin correlations: 2.095s
# ZZ=-4.9 | h=-8.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-267.525 | time=0js
# iter=1 | energy=(-267.5249999999993+0j) | time=0.12409579998347908s
# computing spin correlations: 2.133s
# ZZ=-4.9 | h=-8.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-265.025 | time=0js
# iter=1 | energy=(-265.02499999999895+0j) | time=0.15431180101586506s
# computing spin correlations: 2.132s
# ZZ=-4.9 | h=-8.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-262.525 | time=0js
# iter=1 | energy=(-262.5249999999994+0j) | time=0.15935730101773515s
# computing spin correlations: 2.126s
# ZZ=-4.9 | h=-8.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-260.025 | time=0js
# iter=1 | energy=(-260.0249999999994+0j) | time=0.1189764030277729s
# computing spin correlations: 2.119s
# ZZ=-4.9 | h=-7.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-257.525 | time=0js
# iter=1 | energy=(-257.5249999999991+0j) | time=0.12122500402620062s
# computing spin correlations: 2.115s
# ZZ=-4.9 | h=-7.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-255.025 | time=0js
# iter=1 | energy=(-255.02499999999898+0j) | time=0.1153609009925276s
# computing spin correlations: 2.136s
# ZZ=-4.9 | h=-7.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-252.525 | time=0js
# iter=1 | energy=(-252.52499999999898+0j) | time=0.11996370099950582s
# computing spin correlations: 2.131s
# ZZ=-4.9 | h=-7.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-250.025 | time=0js
# iter=1 | energy=(-250.02499999999964+0j) | time=0.11864840099588037s
# computing spin correlations: 2.116s
# ZZ=-4.9 | h=-7.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-247.525 | time=0js
# iter=1 | energy=(-247.52499999999924+0j) | time=0.11811949999537319s
# computing spin correlations: 2.167s
# ZZ=-4.9 | h=-7.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-245.025 | time=0js
# iter=1 | energy=(-245.02499999999878+0j) | time=0.12135600001784042s
# computing spin correlations: 2.145s
# ZZ=-4.9 | h=-7.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-242.525 | time=0js
# iter=1 | energy=(-242.52499999999955+0j) | time=0.1185525999753736s
# computing spin correlations: 2.125s
# ZZ=-4.9 | h=-7.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-240.025 | time=0js
# iter=1 | energy=(-240.0249999999993+0j) | time=0.1184757009614259s
# computing spin correlations: 2.139s
# ZZ=-4.9 | h=-7.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-237.525 | time=0js
# iter=1 | energy=(-237.52499999999927+0j) | time=0.12659390200860798s
# computing spin correlations: 2.148s
# ZZ=-4.9 | h=-7.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-235.025 | time=0js
# iter=1 | energy=(-235.0249999999994+0j) | time=0.11618530401028693s
# computing spin correlations: 2.146s
# ZZ=-4.9 | h=-6.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-232.525 | time=0js
# iter=1 | energy=(-232.52499999999927+0j) | time=0.11790110397851095s
# computing spin correlations: 2.128s
# ZZ=-4.9 | h=-6.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-230.025 | time=0js
# iter=1 | energy=(-230.02499999999924+0j) | time=0.11640170402824879s
# computing spin correlations: 2.154s
# ZZ=-4.9 | h=-6.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-227.525 | time=0js
# iter=1 | energy=(-227.524999999999+0j) | time=0.1152475019916892s
# computing spin correlations: 2.105s
# ZZ=-4.9 | h=-6.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-225.025 | time=0js
# iter=1 | energy=(-225.024999999999+0j) | time=0.12017790204845369s
# computing spin correlations: 2.102s
# ZZ=-4.9 | h=-6.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-222.525 | time=0js
# iter=1 | energy=(-222.52499999999932+0j) | time=0.1660297029884532s
# computing spin correlations: 2.141s
# ZZ=-4.9 | h=-6.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-220.025 | time=0js
# iter=1 | energy=(-220.02499999999876+0j) | time=0.11894900602055714s
# computing spin correlations: 2.139s
# ZZ=-4.9 | h=-6.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-217.525 | time=0js
# iter=1 | energy=(-217.52499999999986+0j) | time=0.12485150701832026s
# computing spin correlations: 2.13s
# ZZ=-4.9 | h=-6.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-215.025 | time=0js
# iter=1 | energy=(-215.0249999999991+0j) | time=0.12330360698979348s
# computing spin correlations: 2.119s
# ZZ=-4.9 | h=-6.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-212.525 | time=0js
# iter=1 | energy=(-212.52499999999918+0j) | time=0.13783472101204097s
# computing spin correlations: 2.126s
# ZZ=-4.9 | h=-6.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-210.025 | time=0js
# iter=1 | energy=(-210.02499999999873+0j) | time=0.12104801699751988s
# computing spin correlations: 2.131s
# ZZ=-4.9 | h=-5.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-207.525 | time=0js
# iter=1 | energy=(-207.52499999999912+0j) | time=0.11840162298176438s
# computing spin correlations: 2.113s
# ZZ=-4.9 | h=-5.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-205.025 | time=0js
# iter=1 | energy=(-205.02499999999858+0j) | time=0.15126112900907174s
# computing spin correlations: 2.124s
# ZZ=-4.9 | h=-5.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-202.525 | time=0js
# iter=1 | energy=(-202.5249999999994+0j) | time=0.12019150197738782s
# computing spin correlations: 2.135s
# ZZ=-4.9 | h=-5.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-200.025 | time=0js
# iter=1 | energy=(-200.02499999999898+0j) | time=0.11495589796686545s
# computing spin correlations: 2.147s
# ZZ=-4.9 | h=-5.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-197.525 | time=0js
# iter=1 | energy=(-197.52499999999927+0j) | time=0.11999729799572378s
# computing spin correlations: 2.141s
# ZZ=-4.9 | h=-5.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-195.025 | time=0js
# iter=1 | energy=(-195.02499999999912+0j) | time=0.17319729598239064s
# computing spin correlations: 2.13s
# ZZ=-4.9 | h=-5.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-192.525 | time=0js
# iter=1 | energy=(-192.52499999999927+0j) | time=0.11837108101462945s
# computing spin correlations: 2.155s
# ZZ=-4.9 | h=-5.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-190.025 | time=0js
# iter=1 | energy=(-190.02499999999935+0j) | time=0.129879278014414s
# computing spin correlations: 2.13s
# ZZ=-4.9 | h=-5.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-187.525 | time=0js
# iter=1 | energy=(-187.52499999999927+0j) | time=0.11784910899586976s
# computing spin correlations: 2.118s
# ZZ=-4.9 | h=-5.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-185.025 | time=0js
# iter=1 | energy=(-185.0249999999994+0j) | time=0.12036549602635205s
# computing spin correlations: 2.142s
# ZZ=-4.8 | h=-10.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-308.8 | time=0js
# iter=1 | energy=(-308.7999999999991+0j) | time=0.12190939497668296s
# computing spin correlations: 2.121s
# ZZ=-4.8 | h=-9.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-306.3 | time=0js
# iter=1 | energy=(-306.29999999999893+0j) | time=0.11451620399020612s
# computing spin correlations: 2.121s
# ZZ=-4.8 | h=-9.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-303.8 | time=0js
# iter=1 | energy=(-303.79999999999916+0j) | time=0.11614710401045159s
# computing spin correlations: 2.126s
# ZZ=-4.8 | h=-9.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-301.3 | time=0js
# iter=1 | energy=(-301.2999999999987+0j) | time=0.1262379050021991s
# computing spin correlations: 2.155s
# ZZ=-4.8 | h=-9.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-298.8 | time=0js
# iter=1 | energy=(-298.79999999999905+0j) | time=0.11878960800822824s
# computing spin correlations: 2.113s
# ZZ=-4.8 | h=-9.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-296.3 | time=0js
# iter=1 | energy=(-296.29999999999905+0j) | time=0.13362120901001617s
# computing spin correlations: 2.113s
# ZZ=-4.8 | h=-9.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-293.8 | time=0js
# iter=1 | energy=(-293.79999999999865+0j) | time=0.1582280279835686s
# computing spin correlations: 2.156s
# ZZ=-4.8 | h=-9.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-291.3 | time=0js
# iter=1 | energy=(-291.2999999999996+0j) | time=0.1316041229874827s
# computing spin correlations: 2.121s
# ZZ=-4.8 | h=-9.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-288.8 | time=0js
# iter=1 | energy=(-288.79999999999905+0j) | time=0.11346802004845813s
# computing spin correlations: 2.151s
# ZZ=-4.8 | h=-9.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-286.3 | time=0js
# iter=1 | energy=(-286.29999999999814+0j) | time=0.12121640401892364s
# computing spin correlations: 2.131s
# ZZ=-4.8 | h=-9.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-283.8 | time=0js
# iter=1 | energy=(-283.79999999999916+0j) | time=0.11500590405194089s
# computing spin correlations: 2.151s
# ZZ=-4.8 | h=-8.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-281.3 | time=0js
# iter=1 | energy=(-281.29999999999853+0j) | time=0.14691930497065187s
# computing spin correlations: 2.105s
# ZZ=-4.8 | h=-8.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-278.8 | time=0js
# iter=1 | energy=(-278.7999999999992+0j) | time=0.11278540000785142s
# computing spin correlations: 2.173s
# ZZ=-4.8 | h=-8.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-276.3 | time=0js
# iter=1 | energy=(-276.2999999999988+0j) | time=0.12048059998778626s
# computing spin correlations: 2.136s
# ZZ=-4.8 | h=-8.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-273.8 | time=0js
# iter=1 | energy=(-273.79999999999825+0j) | time=0.14415580104105175s
# computing spin correlations: 2.152s
# ZZ=-4.8 | h=-8.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-271.3 | time=0js
# iter=1 | energy=(-271.29999999999933+0j) | time=0.11368130100890994s
# computing spin correlations: 2.137s
# ZZ=-4.8 | h=-8.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-268.8 | time=0js
# iter=1 | energy=(-268.7999999999992+0j) | time=0.11757450102595612s
# computing spin correlations: 2.14s
# ZZ=-4.8 | h=-8.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-266.3 | time=0js
# iter=1 | energy=(-266.29999999999893+0j) | time=0.16502518102061003s
# computing spin correlations: 2.118s
# ZZ=-4.8 | h=-8.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-263.8 | time=0js
# iter=1 | energy=(-263.7999999999989+0j) | time=0.1433621839969419s
# computing spin correlations: 2.18s
# ZZ=-4.8 | h=-8.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-261.3 | time=0js
# iter=1 | energy=(-261.29999999999893+0j) | time=0.11865128600038588s
# computing spin correlations: 2.118s
# ZZ=-4.8 | h=-8.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-258.8 | time=0js
# iter=1 | energy=(-258.7999999999988+0j) | time=0.18139099201653153s
# computing spin correlations: 2.105s
# ZZ=-4.8 | h=-7.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-256.3 | time=0js
# iter=1 | energy=(-256.2999999999992+0j) | time=0.11742889496963471s
# computing spin correlations: 2.102s
# ZZ=-4.8 | h=-7.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-253.8 | time=0js
# iter=1 | energy=(-253.7999999999986+0j) | time=0.139962293964345s
# computing spin correlations: 2.105s
# ZZ=-4.8 | h=-7.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-251.3 | time=0js
# iter=1 | energy=(-251.29999999999885+0j) | time=0.11534549295902252s
# computing spin correlations: 2.104s
# ZZ=-4.8 | h=-7.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-248.8 | time=0js
# iter=1 | energy=(-248.7999999999991+0j) | time=0.1244479920133017s
# computing spin correlations: 2.125s
# ZZ=-4.8 | h=-7.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-246.3 | time=0js
# iter=1 | energy=(-246.29999999999953+0j) | time=0.12525959801860154s
# computing spin correlations: 2.082s
# ZZ=-4.8 | h=-7.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-243.8 | time=0js
# iter=1 | energy=(-243.7999999999983+0j) | time=0.11408419901272282s
# computing spin correlations: 2.111s
# ZZ=-4.8 | h=-7.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-241.3 | time=0js
# iter=1 | energy=(-241.29999999999927+0j) | time=0.11516649898840114s
# computing spin correlations: 2.099s
# ZZ=-4.8 | h=-7.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-238.8 | time=0js
# iter=1 | energy=(-238.79999999999905+0j) | time=0.12381819903384894s
# computing spin correlations: 2.098s
# ZZ=-4.8 | h=-7.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-236.3 | time=0js
# iter=1 | energy=(-236.29999999999876+0j) | time=0.11453800002345815s
# computing spin correlations: 2.137s
# ZZ=-4.8 | h=-7.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-233.8 | time=0js
# iter=1 | energy=(-233.79999999999876+0j) | time=0.11438479903154075s
# computing spin correlations: 2.081s
# ZZ=-4.8 | h=-6.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-231.3 | time=0js
# iter=1 | energy=(-231.29999999999964+0j) | time=0.11889209703076631s
# computing spin correlations: 2.094s
# ZZ=-4.8 | h=-6.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-228.8 | time=0js
# iter=1 | energy=(-228.79999999999865+0j) | time=0.11585729703074321s
# computing spin correlations: 2.108s
# ZZ=-4.8 | h=-6.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-226.3 | time=0js
# iter=1 | energy=(-226.2999999999994+0j) | time=0.11825059703551233s
# computing spin correlations: 2.115s
# ZZ=-4.8 | h=-6.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-223.8 | time=0js
# iter=1 | energy=(-223.79999999999905+0j) | time=0.12201010598801076s
# computing spin correlations: 2.121s
# ZZ=-4.8 | h=-6.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-221.3 | time=0js
# iter=1 | energy=(-221.2999999999987+0j) | time=0.1380526059656404s
# computing spin correlations: 2.12s
# ZZ=-4.8 | h=-6.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-218.8 | time=0js
# iter=1 | energy=(-218.799999999999+0j) | time=0.11969650100218132s
# computing spin correlations: 2.149s
# ZZ=-4.8 | h=-6.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-216.3 | time=0js
# iter=1 | energy=(-216.29999999999907+0j) | time=0.1362167980405502s
# computing spin correlations: 2.094s
# ZZ=-4.8 | h=-6.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-213.8 | time=0js
# iter=1 | energy=(-213.799999999999+0j) | time=0.11657749902224168s
# computing spin correlations: 2.12s
# ZZ=-4.8 | h=-6.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-211.3 | time=0js
# iter=1 | energy=(-211.29999999999885+0j) | time=0.11917859798995778s
# computing spin correlations: 2.122s
# ZZ=-4.8 | h=-6.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-208.8 | time=0js
# iter=1 | energy=(-208.7999999999993+0j) | time=0.11712139897281304s
# computing spin correlations: 2.112s
# ZZ=-4.8 | h=-5.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-206.3 | time=0js
# iter=1 | energy=(-206.29999999999924+0j) | time=0.1174886979861185s
# computing spin correlations: 2.129s
# ZZ=-4.8 | h=-5.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-203.8 | time=0js
# iter=1 | energy=(-203.79999999999967+0j) | time=0.12208689900580794s
# computing spin correlations: 2.088s
# ZZ=-4.8 | h=-5.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-201.3 | time=0js
# iter=1 | energy=(-201.29999999999927+0j) | time=0.11904779798351228s
# computing spin correlations: 2.168s
# ZZ=-4.8 | h=-5.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-198.8 | time=0js
# iter=1 | energy=(-198.79999999999916+0j) | time=0.1185666989767924s
# computing spin correlations: 2.142s
# ZZ=-4.8 | h=-5.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-196.3 | time=0js
# iter=1 | energy=(-196.29999999999944+0j) | time=0.1387417980004102s
# computing spin correlations: 2.115s
# ZZ=-4.8 | h=-5.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-193.8 | time=0js
# iter=1 | energy=(-193.799999999999+0j) | time=0.11516779800876975s
# computing spin correlations: 2.101s
# ZZ=-4.8 | h=-5.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-191.3 | time=0js
# iter=1 | energy=(-191.29999999999956+0j) | time=0.11892009899020195s
# computing spin correlations: 2.153s
# ZZ=-4.8 | h=-5.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-188.8 | time=0js
# iter=1 | energy=(-188.79999999999933+0j) | time=0.12189479899825528s
# computing spin correlations: 2.098s
# ZZ=-4.8 | h=-5.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-186.3 | time=0js
# iter=1 | energy=(-186.29999999999933+0j) | time=0.12453289801487699s
# computing spin correlations: 2.14s
# ZZ=-4.8 | h=-5.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-183.8 | time=0js
# iter=1 | energy=(-183.79999999999916+0j) | time=0.11479309800779447s
# computing spin correlations: 2.115s
# ZZ=-4.7 | h=-10.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-307.575 | time=0js
# iter=1 | energy=(-307.5749999999995+0j) | time=0.11658929800614715s
# computing spin correlations: 2.133s
# ZZ=-4.7 | h=-9.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-305.075 | time=0js
# iter=1 | energy=(-305.07499999999925+0j) | time=0.11754889803705737s
# computing spin correlations: 2.095s
# ZZ=-4.7 | h=-9.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-302.575 | time=0js
# iter=1 | energy=(-302.5749999999995+0j) | time=0.11810629902174696s
# computing spin correlations: 2.136s
# ZZ=-4.7 | h=-9.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-300.075 | time=0js
# iter=1 | energy=(-300.0749999999988+0j) | time=0.13241439900593832s
# computing spin correlations: 2.083s
# ZZ=-4.7 | h=-9.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-297.575 | time=0js
# iter=1 | energy=(-297.57499999999817+0j) | time=0.1248943000100553s
# computing spin correlations: 2.147s
# ZZ=-4.7 | h=-9.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-295.075 | time=0js
# iter=1 | energy=(-295.07499999999925+0j) | time=0.13648359896615148s
# computing spin correlations: 2.093s
# ZZ=-4.7 | h=-9.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-292.575 | time=0js
# iter=1 | energy=(-292.57499999999874+0j) | time=0.16176429903134704s
# computing spin correlations: 2.163s
# ZZ=-4.7 | h=-9.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-290.075 | time=0js
# iter=1 | energy=(-290.07499999999936+0j) | time=0.17918339901370928s
# computing spin correlations: 2.127s
# ZZ=-4.7 | h=-9.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-287.575 | time=0js
# iter=1 | energy=(-287.5749999999992+0j) | time=0.16293339896947145s
# computing spin correlations: 2.164s
# ZZ=-4.7 | h=-9.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-285.075 | time=0js
# iter=1 | energy=(-285.07499999999874+0j) | time=0.1529499989701435s
# computing spin correlations: 2.162s
# ZZ=-4.7 | h=-9.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-282.575 | time=0js
# iter=1 | energy=(-282.574999999999+0j) | time=0.16095530800521374s
# computing spin correlations: 2.131s
# ZZ=-4.7 | h=-8.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-280.075 | time=0js
# iter=1 | energy=(-280.07499999999897+0j) | time=0.1768065079813823s
# computing spin correlations: 2.135s
# ZZ=-4.7 | h=-8.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-277.575 | time=0js
# iter=1 | energy=(-277.5749999999995+0j) | time=0.1801203009672463s
# computing spin correlations: 2.097s
# ZZ=-4.7 | h=-8.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-275.075 | time=0js
# iter=1 | energy=(-275.07499999999897+0j) | time=0.18175610102480277s
# computing spin correlations: 2.107s
# ZZ=-4.7 | h=-8.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-272.575 | time=0js
# iter=1 | energy=(-272.5749999999997+0j) | time=0.15273560100467876s
# computing spin correlations: 2.106s
# ZZ=-4.7 | h=-8.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-270.075 | time=0js
# iter=1 | energy=(-270.07499999999845+0j) | time=0.16688101005274802s
# computing spin correlations: 2.142s
# ZZ=-4.7 | h=-8.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-267.575 | time=0js
# iter=1 | energy=(-267.5749999999993+0j) | time=0.11703600699547678s
# computing spin correlations: 2.16s
# ZZ=-4.7 | h=-8.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-265.075 | time=0js
# iter=1 | energy=(-265.07499999999874+0j) | time=0.1536683090380393s
# computing spin correlations: 2.128s
# ZZ=-4.7 | h=-8.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-262.575 | time=0js
# iter=1 | energy=(-262.57499999999885+0j) | time=0.152577500033658s
# computing spin correlations: 2.112s
# ZZ=-4.7 | h=-8.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-260.075 | time=0js
# iter=1 | energy=(-260.0749999999989+0j) | time=0.15851840004324913s
# computing spin correlations: 2.146s
# ZZ=-4.7 | h=-8.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-257.575 | time=0js
# iter=1 | energy=(-257.5749999999999+0j) | time=0.15396010497352108s
# computing spin correlations: 2.128s
# ZZ=-4.7 | h=-7.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-255.075 | time=0js
# iter=1 | energy=(-255.0749999999996+0j) | time=0.15808140602894127s
# computing spin correlations: 2.128s
# ZZ=-4.7 | h=-7.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-252.575 | time=0js
# iter=1 | energy=(-252.5749999999992+0j) | time=0.12446950399316847s
# computing spin correlations: 2.126s
# ZZ=-4.7 | h=-7.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-250.075 | time=0js
# iter=1 | energy=(-250.07499999999914+0j) | time=0.16594399703899398s
# computing spin correlations: 2.138s
# ZZ=-4.7 | h=-7.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-247.575 | time=0js
# iter=1 | energy=(-247.57499999999885+0j) | time=0.1209505979786627s
# computing spin correlations: 2.152s
# ZZ=-4.7 | h=-7.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-245.075 | time=0js
# iter=1 | energy=(-245.07499999999897+0j) | time=0.13342689903220162s
# computing spin correlations: 2.124s
# ZZ=-4.7 | h=-7.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# ...
# computing spin correlations: 2.123s
# ZZ=5.0 | h=-9.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-168.75 | time=0js
# iter=1 | energy=(-168.74999999999946+0j) | time=0.1213567879749462s
# computing spin correlations: 2.131s
# ZZ=5.0 | h=-9.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-166.25 | time=0js
# iter=1 | energy=(-166.24999999999957+0j) | time=0.1206520990235731s
# computing spin correlations: 2.159s
# ZZ=5.0 | h=-9.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-163.75 | time=0js
# iter=1 | energy=(-163.74999999999977+0j) | time=0.1372275070170872s
# computing spin correlations: 2.132s
# ZZ=5.0 | h=-8.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-161.25 | time=0js
# iter=1 | energy=(-161.24999999999923+0j) | time=0.12109070597216487s
# computing spin correlations: 2.164s
# ZZ=5.0 | h=-8.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-158.75 | time=0js
# iter=1 | energy=(-158.74999999999926+0j) | time=0.13053950702305883s
# computing spin correlations: 2.195s
# ZZ=5.0 | h=-8.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-156.25 | time=0js
# iter=1 | energy=(-156.24999999999892+0j) | time=0.11960848298622295s
# computing spin correlations: 2.14s
# ZZ=5.0 | h=-8.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-153.75 | time=0js
# iter=1 | energy=(-153.7499999999995+0j) | time=0.11947118199896067s
# computing spin correlations: 2.145s
# ZZ=5.0 | h=-8.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-151.25 | time=0js
# iter=1 | energy=(-151.2499999999993+0j) | time=0.12731978198280558s
# computing spin correlations: 2.135s
# ZZ=5.0 | h=-8.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-148.75 | time=0js
# iter=1 | energy=(-148.7499999999993+0j) | time=0.13094160403124988s
# computing spin correlations: 2.184s
# ZZ=5.0 | h=-8.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-146.25 | time=0js
# iter=1 | energy=(-146.249999999999+0j) | time=0.12936470395652577s
# computing spin correlations: 2.117s
# ZZ=5.0 | h=-8.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-143.75 | time=0js
# iter=1 | energy=(-143.7499999999997+0j) | time=0.1268439030391164s
# computing spin correlations: 2.128s
# ZZ=5.0 | h=-8.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-141.25 | time=0js
# iter=1 | energy=(-141.24999999999903+0j) | time=0.1193630020134151s
# computing spin correlations: 2.106s
# ZZ=5.0 | h=-8.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-138.75 | time=0js
# iter=1 | energy=(-138.74999999999923+0j) | time=0.12911270203767344s
# computing spin correlations: 2.134s
# ZZ=5.0 | h=-7.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-136.25 | time=0js
# iter=1 | energy=(-136.2499999999993+0j) | time=0.12213259900454432s
# computing spin correlations: 2.126s
# ZZ=5.0 | h=-7.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-133.75 | time=0js
# iter=1 | energy=(-133.74999999999912+0j) | time=0.12917139899218455s
# computing spin correlations: 2.106s
# ZZ=5.0 | h=-7.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-131.25 | time=0js
# iter=1 | energy=(-131.24999999999957+0j) | time=0.11856969899963588s
# computing spin correlations: 2.139s
# ZZ=5.0 | h=-7.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-128.75 | time=0js
# iter=1 | energy=(-128.74999999999918+0j) | time=0.1476047919713892s
# computing spin correlations: 2.139s
# ZZ=5.0 | h=-7.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-126.25 | time=0js
# iter=1 | energy=(-126.24999999999986+0j) | time=0.13038539298577234s
# computing spin correlations: 2.117s
# ZZ=5.0 | h=-7.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-123.75 | time=0js
# iter=1 | energy=(-123.75000000000004+0j) | time=0.12359539500903338s
# computing spin correlations: 2.144s
# ZZ=5.0 | h=-7.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-121.25 | time=0js
# iter=1 | energy=(-121.24999999999957+0j) | time=0.11557619500672445s
# computing spin correlations: 2.165s
# ZZ=5.0 | h=-7.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-118.75 | time=0js
# iter=1 | energy=(-118.74999999999918+0j) | time=0.15878239402081817s
# computing spin correlations: 2.154s
# ZZ=5.0 | h=-7.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-116.25 | time=0js
# iter=1 | energy=(-116.24999999999973+0j) | time=0.11943929496919736s
# computing spin correlations: 2.142s
# ZZ=5.0 | h=-7.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-113.75 | time=0js
# iter=1 | energy=(-113.74999999999983+0j) | time=0.17240149300778285s
# computing spin correlations: 2.137s
# ZZ=5.0 | h=-6.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-111.25 | time=0js
# iter=1 | energy=(-111.25000000000004+0j) | time=0.12143919401569292s
# computing spin correlations: 2.131s
# ZZ=5.0 | h=-6.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-108.75 | time=0js
# iter=1 | energy=(-108.74999999999966+0j) | time=0.1354425570461899s
# computing spin correlations: 2.118s
# ZZ=5.0 | h=-6.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-106.25 | time=0js
# iter=1 | energy=(-106.24999999999969+0j) | time=0.12648135400377214s
# computing spin correlations: 2.134s
# ZZ=5.0 | h=-6.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-103.75 | time=0js
# iter=1 | energy=(-103.74999999999935+0j) | time=0.11920299200573936s
# computing spin correlations: 2.098s
# ZZ=5.0 | h=-6.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-101.25 | time=0js
# iter=1 | energy=(-101.24999999999939+0j) | time=0.21932628599461168s
# computing spin correlations: 2.137s
# ZZ=5.0 | h=-6.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-98.75 | time=0js
# iter=1 | energy=(-98.74999999999946+0j) | time=0.11583799298387021s
# computing spin correlations: 2.217s
# ZZ=5.0 | h=-6.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-96.25 | time=0js
# iter=1 | energy=(-96.24999999999967+0j) | time=0.11610139696858823s
# computing spin correlations: 2.131s
# ZZ=5.0 | h=-6.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-93.75 | time=0js
# iter=1 | energy=(-93.74999999999936+0j) | time=0.11869689699960873s
# computing spin correlations: 2.115s
# ZZ=5.0 | h=-6.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-91.25 | time=0js
# iter=1 | energy=(-91.24999999999959+0j) | time=0.1177882970077917s
# computing spin correlations: 2.146s
# ZZ=5.0 | h=-6.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-88.75 | time=0js
# iter=1 | energy=(-88.74999999999955+0j) | time=0.11770140001317486s
# computing spin correlations: 2.15s
# ZZ=5.0 | h=-5.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-86.339665 | time=0js
# iter=1 | energy=(-86.33966473212234+0j) | time=0.12519590003648773s
# computing spin correlations: 2.223s
# ZZ=5.0 | h=-5.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-84.3993 | time=0js
# iter=1 | energy=(-84.4800273144053+0j) | time=1.6072884990135208s
# iter=2 | energy=(-84.48107626853621+0j) | time=2.8483910990180448s
# iter=3 | energy=(-84.4816743702593+0j) | time=4.006064298038837s
# iter=4 | energy=(-84.48277273700616+0j) | time=5.278807998052798s
# iter=5 | energy=(-84.49207813249238+0j) | time=6.744425797078293s
# iter=6 | energy=(-84.58336713225525+0j) | time=8.141171497118194s
# iter=7 | energy=(-84.66046853031197+0j) | time=9.622953508107457s
# iter=8 | energy=(-84.74132664092255+0j) | time=11.018424018111546s
# iter=9 | energy=(-84.78470829710695+0j) | time=12.30065892712446s
# iter=10 | energy=(-84.79873303963183+0j) | time=13.755327238119207s
# iter=11 | energy=(-84.80170197796438+0j) | time=15.174395948124584s
# iter=12 | energy=(-84.80244267157258+0j) | time=16.467616191133857s
# iter=13 | energy=(-84.80260845360809+0j) | time=17.37735535914544s
# iter=14 | energy=(-84.80265188302015+0j) | time=18.035460408136714s
# iter=15 | energy=(-84.80265188301972+0j) | time=18.710368759115227s
# computing spin correlations: 13.756s
# ZZ=5.0 | h=-5.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-82.492662 | time=0js
# iter=1 | energy=(-82.61860176287875+0j) | time=1.5533305529970676s
# iter=2 | energy=(-82.67373686898246+0j) | time=3.0496922039892524s
# iter=3 | energy=(-82.98767815342565+0j) | time=4.283778112963773s
# iter=4 | energy=(-82.9970785773581+0j) | time=5.685429164965171s
# iter=5 | energy=(-83.01177347670674+0j) | time=7.107565315964166s
# iter=6 | energy=(-83.0904085128608+0j) | time=8.562730866950005s
# iter=7 | energy=(-83.12666803345105+0j) | time=9.972120617923792s
# iter=8 | energy=(-83.13310034279777+0j) | time=11.380582269921433s
# iter=9 | energy=(-83.1506251617771+0j) | time=12.765815361926798s
# iter=10 | energy=(-83.18301450617591+0j) | time=14.095909570925869s
# iter=11 | energy=(-83.19284878584634+0j) | time=15.539510979899205s
# iter=12 | energy=(-83.19404397027913+0j) | time=16.80912038788665s
# iter=13 | energy=(-83.19404397027849+0j) | time=17.3356829918921s
# computing spin correlations: 13.816s
# ZZ=5.0 | h=-5.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-80.996527 | time=0js
# iter=1 | energy=(-81.51696624172571+0j) | time=1.7488581130164675s
# iter=2 | energy=(-81.57585169208723+0j) | time=3.0737581260036677s
# iter=3 | energy=(-81.62114118113489+0j) | time=4.562550641014241s
# iter=4 | energy=(-81.68436573576024+0j) | time=6.0103739550104365s
# iter=5 | energy=(-81.69379029221652+0j) | time=7.28424286696827s
# iter=6 | energy=(-81.69567010086023+0j) | time=8.665831980993971s
# iter=7 | energy=(-81.69738109311724+0j) | time=10.024836384982336s
# iter=8 | energy=(-81.69988744053335+0j) | time=11.304423886991572s
# iter=9 | energy=(-81.70316980382849+0j) | time=12.693105088954326s
# iter=10 | energy=(-81.70696280016116+0j) | time=14.093519091955386s
# iter=11 | energy=(-81.71060240808443+0j) | time=15.381544393952936s
# iter=12 | energy=(-81.71255628399679+0j) | time=16.798411895986646s
# iter=13 | energy=(-81.71336283526614+0j) | time=18.115541796956677s
# iter=14 | energy=(-81.71347955739188+0j) | time=18.776602896978147s
# iter=15 | energy=(-81.71347955739142+0j) | time=19.26597219699761s
# computing spin correlations: 13.529s
# ZZ=5.0 | h=-5.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-79.774497 | time=0js
# iter=1 | energy=(-80.27379315579823+0j) | time=1.6563022849732079s
# iter=2 | energy=(-80.3033230696068+0j) | time=3.220064670953434s
# iter=3 | energy=(-80.31115474530839+0j) | time=4.513621657970361s
# iter=4 | energy=(-80.31360702080538+0j) | time=5.983021040970925s
# iter=5 | energy=(-80.31405095723669+0j) | time=6.8367454299586825s
# iter=6 | energy=(-80.31405095723748+0j) | time=7.470225122931879s
# computing spin correlations: 13.631s
# ZZ=5.0 | h=-5.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-78.395779 | time=0js
# iter=1 | energy=(-78.99610622131618+0j) | time=1.6145728109986521s
# iter=2 | energy=(-79.03189554822501+0j) | time=3.032175422005821s
# iter=3 | energy=(-79.04045200607779+0j) | time=4.481839030981064s
# iter=4 | energy=(-79.04224827070743+0j) | time=5.749804739956744s
# iter=5 | energy=(-79.04245094344728+0j) | time=6.6505031459382735s
# iter=6 | energy=(-79.04245094344691+0j) | time=7.138899348967243s
# computing spin correlations: 13.712s
# ZZ=5.0 | h=-5.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-77.173664 | time=0js
# iter=1 | energy=(-77.72933754789497+0j) | time=1.706373415014241s
# iter=2 | energy=(-77.82446390442627+0j) | time=3.102134378044866s
# iter=3 | energy=(-77.86118556125214+0j) | time=4.518294164037798s
# iter=4 | energy=(-77.86410563197643+0j) | time=5.870686551032122s
# iter=5 | energy=(-77.86436442737353+0j) | time=6.707587143057026s
# iter=6 | energy=(-77.86436442737458+0j) | time=7.340144937043078s
# computing spin correlations: 13.779s
# ZZ=5.0 | h=-5.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-76.059349 | time=0js
# iter=1 | energy=(-76.6221275813951+0j) | time=1.581917903968133s
# iter=2 | energy=(-76.75858347473802+0j) | time=3.046045608003624s
# iter=3 | energy=(-76.76459999767192+0j) | time=4.513772612030152s
# iter=4 | energy=(-76.76484592952733+0j) | time=5.295372414053418s
# iter=5 | energy=(-76.76484592952777+0j) | time=5.771717816009186s
# computing spin correlations: 13.657s
# ZZ=5.0 | h=-5.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-75.088638 | time=0js
# iter=1 | energy=(-75.53257724795365+0j) | time=1.659041601989884s
# iter=2 | energy=(-75.66584132415977+0j) | time=3.1793700059643015s
# iter=3 | energy=(-75.67663131561233+0j) | time=4.563066710950807s
# iter=4 | energy=(-75.70286979274651+0j) | time=6.036829216987826s
# iter=5 | energy=(-75.7232529795986+0j) | time=7.492999822017737s
# iter=6 | energy=(-75.72723330320274+0j) | time=8.823133027006406s
# iter=7 | energy=(-75.72738569527294+0j) | time=9.587146129983012s
# iter=8 | energy=(-75.72738569527287+0j) | time=10.13989293196937s
# computing spin correlations: 14.015s
# ZZ=5.0 | h=-5.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-74.227477 | time=0js
# iter=1 | energy=(-74.56492032123944+0j) | time=1.5367275039898232s
# iter=2 | energy=(-74.5649203212405+0j) | time=2.040246505988762s
# computing spin correlations: 13.063s

# %%
ZZ_coupling_start = 2.7
ZZ_coupling_end = 5
delta_ZZ = 0.1

ZZ_couplings = bk.arange(ZZ_coupling_start, ZZ_coupling_end+delta_ZZ, delta_ZZ)

magnetic_field_start = -5
magnetic_field_end = 0
delta_h = 0.1

magnetic_fields = bk.arange(magnetic_field_start, magnetic_field_end+delta_h, delta_h)

# %%
for it1, ZZ_coupling in enumerate(ZZ_couplings):
    for it2, magnetic_field in enumerate(magnetic_fields):
        
        if verbose:
            print(f"ZZ={round(ZZ_coupling,2)} | h={round(magnetic_field,2)}")
        
        Hamiltonian = XXZ_model(
            bk=bk, n_sites=n_sites, ZZ_coupling=ZZ_coupling,
            XY_coupling=XY_coupling, magnetic_field=magnetic_field,
        )
        
        ground_energies, ground_times, ground_MPS = DMRG(
            bk = bk,
            Hamiltonian = Hamiltonian,
            NKeep = NKeep,
            NSweep = NSweep,
            Krylov_bases = Krylov_bases,
            Lanczos_cutoff = Lanczos_cutoff,
            iterative_diag = True,
            two_site = two_site,
            verbose = verbose,
            tol = 1e-8,
        )
        
        param = Params(
            L = n_sites,
            XY = XY_coupling,
            ZZ = ZZ_coupling,
            h = magnetic_field,
            NKeep = NKeep,
            NSweep = NSweep,
            diag = iterative_diag,
            Krylov = Krylov_bases,
            cutoff = Lanczos_cutoff,
            two = two_site
        )
        
        # dir_name = Path(f"data")
        dir_name = Path(f"{device}/data")
        dir_name.mkdir(parents=True, exist_ok=True)
        
        filename = f"{param.to_log()}"
        ground_state_energy = ground_energies[-1]
        Neumann_entropy = get_Neumann_entropy(ground_MPS, bk=bk)
        spin_z = get_spin_z(ground_MPS, bk)
        
        if verbose:
            print(f"computing spin correlations: ", end="")
            now = time.perf_counter()
        spin_correlations = get_spin_correlations(ground_MPS, bk)
        if verbose:
            print(f"{round(time.perf_counter()-now,3)}s")
        
        result = Results(
            ground_MPS = [],
            ground_state_energy = ground_state_energy,
            ground_energies = ground_energies,
            Neumann_entropy = Neumann_entropy,
            spin_z = spin_z,
            spin_correlations = spin_correlations,
        )
        
        output: dict[str, Any] = {}
        output.update(asdict(param))
        output.update(asdict(result))
        
        with open(dir_name / f"{filename}.pkl", "wb") as file:
            pickle.dump(output, file)
# Out:
# ZZ=2.7 | h=-5.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-91.925 | time=0js
# iter=1 | energy=(-91.9249999999998+0j) | time=0.12159419897943735s
# computing spin correlations: 2.077s
# ZZ=2.7 | h=-4.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-89.425 | time=0js
# iter=1 | energy=(-89.4249999999996+0j) | time=0.11380240001017228s
# computing spin correlations: 2.099s
# ZZ=2.7 | h=-4.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-86.925 | time=0js
# iter=1 | energy=(-86.92499999999964+0j) | time=0.11385010002413765s
# computing spin correlations: 2.115s
# ZZ=2.7 | h=-4.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-84.425 | time=0js
# iter=1 | energy=(-84.42499999999941+0j) | time=0.14939550001872703s
# computing spin correlations: 2.102s
# ZZ=2.7 | h=-4.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-81.925 | time=0js
# iter=1 | energy=(-81.92499999999953+0j) | time=0.11318929301341996s
# computing spin correlations: 2.096s
# ZZ=2.7 | h=-4.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-79.425 | time=0js
# iter=1 | energy=(-79.4249999999996+0j) | time=0.11574829299934208s
# computing spin correlations: 2.089s
# ZZ=2.7 | h=-4.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-76.925 | time=0js
# iter=1 | energy=(-76.92499999999961+0j) | time=0.11414169298950583s
# computing spin correlations: 2.097s
# ZZ=2.7 | h=-4.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-74.425 | time=0js
# iter=1 | energy=(-74.42499999999988+0j) | time=0.11493590095778927s
# computing spin correlations: 2.169s
# ZZ=2.7 | h=-4.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-71.925 | time=0js
# iter=1 | energy=(-71.92499999999961+0j) | time=0.1462397999712266s
# computing spin correlations: 2.075s
# ZZ=2.7 | h=-4.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-69.425 | time=0js
# iter=1 | energy=(-69.42499999999974+0j) | time=0.12235359998885542s
# computing spin correlations: 2.094s
# ZZ=2.7 | h=-4.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-66.925 | time=0js
# iter=1 | energy=(-66.9249999999995+0j) | time=0.1171364999609068s
# computing spin correlations: 2.095s
# ZZ=2.7 | h=-3.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.425 | time=0js
# iter=1 | energy=(-64.42499999999981+0j) | time=0.11464179999893531s
# computing spin correlations: 2.084s
# ZZ=2.7 | h=-3.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-61.925 | time=0js
# iter=1 | energy=(-61.92499999999962+0j) | time=0.11560790002113208s
# computing spin correlations: 2.099s
# ZZ=2.7 | h=-3.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-59.425 | time=0js
# iter=1 | energy=(-59.42499999999956+0j) | time=0.11439048103056848s
# computing spin correlations: 2.112s
# ZZ=2.7 | h=-3.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-57.095779 | time=0js
# iter=1 | energy=(-57.11267321372043+0j) | time=0.6391149970004335s
# iter=2 | energy=(-57.112673213719965+0j) | time=0.8721744589856826s
# computing spin correlations: 7.203s
# ZZ=2.7 | h=-3.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-55.221539 | time=0js
# iter=1 | energy=(-55.3003195912379+0j) | time=1.1881611389690079s
# iter=2 | energy=(-55.30031959123779+0j) | time=1.6626203329651617s
# computing spin correlations: 11.159s
# ZZ=2.7 | h=-3.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.554244 | time=0js
# iter=1 | energy=(-53.690216012251504+0j) | time=1.5111523249652237s
# iter=2 | energy=(-53.74597966162157+0j) | time=2.799696806934662s
# iter=3 | energy=(-53.860562788692974+0j) | time=4.032191384932958s
# iter=4 | energy=(-53.9016593921745+0j) | time=5.3883908709394746s
# iter=5 | energy=(-53.9042074823948+0j) | time=6.555817344982643s
# iter=6 | energy=(-53.90420748239435+0j) | time=7.056319076975342s
# computing spin correlations: 12.498s
# ZZ=2.7 | h=-3.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-52.144138 | time=0js
# iter=1 | energy=(-52.30356533380234+0j) | time=1.0300479449797422s
# iter=2 | energy=(-52.30356533380179+0j) | time=1.7079935750225559s
# computing spin correlations: 12.141s
# ZZ=2.7 | h=-3.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-50.702397 | time=0js
# iter=1 | energy=(-50.922226834426084+0j) | time=1.0971337069640867s
# iter=2 | energy=(-50.9222268344256+0j) | time=1.6269960469799116s
# computing spin correlations: 12.219s
# ZZ=2.7 | h=-3.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-49.701196 | time=0js
# iter=1 | energy=(-49.83319719992262+0j) | time=1.12647520104656s
# iter=2 | energy=(-49.833197199922225+0j) | time=1.6826246010605246s
# computing spin correlations: 12.259s
# ZZ=2.7 | h=-3.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-48.567879 | time=0js
# iter=1 | energy=(-48.70267713237563+0j) | time=1.0152197029674426s
# iter=2 | energy=(-48.70267713237537+0j) | time=1.7118635050137527s
# computing spin correlations: 12.17s
# ZZ=2.7 | h=-2.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-47.553073 | time=0js
# iter=1 | energy=(-47.664914743551606+0j) | time=1.0055447549675591s
# iter=2 | energy=(-47.664914743551506+0j) | time=1.6243770659784786s
# computing spin correlations: 12.544s
# ZZ=2.7 | h=-2.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-46.262071 | time=0js
# iter=1 | energy=(-46.564877238049526+0j) | time=1.100131610990502s
# iter=2 | energy=(-46.564877238048986+0j) | time=1.6367676169611514s
# computing spin correlations: 12.404s
# ZZ=2.7 | h=-2.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-45.454153 | time=0js
# iter=1 | energy=(-45.70630607711492+0j) | time=1.1758898299885914s
# iter=2 | energy=(-45.706306077115144+0j) | time=1.6738267419859767s
# computing spin correlations: 12.589s
# ZZ=2.7 | h=-2.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-44.748067 | time=0js
# iter=1 | energy=(-44.912382374260524+0j) | time=1.115637123992201s
# iter=2 | energy=(-44.91238237426066+0j) | time=1.6964007359929383s
# computing spin correlations: 12.151s
# ZZ=2.7 | h=-2.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-44.098966 | time=0js
# iter=1 | energy=(-44.167641191244144+0j) | time=1.0800199160003103s
# iter=2 | energy=(-44.16764119124388+0j) | time=1.5975043239886872s
# computing spin correlations: 12.434s
# ZZ=2.7 | h=-2.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-43.112425 | time=0js
# iter=1 | energy=(-43.36762531901482+0j) | time=1.5066398999770172s
# iter=2 | energy=(-43.367625319015254+0j) | time=1.9771985999541357s
# computing spin correlations: 12.348s
# ZZ=2.7 | h=-2.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-42.651778 | time=0js
# iter=1 | energy=(-42.75574398712794+0j) | time=1.05049480200978s
# iter=2 | energy=(-42.755743987128376+0j) | time=1.6146574040176347s
# computing spin correlations: 12.228s
# ZZ=2.7 | h=-2.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.741228 | time=0js
# iter=1 | energy=(-42.05573344343042+0j) | time=1.2025679069920443s
# iter=2 | energy=(-42.05573344343001+0j) | time=1.698032410000451s
# computing spin correlations: 12.503s
# ZZ=2.7 | h=-2.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.44445 | time=0js
# iter=1 | energy=(-41.55951965926398+0j) | time=1.060780502972193s
# iter=2 | energy=(-41.55951965926364+0j) | time=1.689620904973708s
# computing spin correlations: 12.691s
# ZZ=2.7 | h=-2.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.626513 | time=0js
# iter=1 | energy=(-40.959502494927456+0j) | time=1.051224700990133s
# iter=2 | energy=(-40.959502494927776+0j) | time=1.6439616010175087s
# computing spin correlations: 12.871s
# ZZ=2.7 | h=-1.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.463298 | time=0js
# iter=1 | energy=(-40.561135327859546+0j) | time=1.1433953980449587s
# iter=2 | energy=(-40.56113532785961+0j) | time=1.6773178970324807s
# computing spin correlations: 12.262s
# ZZ=2.7 | h=-1.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.751975 | time=0js
# iter=1 | energy=(-40.06112684955601+0j) | time=1.0145578940282576s
# iter=2 | energy=(-40.061126849556345+0j) | time=1.668729291006457s
# computing spin correlations: 12.435s
# ZZ=2.7 | h=-1.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.67761 | time=0js
# iter=1 | energy=(-39.74254237314613+0j) | time=1.0907563950167969s
# iter=2 | energy=(-39.74254237314621+0j) | time=1.8133894920465536s
# computing spin correlations: 13.282s
# ZZ=2.7 | h=-1.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.103434 | time=0js
# iter=1 | energy=(-39.342539887603294+0j) | time=1.2579802940017544s
# iter=2 | energy=(-39.34253988760317+0j) | time=1.771931391034741s
# computing spin correlations: 13.051s
# ZZ=2.7 | h=-1.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.020784 | time=0js
# iter=1 | energy=(-39.08663070539061+0j) | time=1.1747854999848641s
# iter=2 | energy=(-39.08663070539056+0j) | time=1.7286854999838397s
# computing spin correlations: 12.791s
# ZZ=2.7 | h=-1.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.64391 | time=0js
# iter=1 | energy=(-38.78663688011653+0j) | time=1.0367018000106327s
# iter=2 | energy=(-38.786636880116504+0j) | time=1.6031989000039175s
# computing spin correlations: 13.516s
# ZZ=2.7 | h=-1.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.398598 | time=0js
# iter=1 | energy=(-38.580700771640984+0j) | time=1.0065722970175557s
# iter=2 | energy=(-38.58070077164134+0j) | time=1.6979276950005442s
# computing spin correlations: 12.611s
# ZZ=2.7 | h=-1.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.313837 | time=0js
# iter=1 | energy=(-38.38072543615424+0j) | time=1.0724044989910908s
# iter=2 | energy=(-38.38072543615421+0j) | time=1.5886738989502192s
# computing spin correlations: 12.833s
# ZZ=2.7 | h=-1.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.903987 | time=0js
# iter=1 | energy=(-38.180723203518184+0j) | time=1.1118478989810683s
# iter=2 | energy=(-38.18072320351774+0j) | time=1.7848530989722349s
# computing spin correlations: 12.847s
# ZZ=2.7 | h=-1.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.07782 | time=0js
# iter=1 | energy=(-38.129320955649405+0j) | time=1.1253110020188615s
# iter=2 | energy=(-38.12932095564932+0j) | time=1.9343992020585574s
# computing spin correlations: 12.765s
# ZZ=2.7 | h=-0.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.745418 | time=0js
# iter=1 | energy=(-38.029250368598+0j) | time=1.0077824089676142s
# iter=2 | energy=(-38.029250368598035+0j) | time=1.6555564149748534s
# computing spin correlations: 13.535s
# ZZ=2.7 | h=-0.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.531069 | time=0js
# iter=1 | energy=(-37.62891318821295+0j) | time=1.140029998961836s
# iter=2 | energy=(-37.62891318821291+0j) | time=1.7453739979537204s
# computing spin correlations: 12.772s
# ZZ=2.7 | h=-0.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.542174 | time=0js
# iter=1 | energy=(-37.62891395720054+0j) | time=1.1942584000062197s
# iter=2 | energy=(-37.62891395720058+0j) | time=1.7153090999927372s
# computing spin correlations: 12.651s
# ZZ=2.7 | h=-0.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.551935 | time=0js
# iter=1 | energy=(-37.62891498105297+0j) | time=1.1814088000101037s
# iter=2 | energy=(-37.6289149810527+0j) | time=1.631793400971219s
# computing spin correlations: 12.544s
# ZZ=2.7 | h=-0.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.559558 | time=0js
# iter=1 | energy=(-37.62889485847097+0j) | time=1.011330501001794s
# iter=2 | energy=(-37.628894858471185+0j) | time=1.6518024010001682s
# computing spin correlations: 12.893s
# ZZ=2.7 | h=-0.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.566048 | time=0js
# iter=1 | energy=(-37.62888960628064+0j) | time=0.9956724009825848s
# iter=2 | energy=(-37.62888960628086+0j) | time=1.6082975009921938s
# computing spin correlations: 13.194s
# ZZ=2.7 | h=-0.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.57177 | time=0js
# iter=1 | energy=(-37.62890044758322+0j) | time=0.8887614990235306s
# iter=2 | energy=(-37.62890044758347+0j) | time=1.5330733980517834s
# computing spin correlations: 12.192s
# ZZ=2.7 | h=-0.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.576903 | time=0js
# iter=1 | energy=(-37.628903505773856+0j) | time=0.9760607969947159s
# iter=2 | energy=(-37.62890350577377+0j) | time=1.4527422959799878s
# computing spin correlations: 12.414s
# ZZ=2.7 | h=-0.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.581537 | time=0js
# iter=1 | energy=(-37.628899899803166+0j) | time=0.8948977990075946s
# iter=2 | energy=(-37.62889989980325+0j) | time=1.3723096980247647s
# computing spin correlations: 11.967s
# ZZ=2.7 | h=0.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.585822 | time=0js
# iter=1 | energy=(-37.628880242870665+0j) | time=0.8495130970259197s
# iter=2 | energy=(-37.62888024287055+0j) | time=1.303042796032969s
# computing spin correlations: 12.407s
# ZZ=2.8 | h=-5.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-90.7 | time=0js
# iter=1 | energy=(-90.69999999999946+0j) | time=0.11766129999887198s
# computing spin correlations: 2.141s
# ZZ=2.8 | h=-4.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-88.2 | time=0js
# iter=1 | energy=(-88.19999999999945+0j) | time=0.1184785999939777s
# computing spin correlations: 2.137s
# ZZ=2.8 | h=-4.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-85.7 | time=0js
# iter=1 | energy=(-85.69999999999972+0j) | time=0.12614380003651604s
# computing spin correlations: 2.121s
# ZZ=2.8 | h=-4.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-83.2 | time=0js
# iter=1 | energy=(-83.19999999999962+0j) | time=0.11844989995006472s
# computing spin correlations: 2.11s
# ZZ=2.8 | h=-4.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-80.7 | time=0js
# iter=1 | energy=(-80.69999999999976+0j) | time=0.11951289896387607s
# computing spin correlations: 2.116s
# ZZ=2.8 | h=-4.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-78.2 | time=0js
# iter=1 | energy=(-78.19999999999956+0j) | time=0.12825399899156764s
# computing spin correlations: 2.119s
# ZZ=2.8 | h=-4.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-75.7 | time=0js
# iter=1 | energy=(-75.69999999999958+0j) | time=0.11549140000715852s
# computing spin correlations: 2.151s
# ZZ=2.8 | h=-4.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-73.2 | time=0js
# iter=1 | energy=(-73.1999999999996+0j) | time=0.12963930005207658s
# computing spin correlations: 2.129s
# ZZ=2.8 | h=-4.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-70.7 | time=0js
# iter=1 | energy=(-70.69999999999978+0j) | time=0.11447479802882299s
# computing spin correlations: 2.123s
# ZZ=2.8 | h=-4.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-68.2 | time=0js
# iter=1 | energy=(-68.19999999999962+0j) | time=0.12395049800397828s
# computing spin correlations: 2.095s
# ZZ=2.8 | h=-4.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-65.7 | time=0js
# iter=1 | energy=(-65.69999999999958+0j) | time=0.11609029799001291s
# computing spin correlations: 2.129s
# ZZ=2.8 | h=-3.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.2 | time=0js
# iter=1 | energy=(-63.19999999999956+0j) | time=0.11748050001915544s
# computing spin correlations: 2.105s
# ZZ=2.8 | h=-3.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-60.7 | time=0js
# iter=1 | energy=(-60.699999999999704+0j) | time=0.11646270001074299s
# computing spin correlations: 2.114s
# ZZ=2.8 | h=-3.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-58.370774 | time=0js
# iter=1 | energy=(-58.38780618237665+0j) | time=0.5382184989866801s
# iter=2 | energy=(-58.3878061823765+0j) | time=0.7847114979522303s
# computing spin correlations: 7.482s
# ZZ=2.8 | h=-3.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-56.497794 | time=0js
# iter=1 | energy=(-56.57512503438425+0j) | time=1.3029746030224487s
# iter=2 | energy=(-56.57512503438446+0j) | time=1.7887061040382832s
# computing spin correlations: 11.745s
# ZZ=2.8 | h=-3.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-54.831658 | time=0js
# iter=1 | energy=(-54.96481936503077+0j) | time=1.343736202979926s
# iter=2 | energy=(-55.169875517062906+0j) | time=2.7136791070224717s
# iter=3 | energy=(-55.1759203922729+0j) | time=3.832945209054742s
# iter=4 | energy=(-55.17604809856202+0j) | time=4.535610211023595s
# iter=5 | energy=(-55.17604809856191+0j) | time=5.031870212056674s
# computing spin correlations: 12.538s
# ZZ=2.8 | h=-3.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.417683 | time=0js
# iter=1 | energy=(-53.576261546154996+0j) | time=1.0866396009805612s
# iter=2 | energy=(-53.57626154615498+0j) | time=1.6391027019708417s
# computing spin correlations: 12.268s
# ZZ=2.8 | h=-3.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-51.976945 | time=0js
# iter=1 | energy=(-52.19436526419878+0j) | time=1.3583660000003874s
# iter=2 | energy=(-52.397450955542645+0j) | time=2.7914913989952765s
# iter=3 | energy=(-52.400355128848695+0j) | time=4.282032297982369s
# iter=4 | energy=(-52.40035512884837+0j) | time=4.73566079797456s
# computing spin correlations: 12.739s
# ZZ=2.8 | h=-3.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-50.97323 | time=0js
# iter=1 | energy=(-51.10048245218732+0j) | time=0.9958937059855089s
# iter=2 | energy=(-51.10048245218748+0j) | time=1.6803558110259473s
# computing spin correlations: 12.188s
# ZZ=2.8 | h=-3.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-49.840144 | time=0js
# iter=1 | energy=(-49.96680952761749+0j) | time=1.3580881009693258s
# iter=2 | energy=(-49.966809527617684+0j) | time=1.8898423009668477s
# computing spin correlations: 12.428s
# ZZ=2.8 | h=-3.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-48.455756 | time=0js
# iter=1 | energy=(-48.766734281322464+0j) | time=1.089269799995236s
# iter=2 | energy=(-48.76673428132222+0j) | time=1.5972779999719933s
# computing spin correlations: 12.076s
# ZZ=2.8 | h=-2.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-47.532564 | time=0js
# iter=1 | energy=(-47.82488891472473+0j) | time=1.0115312009584159s
# iter=2 | energy=(-47.82488891472498+0j) | time=1.6773554019164294s
# computing spin correlations: 12.496s
# ZZ=2.8 | h=-2.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-46.722953 | time=0js
# iter=1 | energy=(-46.96104062707062+0j) | time=1.0862655999953859s
# iter=2 | energy=(-46.961040627071014+0j) | time=1.5972641009720974s
# computing spin correlations: 12.766s
# ZZ=2.8 | h=-2.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-46.011211 | time=0js
# iter=1 | energy=(-46.16048331256193+0j) | time=1.0808668000390753s
# iter=2 | energy=(-46.16048331256237+0j) | time=1.5866201990284026s
# computing spin correlations: 12.469s
# ZZ=2.8 | h=-2.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-44.898193 | time=0js
# iter=1 | energy=(-45.260454085443456+0j) | time=1.133111100003589s
# iter=2 | energy=(-45.26045408544363+0j) | time=1.6512719999882393s
# computing spin correlations: 12.831s
# ZZ=2.8 | h=-2.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-44.374859 | time=0js
# iter=1 | energy=(-44.607478672401946+0j) | time=1.1160306999809109s
# iter=2 | energy=(-44.607478672402216+0j) | time=1.646313599019777s
# computing spin correlations: 12.668s
# ZZ=2.8 | h=-2.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-43.898143 | time=0js
# iter=1 | energy=(-43.98548913115562+0j) | time=1.0376133989775553s
# iter=2 | energy=(-43.98548913115572+0j) | time=1.5746709979721345s
# computing spin correlations: 12.474s
# ZZ=2.8 | h=-2.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-42.99885 | time=0js
# iter=1 | energy=(-43.28547561312773+0j) | time=1.1946984969545156s
# iter=2 | energy=(-43.285475613127666+0j) | time=1.7256280959700234s
# computing spin correlations: 12.435s
# ZZ=2.8 | h=-2.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-42.68204 | time=0js
# iter=1 | energy=(-42.77708817162209+0j) | time=1.044707999972161s
# iter=2 | energy=(-42.77708817162201+0j) | time=1.704086298996117s
# computing spin correlations: 12.277s
# ZZ=2.8 | h=-2.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.877922 | time=0js
# iter=1 | energy=(-42.1770796315851+0j) | time=1.0290042019914836s
# iter=2 | energy=(-42.177079631585194+0j) | time=1.5898426030180417s
# computing spin correlations: 13.063s
# ZZ=2.8 | h=-2.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.684656 | time=0js
# iter=1 | energy=(-41.764283126742335+0j) | time=1.0234921330120414s
# iter=2 | energy=(-41.764283126742114+0j) | time=1.706758055021055s
# computing spin correlations: 13.272s
# ZZ=2.8 | h=-1.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.995587 | time=0js
# iter=1 | energy=(-41.26427752434287+0j) | time=1.1859176339930855s
# iter=2 | energy=(-41.26427752434318+0j) | time=1.8148574520018883s
# computing spin correlations: 12.777s
# ZZ=2.8 | h=-1.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.867561 | time=0js
# iter=1 | energy=(-40.929004268619984+0j) | time=1.1345015040133148s
# iter=2 | energy=(-40.929004268619984+0j) | time=1.6599117070436478s
# computing spin correlations: 12.781s
# ZZ=2.8 | h=-1.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.332705 | time=0js
# iter=1 | energy=(-40.52900544319168+0j) | time=1.4430730040185153s
# iter=2 | energy=(-40.52900544319196+0j) | time=1.9337643050239421s
# computing spin correlations: 12.865s
# ZZ=2.8 | h=-1.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.153823 | time=0js
# iter=1 | energy=(-40.25444818125614+0j) | time=1.1354655849863775s
# iter=2 | energy=(-40.2544481812566+0j) | time=1.6850043769809417s
# computing spin correlations: 12.879s
# ZZ=2.8 | h=-1.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.84617 | time=0js
# iter=1 | energy=(-39.95446107179623+0j) | time=1.0528270290233195s
# iter=2 | energy=(-39.9544610717962+0j) | time=1.5940233430010267s
# computing spin correlations: 12.971s
# ZZ=2.8 | h=-1.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.316768 | time=0js
# iter=1 | energy=(-39.65444649148462+0j) | time=1.014744904008694s
# iter=2 | energy=(-39.6544464914851+0j) | time=1.5872747060493566s
# computing spin correlations: 12.771s
# ZZ=2.8 | h=-1.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.467673 | time=0js
# iter=1 | energy=(-39.529049286895074+0j) | time=1.030652410001494s
# iter=2 | energy=(-39.52904928689511+0j) | time=1.5466954149887897s
# computing spin correlations: 12.747s
# ZZ=2.8 | h=-1.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.105209 | time=0js
# iter=1 | energy=(-39.32904628139911+0j) | time=1.053933398972731s
# iter=2 | energy=(-39.329046281398895+0j) | time=1.482800398953259s
# computing spin correlations: 12.368s
# ZZ=2.8 | h=-1.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.193329 | time=0js
# iter=1 | energy=(-39.25998401402781+0j) | time=1.0777949979528785s
# iter=2 | energy=(-39.25998401402779+0j) | time=1.5984636969515122s
# computing spin correlations: 12.701s
# ZZ=2.8 | h=-1.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.918465 | time=0js
# iter=1 | energy=(-39.159913005206064+0j) | time=1.0645439070067368s
# iter=2 | energy=(-39.15991300520617+0j) | time=1.6114726120140404s
# computing spin correlations: 12.608s
# ZZ=2.8 | h=-0.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.600661 | time=0js
# iter=1 | energy=(-38.7026464239189+0j) | time=1.1059390080044977s
# iter=2 | energy=(-38.7026464239189+0j) | time=1.6630402129958384s
# computing spin correlations: 12.399s
# ZZ=2.8 | h=-0.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.612701 | time=0js
# iter=1 | energy=(-38.70264656134458+0j) | time=1.1577300060307607s
# iter=2 | energy=(-38.70264656134421+0j) | time=1.7111074090353213s
# computing spin correlations: 12.546s
# ZZ=2.8 | h=-0.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.622458 | time=0js
# iter=1 | energy=(-38.70264812061624+0j) | time=0.9926265010144562s
# iter=2 | energy=(-38.70264812061628+0j) | time=1.690777401032392s
# computing spin correlations: 12.743s
# ZZ=2.8 | h=-0.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.630588 | time=0js
# iter=1 | energy=(-38.70264892406416+0j) | time=1.023016495979391s
# iter=2 | energy=(-38.70264892406423+0j) | time=1.6701964939711615s
# computing spin correlations: 12.863s
# ZZ=2.8 | h=-0.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.637079 | time=0js
# iter=1 | energy=(-38.702648482157564+0j) | time=1.0101733020273969s
# iter=2 | energy=(-38.702648482157464+0j) | time=1.6283546030172147s
# computing spin correlations: 12.98s
# ZZ=2.8 | h=-0.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.64285 | time=0js
# iter=1 | energy=(-38.70262369986235+0j) | time=0.9234905000193976s
# iter=2 | energy=(-38.702623699862386+0j) | time=1.6050973000237718s
# computing spin correlations: 12.641s
# ZZ=2.8 | h=-0.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.647934 | time=0js
# iter=1 | energy=(-38.702632827942864+0j) | time=0.9412716980441473s
# iter=2 | energy=(-38.702632827942885+0j) | time=1.4124269970925525s
# computing spin correlations: 12.252s
# ZZ=2.8 | h=-0.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.652646 | time=0js
# iter=1 | energy=(-38.70263821735941+0j) | time=0.9089604999753647s
# iter=2 | energy=(-38.70263821735948+0j) | time=1.3823247999534942s
# computing spin correlations: 12.332s
# ZZ=2.8 | h=-0.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.656808 | time=0js
# iter=1 | energy=(-38.702634557146325+0j) | time=0.8241963009932078s
# iter=2 | energy=(-38.7026345571463+0j) | time=1.423078800959047s
# computing spin correlations: 11.89s
# ZZ=2.8 | h=0.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.660685 | time=0js
# iter=1 | energy=(-38.70260997744248+0j) | time=0.7476137009798549s
# iter=2 | energy=(-38.70260997744295+0j) | time=1.3808635009918362s
# computing spin correlations: 12.674s
# ZZ=2.9 | h=-5.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-89.475 | time=0js
# iter=1 | energy=(-89.47499999999964+0j) | time=0.12427730002673343s
# computing spin correlations: 2.107s
# ZZ=2.9 | h=-4.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-86.975 | time=0js
# iter=1 | energy=(-86.97499999999962+0j) | time=0.1135200000135228s
# computing spin correlations: 2.08s
# ZZ=2.9 | h=-4.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-84.475 | time=0js
# iter=1 | energy=(-84.4749999999996+0j) | time=0.1187449999852106s
# computing spin correlations: 2.102s
# ZZ=2.9 | h=-4.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-81.975 | time=0js
# iter=1 | energy=(-81.97499999999975+0j) | time=0.12254899798426777s
# computing spin correlations: 2.108s
# ZZ=2.9 | h=-4.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-79.475 | time=0js
# iter=1 | energy=(-79.47499999999957+0j) | time=0.11835169797996059s
# computing spin correlations: 2.148s
# ZZ=2.9 | h=-4.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-76.975 | time=0js
# iter=1 | energy=(-76.97499999999941+0j) | time=0.12281549698673189s
# computing spin correlations: 2.125s
# ZZ=2.9 | h=-4.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-74.475 | time=0js
# iter=1 | energy=(-74.47499999999962+0j) | time=0.16524040000513196s
# computing spin correlations: 2.093s
# ZZ=2.9 | h=-4.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-71.975 | time=0js
# iter=1 | energy=(-71.97499999999967+0j) | time=0.11415979999583215s
# computing spin correlations: 2.081s
# ZZ=2.9 | h=-4.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-69.475 | time=0js
# iter=1 | energy=(-69.4749999999995+0j) | time=0.11752039898419753s
# computing spin correlations: 2.135s
# ZZ=2.9 | h=-4.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-66.975 | time=0js
# iter=1 | energy=(-66.97499999999943+0j) | time=0.11354949697852135s
# computing spin correlations: 2.069s
# ZZ=2.9 | h=-4.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.475 | time=0js
# iter=1 | energy=(-64.4749999999998+0j) | time=0.11364109697751701s
# computing spin correlations: 2.111s
# ZZ=2.9 | h=-3.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-61.975 | time=0js
# iter=1 | energy=(-61.974999999999696+0j) | time=0.11368939600652084s
# computing spin correlations: 2.115s
# ZZ=2.9 | h=-3.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-59.64577 | time=0js
# iter=1 | energy=(-59.66284348264461+0j) | time=0.5315996810095385s
# iter=2 | energy=(-59.66284348264469+0j) | time=0.7313858739798889s
# computing spin correlations: 6.122s
# ZZ=2.9 | h=-3.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-57.771673 | time=0js
# iter=1 | energy=(-57.849862469369334+0j) | time=1.2683696980238892s
# iter=2 | energy=(-57.84986246936896+0j) | time=1.7142738979891874s
# computing spin correlations: 11.612s
# ZZ=2.9 | h=-3.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-56.105719 | time=0js
# iter=1 | energy=(-56.23865685976348+0j) | time=1.3606423050514422s
# iter=2 | energy=(-56.44274831460568+0j) | time=2.5976500090328045s
# iter=3 | energy=(-56.448572557193785+0j) | time=3.7642748140497133s
# iter=4 | energy=(-56.44886164059792+0j) | time=4.5437127180048265s
# iter=5 | energy=(-56.44886164059843+0j) | time=4.99850502202753s
# computing spin correlations: 12.911s
# ZZ=2.9 | h=-3.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-54.697981 | time=0js
# iter=1 | energy=(-54.849048395802626+0j) | time=1.1423066059942357s
# iter=2 | energy=(-54.849048395801965+0j) | time=1.6755618079914711s
# computing spin correlations: 12.454s
# ZZ=2.9 | h=-3.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.250319 | time=0js
# iter=1 | energy=(-53.46610763147383+0j) | time=1.2061301070498303s
# iter=2 | energy=(-53.61088182872362+0j) | time=2.584437115001492s
# iter=3 | energy=(-53.64416854397835+0j) | time=4.0759318230557255s
# iter=4 | energy=(-53.666032638798555+0j) | time=5.275323530077003s
# iter=5 | energy=(-53.667967501966224+0j) | time=6.382858940109145s
# iter=6 | energy=(-53.667967501966+0j) | time=6.8248530441196635s
# computing spin correlations: 12.714s
# ZZ=2.9 | h=-3.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-51.945831 | time=0js
# iter=1 | energy=(-52.208699539910995+0j) | time=1.1877911100164056s
# iter=2 | energy=(-52.208699539911656+0j) | time=1.707681414030958s
# computing spin correlations: 12.476s
# ZZ=2.9 | h=-3.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-51.11188 | time=0js
# iter=1 | energy=(-51.23144962425101+0j) | time=1.17992200498702s
# iter=2 | energy=(-51.231449624250565+0j) | time=1.6894548069685698s
# computing spin correlations: 12.109s
# ZZ=2.9 | h=-3.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-49.727487 | time=0js
# iter=1 | energy=(-50.03135858519338+0j) | time=1.042510000988841s
# iter=2 | energy=(-50.03135858519258+0j) | time=1.719806000997778s
# computing spin correlations: 12.39s
# ZZ=2.9 | h=-3.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-48.8025 | time=0js
# iter=1 | energy=(-49.085606608689204+0j) | time=1.1364514000015333s
# iter=2 | energy=(-49.08560660868979+0j) | time=1.7907101020100527s
# computing spin correlations: 12.155s
# ZZ=2.9 | h=-2.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-47.99084 | time=0js
# iter=1 | energy=(-48.21673680507886+0j) | time=1.0537682020221837s
# iter=2 | energy=(-48.2167368050788+0j) | time=1.5544550040503964s
# computing spin correlations: 12.564s
# ZZ=2.9 | h=-2.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-47.273434 | time=0js
# iter=1 | energy=(-47.40984388677777+0j) | time=1.1054975030128844s
# iter=2 | energy=(-47.40984388677697+0j) | time=1.6957648050156422s
# computing spin correlations: 12.4s
# ZZ=2.9 | h=-2.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-46.165213 | time=0js
# iter=1 | energy=(-46.509816754454945+0j) | time=1.2083499019499868s
# iter=2 | energy=(-46.509816754455784+0j) | time=1.759977702924516s
# computing spin correlations: 12.838s
# ZZ=2.9 | h=-2.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-45.637422 | time=0js
# iter=1 | energy=(-45.848987630471036+0j) | time=1.689529000024777s
# iter=2 | energy=(-45.84898763047187+0j) | time=2.1773442000267096s
# computing spin correlations: 12.748s
# ZZ=2.9 | h=-2.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-45.142393 | time=0js
# iter=1 | energy=(-45.217390601078435+0j) | time=1.1107628000318073s
# iter=2 | energy=(-45.21739060107856+0j) | time=1.6398427010281011s
# computing spin correlations: 12.987s
# ZZ=2.9 | h=-2.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-44.257426 | time=0js
# iter=1 | energy=(-44.51738064371352+0j) | time=1.017370896995999s
# iter=2 | energy=(-44.51738064371381+0j) | time=1.5491294960374944s
# computing spin correlations: 13.178s
# ZZ=2.9 | h=-2.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-43.91714 | time=0js
# iter=1 | energy=(-43.99743475853232+0j) | time=1.0772928000078537s
# iter=2 | energy=(-43.997434758532336+0j) | time=1.715409099997487s
# computing spin correlations: 12.426s
# ZZ=2.9 | h=-2.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-43.130551 | time=0js
# iter=1 | energy=(-43.39742833949073+0j) | time=1.0688617990235798s
# iter=2 | energy=(-43.39742833949091+0j) | time=1.7066363980411552s
# computing spin correlations: 12.519s
# ZZ=2.9 | h=-2.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-42.899895 | time=0js
# iter=1 | energy=(-42.970986586690906+0j) | time=1.0996049999957904s
# iter=2 | energy=(-42.97098658669065+0j) | time=1.7146185000310652s
# computing spin correlations: 12.257s
# ZZ=2.9 | h=-2.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-42.239912 | time=0js
# iter=1 | energy=(-42.47098573900491+0j) | time=1.2074194999877363s
# iter=2 | energy=(-42.47098573900504+0j) | time=1.8757595009519719s
# computing spin correlations: 12.283s
# ZZ=2.9 | h=-1.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-42.046501 | time=0js
# iter=1 | energy=(-42.119983797414754+0j) | time=1.07429450500058s
# iter=2 | energy=(-42.119983797414626+0j) | time=1.6031673069810495s
# computing spin correlations: 12.306s
# ZZ=2.9 | h=-1.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.557655 | time=0js
# iter=1 | energy=(-41.71998429837744+0j) | time=1.1178482089890167s
# iter=2 | energy=(-41.71998429837757+0j) | time=1.6889157129917294s
# computing spin correlations: 13.667s
# ZZ=2.9 | h=-1.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.914845 | time=0js
# iter=1 | energy=(-41.319972343834465+0j) | time=1.2120744009735063s
# iter=2 | energy=(-41.319972343834515+0j) | time=1.7964440009673126s
# computing spin correlations: 12.803s
# ZZ=2.9 | h=-1.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.042005 | time=0js
# iter=1 | energy=(-41.12799813693655+0j) | time=1.1456157029606402s
# iter=2 | energy=(-41.127998136936476+0j) | time=1.7652516039670445s
# computing spin correlations: 12.675s
# ZZ=2.9 | h=-1.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.539512 | time=0js
# iter=1 | energy=(-40.8279823986708+0j) | time=1.061251300969161s
# iter=2 | energy=(-40.82798239867065+0j) | time=1.586194800969679s
# computing spin correlations: 12.666s
# ZZ=2.9 | h=-1.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.611879 | time=0js
# iter=1 | energy=(-40.68452130452285+0j) | time=1.1470002009882592s
# iter=2 | energy=(-40.684521304522654+0j) | time=1.6733489009784535s
# computing spin correlations: 12.606s
# ZZ=2.9 | h=-1.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.306178 | time=0js
# iter=1 | energy=(-40.484521305860724+0j) | time=1.0058199010090902s
# iter=2 | energy=(-40.48452130586094+0j) | time=1.5258959020138718s
# computing spin correlations: 12.549s
# ZZ=2.9 | h=-1.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.295135 | time=0js
# iter=1 | energy=(-40.399325202766086+0j) | time=1.2478804019629024s
# iter=2 | energy=(-40.39932520276635+0j) | time=1.7629679019446485s
# computing spin correlations: 13.345s
# ZZ=2.9 | h=-1.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.09968 | time=0js
# iter=1 | energy=(-40.29925504792313+0j) | time=1.1707340010325424s
# iter=2 | energy=(-40.29925504792326+0j) | time=1.6809630010393448s
# computing spin correlations: 12.398s
# ZZ=2.9 | h=-1.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.678152 | time=0js
# iter=1 | energy=(-39.78569929325202+0j) | time=1.1367899010074325s
# iter=2 | energy=(-39.7856992932522+0j) | time=1.6652724010054953s
# computing spin correlations: 12.32s
# ZZ=2.9 | h=-0.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.692975 | time=0js
# iter=1 | energy=(-39.78569964075814+0j) | time=1.1429197959951125s
# iter=2 | energy=(-39.78569964075811+0j) | time=1.7026145940180868s
# computing spin correlations: 12.306s
# ZZ=2.9 | h=-0.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.702322 | time=0js
# iter=1 | energy=(-39.7857004094333+0j) | time=1.089748097001575s
# iter=2 | energy=(-39.78570040943318+0j) | time=1.7203856959822588s
# computing spin correlations: 12.299s
# ZZ=2.9 | h=-0.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.710965 | time=0js
# iter=1 | energy=(-39.7857009427969+0j) | time=1.0067478999844752s
# iter=2 | energy=(-39.785700942796865+0j) | time=1.5577305000042543s
# computing spin correlations: 12.564s
# ZZ=2.9 | h=-0.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.717725 | time=0js
# iter=1 | energy=(-39.785701531001244+0j) | time=1.0872546010068618s
# iter=2 | energy=(-39.78570153100111+0j) | time=1.6154452010523528s
# computing spin correlations: 12.123s
# ZZ=2.9 | h=-0.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.72346 | time=0js
# iter=1 | energy=(-39.785680299626364+0j) | time=1.0736982999951579s
# iter=2 | energy=(-39.785680299626506+0j) | time=1.6266386999632232s
# computing spin correlations: 12.258s
# ...
# iter=2 | energy=(-68.23779862456898+0j) | time=1.7222626979928464s
# computing spin correlations: 12.947s
# ZZ=5.0 | h=-4.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-67.065253 | time=0js
# iter=1 | energy=(-67.63778341910863+0j) | time=1.2605930989957415s
# iter=2 | energy=(-67.637783419109+0j) | time=1.8270996990031563s
# computing spin correlations: 13.459s
# ZZ=5.0 | h=-3.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-67.082997 | time=0js
# iter=1 | energy=(-67.3370191672026+0j) | time=1.2875670960056596s
# iter=2 | energy=(-67.33701916720327+0j) | time=1.7675037949811667s
# computing spin correlations: 12.533s
# ZZ=5.0 | h=-3.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-66.372131 | time=0js
# iter=1 | energy=(-66.83698447788292+0j) | time=1.2885785000398755s
# iter=2 | energy=(-66.83698447788315+0j) | time=1.948261600045953s
# computing spin correlations: 12.951s
# ZZ=5.0 | h=-3.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-65.551106 | time=0js
# iter=1 | energy=(-66.337091341832+0j) | time=1.67028450203361s
# iter=2 | energy=(-66.58254224144514+0j) | time=2.8719440040295012s
# iter=3 | energy=(-66.59165258688935+0j) | time=4.243144105013926s
# iter=4 | energy=(-66.59173417934271+0j) | time=4.777151505986694s
# iter=5 | energy=(-66.59173417934258+0j) | time=5.371846106951125s
# computing spin correlations: 12.529s
# ZZ=5.0 | h=-3.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-65.830239 | time=0js
# iter=1 | energy=(-66.1918104309889+0j) | time=1.3551621059887111s
# iter=2 | energy=(-66.19181043098888+0j) | time=1.9902663079556078s
# computing spin correlations: 12.164s
# ZZ=5.0 | h=-3.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-65.093237 | time=0js
# iter=1 | energy=(-65.79174813223445+0j) | time=1.4659799989894964s
# iter=2 | energy=(-65.79174813223408+0j) | time=1.9279349989956245s
# computing spin correlations: 12.482s
# ZZ=5.0 | h=-3.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-65.420019 | time=0js
# iter=1 | energy=(-65.69453875792779+0j) | time=1.4151044000172988s
# iter=2 | energy=(-65.69453875792755+0j) | time=2.0164002010133117s
# computing spin correlations: 13.032s
# ZZ=5.0 | h=-3.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.82938 | time=0js
# iter=1 | energy=(-65.39445020760238+0j) | time=1.6158143000211567s
# iter=2 | energy=(-65.39449665931078+0j) | time=2.1651670000283048s
# iter=3 | energy=(-65.39449665931082+0j) | time=2.592828499036841s
# computing spin correlations: 12.482s
# ZZ=5.0 | h=-3.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-65.110118 | time=0js
# iter=1 | energy=(-65.35222745613599+0j) | time=1.3715062990086153s
# iter=2 | energy=(-65.3522274561352+0j) | time=1.920807498972863s
# computing spin correlations: 13.118s
# ZZ=5.0 | h=-3.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.569694 | time=0js
# iter=1 | energy=(-65.15201384682096+0j) | time=1.5602408000268042s
# iter=2 | energy=(-65.15210725094232+0j) | time=2.0984173000324517s
# iter=3 | energy=(-65.15210725094263+0j) | time=2.666710600082297s
# computing spin correlations: 12.813s
# ZZ=5.0 | h=-3.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.84461 | time=0js
# iter=1 | energy=(-65.19982949421664+0j) | time=1.407577600039076s
# iter=2 | energy=(-65.20080168640398+0j) | time=2.554706000024453s
# iter=3 | energy=(-65.20089691956646+0j) | time=3.1761774999904446s
# iter=4 | energy=(-65.20103985515398+0j) | time=3.9056570999673568s
# iter=5 | energy=(-65.20103985515391+0j) | time=4.353016099950764s
# computing spin correlations: 12.736s
# ZZ=5.0 | h=-2.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.612677 | time=0js
# iter=1 | energy=(-65.09685514745172+0j) | time=1.6369011020287871s
# iter=2 | energy=(-65.0996194906881+0j) | time=2.804752503056079s
# iter=3 | energy=(-65.10063786561004+0j) | time=4.075319504016079s
# iter=4 | energy=(-65.10099995594159+0j) | time=4.921764403989073s
# iter=5 | energy=(-65.1010147616145+0j) | time=5.533278504968621s
# iter=6 | energy=(-65.10101476161455+0j) | time=6.016904204967432s
# computing spin correlations: 12.835s
# ZZ=5.0 | h=-2.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.449045 | time=0js
# iter=1 | energy=(-64.99650758529994+0j) | time=1.6759147080010734s
# iter=2 | energy=(-64.99952681054053+0j) | time=3.0161093089845963s
# iter=3 | energy=(-65.00056150501155+0j) | time=4.092631908948533s
# iter=4 | energy=(-65.0009657158596+0j) | time=5.09025590994861s
# iter=5 | energy=(-65.00099117653438+0j) | time=5.57437421096256s
# iter=6 | energy=(-65.00099117653401+0j) | time=6.110999310971238s
# computing spin correlations: 12.48s
# ZZ=5.0 | h=-2.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.310227 | time=0js
# iter=1 | energy=(-64.89662258404971+0j) | time=1.6540334990131669s
# iter=2 | energy=(-64.89961371888134+0j) | time=3.033341197995469s
# iter=3 | energy=(-64.9006508845461+0j) | time=4.102177788037807s
# iter=4 | energy=(-64.90095621079584+0j) | time=5.07547177298693s
# iter=5 | energy=(-64.90095621079645+0j) | time=5.514862865966279s
# computing spin correlations: 13.223s
# ZZ=5.0 | h=-2.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.18247 | time=0js
# iter=1 | energy=(-64.79747999730016+0j) | time=1.5261726980097592s
# iter=2 | energy=(-64.79996822423061+0j) | time=2.8422020960133523s
# iter=3 | energy=(-64.80078634766014+0j) | time=3.9253823939943686s
# iter=4 | energy=(-64.80099062249512+0j) | time=4.789111792983022s
# iter=5 | energy=(-64.80100271266531+0j) | time=5.3047420919756405s
# iter=6 | energy=(-64.80100271266573+0j) | time=5.732728692004457s
# computing spin correlations: 12.922s
# ZZ=5.0 | h=-2.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.054738 | time=0js
# iter=1 | energy=(-64.69838133732713+0j) | time=1.5670317020267248s
# iter=2 | energy=(-64.70038222159782+0j) | time=2.848200603039004s
# iter=3 | energy=(-64.70092768691087+0j) | time=3.751366404001601s
# iter=4 | energy=(-64.70100928649471+0j) | time=4.417266503965948s
# iter=5 | energy=(-64.70100928649491+0j) | time=4.951059004932176s
# computing spin correlations: 12.695s
# ZZ=5.0 | h=-2.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.932103 | time=0js
# iter=1 | energy=(-64.59664221121007+0j) | time=1.6847401069826446s
# iter=2 | energy=(-64.59955753450802+0j) | time=2.875218707951717s
# iter=3 | energy=(-64.60062516435933+0j) | time=4.062367806909606s
# iter=4 | energy=(-64.60099030200881+0j) | time=4.9299253059434704s
# iter=5 | energy=(-64.60103896492389+0j) | time=5.617462004942354s
# iter=6 | energy=(-64.60103896492365+0j) | time=6.062666204932611s
# computing spin correlations: 12.742s
# ZZ=5.0 | h=-2.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.814486 | time=0js
# iter=1 | energy=(-64.49775513923365+0j) | time=1.5568273980170488s
# iter=2 | energy=(-64.50045905547371+0j) | time=2.920282297010999s
# iter=3 | energy=(-64.50085944568444+0j) | time=3.6885073970188387s
# iter=4 | energy=(-64.50085944568448+0j) | time=4.13878499699058s
# computing spin correlations: 12.562s
# ZZ=5.0 | h=-2.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.696683 | time=0js
# iter=1 | energy=(-63.77349181660906+0j) | time=0.8570204999996349s
# iter=2 | energy=(-63.773491816609145+0j) | time=1.2007201999658719s
# computing spin correlations: 9.792s
# ZZ=5.0 | h=-2.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.704014 | time=0js
# iter=1 | energy=(-63.77349173991377+0j) | time=0.9665258000022732s
# iter=2 | energy=(-63.77349173991451+0j) | time=1.3784242020337842s
# computing spin correlations: 9.838s
# ZZ=5.0 | h=-2.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.708136 | time=0js
# iter=1 | energy=(-63.77349191259735+0j) | time=0.9529832089901902s
# iter=2 | energy=(-63.77349191259715+0j) | time=1.306177211983595s
# computing spin correlations: 9.993s
# ZZ=5.0 | h=-1.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.71179 | time=0js
# iter=1 | energy=(-63.773491862187626+0j) | time=0.9527504019788466s
# iter=2 | energy=(-63.773491862187306+0j) | time=1.2693756030057557s
# computing spin correlations: 9.518s
# ZZ=5.0 | h=-1.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.715612 | time=0js
# iter=1 | energy=(-63.77349195710903+0j) | time=0.8281686000409536s
# iter=2 | energy=(-63.77349195710916+0j) | time=1.262337701045908s
# computing spin correlations: 9.755s
# ZZ=5.0 | h=-1.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.72036 | time=0js
# iter=1 | energy=(-63.77348232207988+0j) | time=0.9700093999854289s
# iter=2 | energy=(-63.773482322080085+0j) | time=1.3068180999835022s
# computing spin correlations: 9.967s
# ZZ=5.0 | h=-1.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.723316 | time=0js
# iter=1 | energy=(-63.77348361845004+0j) | time=0.9853685999987647s
# iter=2 | energy=(-63.77348361845027+0j) | time=1.330438899982255s
# computing spin correlations: 8.834s
# ZZ=5.0 | h=-1.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.725649 | time=0js
# iter=1 | energy=(-63.77348492934353+0j) | time=0.903746800031513s
# iter=2 | energy=(-63.773484929343425+0j) | time=1.198413799982518s
# computing spin correlations: 11.302s
# ZZ=5.0 | h=-1.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.727772 | time=0js
# iter=1 | energy=(-63.77348639690981+0j) | time=0.7620276000234298s
# iter=2 | energy=(-63.77348639690997+0j) | time=1.0907526000519283s
# computing spin correlations: 9.063s
# ZZ=5.0 | h=-1.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.729738 | time=0js
# iter=1 | energy=(-63.773486987437806+0j) | time=0.7827729000127874s
# iter=2 | energy=(-63.77348698743834+0j) | time=1.0929901000345126s
# computing spin correlations: 8.834s
# ZZ=5.0 | h=-1.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.731688 | time=0js
# iter=1 | energy=(-63.773487878829464+0j) | time=0.753221700026188s
# iter=2 | energy=(-63.773487878829336+0j) | time=1.027181300043594s
# computing spin correlations: 8.491s
# ZZ=5.0 | h=-1.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.73339 | time=0js
# iter=1 | energy=(-63.77348892461882+0j) | time=0.6849260989692993s
# iter=2 | energy=(-63.77348892461883+0j) | time=0.9407182979630306s
# computing spin correlations: 8.74s
# ZZ=5.0 | h=-1.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.735056 | time=0js
# iter=1 | energy=(-63.773492363218224+0j) | time=0.7325079989968799s
# iter=2 | energy=(-63.77349236321782+0j) | time=1.0167412990122102s
# computing spin correlations: 8.286s
# ZZ=5.0 | h=-0.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.736691 | time=0js
# iter=1 | energy=(-63.77349239391525+0j) | time=0.711032300023362s
# iter=2 | energy=(-63.77349239391544+0j) | time=1.0387966000125743s
# computing spin correlations: 8.493s
# ZZ=5.0 | h=-0.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.738312 | time=0js
# iter=1 | energy=(-63.773492463004864+0j) | time=0.7092727000126615s
# iter=2 | energy=(-63.773492463004125+0j) | time=1.0875170010258444s
# computing spin correlations: 8.779s
# ZZ=5.0 | h=-0.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.739721 | time=0js
# iter=1 | energy=(-63.77349229013646+0j) | time=0.6907245999900624s
# iter=2 | energy=(-63.773492290136616+0j) | time=1.0692895000101998s
# computing spin correlations: 9.521s
# ZZ=5.0 | h=-0.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.741113 | time=0js
# iter=1 | energy=(-63.77349225086915+0j) | time=0.7655677029979415s
# iter=2 | energy=(-63.773492250868976+0j) | time=1.0535525039886124s
# computing spin correlations: 8.814s
# ZZ=5.0 | h=-0.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.742467 | time=0js
# iter=1 | energy=(-63.773492309976014+0j) | time=0.716897499980405s
# iter=2 | energy=(-63.77349230997581+0j) | time=0.9945559999905527s
# computing spin correlations: 8.318s
# ZZ=5.0 | h=-0.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.743716 | time=0js
# iter=1 | energy=(-63.77348163448864+0j) | time=0.7041954000014812s
# iter=2 | energy=(-63.77348163448926+0j) | time=1.140952400979586s
# computing spin correlations: 8.772s
# ZZ=5.0 | h=-0.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.744959 | time=0js
# iter=1 | energy=(-63.77348711969472+0j) | time=0.6135733000119217s
# iter=2 | energy=(-63.77348711969469+0j) | time=0.8883301999885589s
# computing spin correlations: 8.352s
# ZZ=5.0 | h=-0.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.746043 | time=0js
# iter=1 | energy=(-63.773490443874614+0j) | time=0.6023988999659196s
# iter=2 | energy=(-63.773490443874636+0j) | time=0.8617201999295503s
# computing spin correlations: 8.481s
# ZZ=5.0 | h=-0.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.747172 | time=0js
# iter=1 | energy=(-63.7734761765327+0j) | time=0.5644967000116594s
# iter=2 | energy=(-63.773476176533194+0j) | time=0.8691416989895515s
# computing spin correlations: 8.623s
# ZZ=5.0 | h=0.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.748163 | time=0js
# iter=1 | energy=(-63.77348872576853+0j) | time=0.6541646959958598s
# iter=2 | energy=(-63.7734887257687+0j) | time=1.1243229929823428s
# computing spin correlations: 10.046s
