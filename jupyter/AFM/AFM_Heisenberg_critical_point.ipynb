# %%
import numpy as np
import sys
import itertools as itertools
import time
sys.path.append("..")
sys.path.append("../..")

import matplotlib.pyplot as plt
from python.Heisenberg import *
from python.DMRG import DMRG
from python.Zippers import MPO_to_Hamiltonian, contract_MPS
from python.Canonical_Form import get_Neumann_entropy_from_left_isometry
from python.Backend import Backend
from python.Decomposition import EIGH

# %%
device = "numpy"
# device = "torch"

bk = Backend(device)

NSweep = 20
Krylov_bases = 5  #* 5 is usually enough
Lanczos_cutoff = 1e-2
two_site = True
verbose = True

# %%
import numpy.typing as npt
import pickle
from dataclasses import dataclass, field, asdict, replace
from copy import deepcopy
from typing import Any, Optional
from pathlib import Path


@dataclass
class Params:
    L: int
    XY: float
    ZZ: float
    h: float
    NKeep: int
    NSweep: int
    diag: bool
    Krylov: int
    cutoff: float
    two: bool
    
    def to_log(self) -> str:
        log_dict = asdict(self)
        
        log_dict['XY'] = round(self.XY, 2)
        log_dict['ZZ'] = round(self.ZZ, 2)
        log_dict['h'] = round(self.h, 2)
        log_dict['cutoff'] = round(self.cutoff, 3)
        
        # Filter out keys where the value is None
        filtered_log_dict = {key: log for key, log in log_dict.items() if log is not None}
        
        # Create log string
        return "_".join(
            f"{key}={log}" for key, log in filtered_log_dict.items()
        )

@dataclass
class Results:
    ground_MPS: list[npt.NDArray]
    ground_state_energy: float
    Neumann_entropy: float
    ground_energies: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    spin_z: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    spin_correlations: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    
    
    def to_array(self):
        return replace(
            self, **{field: np.array(getattr(self, field))
            if isinstance(getattr(self, field), list) else getattr(self, field)
            for field in asdict(self)}
        )
        
    def self_destruct(self):
        for field_name in self.__dataclass_fields__:
            field_value = getattr(self, field_name)
            if isinstance(field_value, list):
                field_value.clear()  # Clear list contents
            else:
                setattr(self, field_name, None)  # Set to None if not a list

# %%
n_sites_lists = np.array([2048])
NKeeps = np.array([128])

XY_coupling = 1
magnetic_field = 0

ZZ_coupling_start = 1.77
ZZ_coupling_end = 2
delta_ZZ = 0.01

ZZ_couplings = bk.arange(ZZ_coupling_start, ZZ_coupling_end+delta_ZZ, delta_ZZ)

# %%
for NKeep in NKeeps:
    for n_sites in n_sites_lists:
        for ZZ_coupling in ZZ_couplings:
            
            if verbose:
                print(f"L={n_sites} | ZZ={round(ZZ_coupling,2)}")
            
            Hamiltonian = XXZ_model(
                bk=bk, n_sites=n_sites, ZZ_coupling=ZZ_coupling,
                XY_coupling=XY_coupling, magnetic_field=magnetic_field,
            )
            
            ground_energies, ground_times, ground_MPS = DMRG(
                bk = bk,
                Hamiltonian = Hamiltonian,
                NKeep = NKeep,
                NSweep = NSweep,
                Krylov_bases = Krylov_bases,
                Lanczos_cutoff = Lanczos_cutoff,
                iterative_diag = True,
                two_site = two_site,
                verbose = verbose,
                tol = 1e-6,
            )
            
            param = Params(
                L = n_sites,
                XY = XY_coupling,
                ZZ = ZZ_coupling,
                h = magnetic_field,
                NKeep = NKeep,
                NSweep = NSweep,
                diag = True,
                Krylov = Krylov_bases,
                cutoff = Lanczos_cutoff,
                two = two_site
            )
            
            # dir_name = Path(f"data")
            dir_name = Path(f"{device}/critical_point")
            dir_name.mkdir(parents=True, exist_ok=True)
            
            filename = f"{param.to_log()}"
            ground_state_energy = ground_energies[-1]
            
            if verbose:
                print(f"computing Neumann entropy: ", end="")
                now = time.perf_counter()
            Neumann_entropy = get_Neumann_entropy_from_left_isometry(ground_MPS, bk=bk)
            if verbose:
                print(f"{round(time.perf_counter()-now,3)}s")
            
            result = Results(
                ground_MPS = [],
                ground_state_energy = ground_state_energy,
                ground_energies = ground_energies,
                Neumann_entropy = Neumann_entropy,
                spin_z = [],
                spin_correlations = [],
            )
            
            output: dict[str, Any] = {}
            output.update(asdict(param))
            output.update(asdict(result))
            
            with open(dir_name / f"{filename}.pkl", "wb") as file:
                pickle.dump(output, file)
# Out:
# L=2048 | ZZ=1.77
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1172.2041 | time=0js
# iter=1 | energy=(-1172.2578750229975+0j) | time=116.82559062799555s
# iter=2 | energy=(-1172.2578750226965+0j) | time=206.87493970498326s
# computing Neumann entropy: 19.67s
# L=2048 | ZZ=1.78
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1176.0763 | time=0js
# iter=1 | energy=(-1176.130029460578+0j) | time=104.42157853700337s
# iter=2 | energy=(-1176.130029460631+0j) | time=188.2141026419995s
# computing Neumann entropy: 15.711s
# L=2048 | ZZ=1.79
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1179.9584 | time=0js
# iter=1 | energy=(-1180.0120568130978+0j) | time=117.09129836101783s
# iter=2 | energy=(-1180.0120568130874+0j) | time=200.40470477801864s
# computing Neumann entropy: 18.251s
# L=2048 | ZZ=1.8
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1183.8503 | time=0js
# iter=1 | energy=(-1183.9038782390821+0j) | time=93.80773440099438s
# iter=2 | energy=(-1183.9038782390207+0j) | time=173.73835546101327s
# computing Neumann entropy: 21.553s
# L=2048 | ZZ=1.81
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1187.752 | time=0js
# iter=1 | energy=(-1187.80538345727+0j) | time=99.15880733402446s
# iter=2 | energy=(-1187.8053834570005+0j) | time=172.41410205102875s
# computing Neumann entropy: 14.182s
# L=2048 | ZZ=1.82
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1191.6632 | time=0js
# iter=1 | energy=(-1191.7165749097164+0j) | time=103.56929282602505s
# iter=2 | energy=(-1191.7165749096678+0j) | time=185.38327594302245s
# computing Neumann entropy: 15.926s
# L=2048 | ZZ=1.83
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1195.584 | time=0js
# iter=1 | energy=(-1195.637288361302+0j) | time=101.1265527769865s
# iter=2 | energy=(-1195.637288360716+0j) | time=174.8254604410031s
# computing Neumann entropy: 18.044s
# L=2048 | ZZ=1.84
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1199.5143 | time=0js
# iter=1 | energy=(-1199.567467190463+0j) | time=102.68985877401428s
# iter=2 | energy=(-1199.5674671900629+0j) | time=181.86243192703114s
# computing Neumann entropy: 16.647s
# L=2048 | ZZ=1.85
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1203.454 | time=0js
# iter=1 | energy=(-1203.507028571742+0j) | time=100.34627182298573s
# iter=2 | energy=(-1203.5070285713039+0j) | time=183.32116906598094s
# computing Neumann entropy: 16.301s
# L=2048 | ZZ=1.86
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1207.4029 | time=0js
# iter=1 | energy=(-1207.4558917059421+0j) | time=132.85306001201388s
# iter=2 | energy=(-1207.4558917058869+0j) | time=225.78087081501144s
# computing Neumann entropy: 24.315s
# L=2048 | ZZ=1.87
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1211.3611 | time=0js
# iter=1 | energy=(-1211.4139744699398+0j) | time=117.1641777989862s
# iter=2 | energy=(-1211.4139744699717+0j) | time=205.27225585098495s
# computing Neumann entropy: 21.386s
# L=2048 | ZZ=1.88
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1215.3285 | time=0js
# iter=1 | energy=(-1215.3811786926608+0j) | time=141.63406146099442s
# iter=2 | energy=(-1215.381178692722+0j) | time=240.019177862996s
# computing Neumann entropy: 14.661s
# L=2048 | ZZ=1.89
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1219.3049 | time=0js
# iter=1 | energy=(-1219.3574793724308+0j) | time=158.5036142389872s
# iter=2 | energy=(-1219.3574793722491+0j) | time=251.44660250699962s
# computing Neumann entropy: 14.343s
# L=2048 | ZZ=1.9
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1223.2902 | time=0js
# iter=1 | energy=(-1223.3427360284331+0j) | time=135.4832594349864s
# iter=2 | energy=(-1223.3427360284331+0j) | time=253.72414801898412s
# computing Neumann entropy: 24.572s
# L=2048 | ZZ=1.91
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1227.2845 | time=0js
# iter=1 | energy=(-1227.336889841777+0j) | time=122.12771184198209s
# iter=2 | energy=(-1227.3368898410374+0j) | time=206.56965279899305s
# computing Neumann entropy: 19.105s
# L=2048 | ZZ=1.92
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1231.2876 | time=0js
# iter=1 | energy=(-1231.3398533654977+0j) | time=99.83890601899475s
# iter=2 | energy=(-1231.3398533648656+0j) | time=176.99947893299395s
# computing Neumann entropy: 15.6s
# L=2048 | ZZ=1.93
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1235.2994 | time=0js
# iter=1 | energy=(-1235.3515600098603+0j) | time=118.09777790299268s
# iter=2 | energy=(-1235.3515600097637+0j) | time=224.54693139501614s
# computing Neumann entropy: 12.191s
# L=2048 | ZZ=1.94
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1239.3199 | time=0js
# iter=1 | energy=(-1239.3719141669148+0j) | time=100.58104289698531s
# iter=2 | energy=(-1239.3719141666543+0j) | time=183.53349954399164s
# computing Neumann entropy: 20.56s
# L=2048 | ZZ=1.95
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1243.3489 | time=0js
# iter=1 | energy=(-1243.4008479311894+0j) | time=98.01455081999302s
# iter=2 | energy=(-1243.4008479311212+0j) | time=171.40509963198565s
# computing Neumann entropy: 13.775s
# L=2048 | ZZ=1.96
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1247.3865 | time=0js
# iter=1 | energy=(-1247.438259645147+0j) | time=95.81415761800599s
# iter=2 | energy=(-1247.4382596452717+0j) | time=173.49285249400418s
# computing Neumann entropy: 15.362s
# L=2048 | ZZ=1.97
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1251.4324 | time=0js
# iter=1 | energy=(-1251.4841044393634+0j) | time=118.96613848299603s
# iter=2 | energy=(-1251.484104439354+0j) | time=193.3200861120131s
# computing Neumann entropy: 16.187s
# L=2048 | ZZ=1.98
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1255.4867 | time=0js
# iter=1 | energy=(-1255.5382971447266+0j) | time=110.67466781201074s
# iter=2 | energy=(-1255.5382971446202+0j) | time=172.72159408801235s
# computing Neumann entropy: 11.38s
# L=2048 | ZZ=1.99
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1259.5493 | time=0js
# iter=1 | energy=(-1259.6007357409976+0j) | time=77.53300577201298s
# iter=2 | energy=(-1259.6007357409242+0j) | time=138.74947960299323s
# computing Neumann entropy: 15.553s
# L=2048 | ZZ=2.0
# L=2048 | NKeep=128 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-1263.6201 | time=0js
# iter=1 | energy=(-1263.6713501138488+0j) | time=84.45314262100146s
# iter=2 | energy=(-1263.6713501138343+0j) | time=141.6473111450032s
# computing Neumann entropy: 12.215s
