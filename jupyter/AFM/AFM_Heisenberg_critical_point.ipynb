# %%
import numpy as np
import sys
import itertools as itertools
import time
sys.path.append("..")
sys.path.append("../..")

import matplotlib.pyplot as plt
from python.Heisenberg import *
from python.DMRG import DMRG
from python.Zippers import MPO_to_Hamiltonian, contract_MPS
from python.Canonical_Form import get_Neumann_entropy_from_left_isometry
from python.Backend import Backend
from python.Decomposition import EIGH

# %%
device = "numpy"
# device = "torch"

bk = Backend(device)

NKeep = 50
NSweep = 20
Krylov_bases = 5  #* 5 is usually enough
Lanczos_cutoff = 1e-2
two_site = True
verbose = True

# %%
import numpy.typing as npt
import pickle
from dataclasses import dataclass, field, asdict, replace
from copy import deepcopy
from typing import Any, Optional
from pathlib import Path


@dataclass
class Params:
    L: int
    XY: float
    ZZ: float
    h: float
    NKeep: int
    NSweep: int
    diag: bool
    Krylov: int
    cutoff: float
    two: bool
    
    def to_log(self) -> str:
        log_dict = asdict(self)
        
        log_dict['XY'] = round(self.XY, 2)
        log_dict['ZZ'] = round(self.ZZ, 2)
        log_dict['h'] = round(self.h, 2)
        log_dict['cutoff'] = round(self.cutoff, 3)
        
        # Filter out keys where the value is None
        filtered_log_dict = {key: log for key, log in log_dict.items() if log is not None}
        
        # Create log string
        return "_".join(
            f"{key}={log}" for key, log in filtered_log_dict.items()
        )

@dataclass
class Results:
    ground_MPS: list[npt.NDArray]
    ground_state_energy: float
    Neumann_entropy: float
    ground_energies: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    spin_z: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    spin_correlations: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    
    
    def to_array(self):
        return replace(
            self, **{field: np.array(getattr(self, field))
            if isinstance(getattr(self, field), list) else getattr(self, field)
            for field in asdict(self)}
        )
        
    def self_destruct(self):
        for field_name in self.__dataclass_fields__:
            field_value = getattr(self, field_name)
            if isinstance(field_value, list):
                field_value.clear()  # Clear list contents
            else:
                setattr(self, field_name, None)  # Set to None if not a list

# %%
n_sites_lists = np.array([64, 128, 256, 512, 1024, 2048])

XY_coupling = 1
magnetic_field = 0

ZZ_coupling_start = 0.8
ZZ_coupling_end = 2
delta_ZZ = 0.01

ZZ_couplings = bk.arange(ZZ_coupling_start, ZZ_coupling_end+delta_ZZ, delta_ZZ)

# %%
for it1, n_sites in enumerate(n_sites_lists):
    for it2, ZZ_coupling in enumerate(ZZ_couplings):
        
        if verbose:
            print(f"L={n_sites} | ZZ={round(ZZ_coupling,2)}")
        
        Hamiltonian = XXZ_model(
            bk=bk, n_sites=n_sites, ZZ_coupling=ZZ_coupling,
            XY_coupling=XY_coupling, magnetic_field=magnetic_field,
        )
        
        ground_energies, ground_times, ground_MPS = DMRG(
            bk = bk,
            Hamiltonian = Hamiltonian,
            NKeep = NKeep,
            NSweep = NSweep,
            Krylov_bases = Krylov_bases,
            Lanczos_cutoff = Lanczos_cutoff,
            iterative_diag = True,
            two_site = two_site,
            verbose = verbose,
            tol = 1e-8,
        )
        
        param = Params(
            L = n_sites,
            XY = XY_coupling,
            ZZ = ZZ_coupling,
            h = magnetic_field,
            NKeep = NKeep,
            NSweep = NSweep,
            diag = True,
            Krylov = Krylov_bases,
            cutoff = Lanczos_cutoff,
            two = two_site
        )
        
        # dir_name = Path(f"data")
        dir_name = Path(f"{device}/critical_point")
        dir_name.mkdir(parents=True, exist_ok=True)
        
        filename = f"{param.to_log()}"
        ground_state_energy = ground_energies[-1]
        
        if verbose:
            print(f"computing Neumann entropy: ", end="")
            now = time.perf_counter()
        Neumann_entropy = get_Neumann_entropy_from_left_isometry(ground_MPS, bk=bk)
        if verbose:
            print(f"{round(time.perf_counter()-now,3)}s")
        
        result = Results(
            ground_MPS = [],
            ground_state_energy = ground_state_energy,
            ground_energies = ground_energies,
            Neumann_entropy = Neumann_entropy,
            spin_z = [],
            spin_correlations = [],
        )
        
        output: dict[str, Any] = {}
        output.update(asdict(param))
        output.update(asdict(result))
        
        with open(dir_name / f"{filename}.pkl", "wb") as file:
            pickle.dump(output, file)
# Out:
# L=64 | ZZ=0.8
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.345118 | time=0js
# iter=1 | energy=(-26.353084071376557+0j) | time=1.7569444599976123s
# iter=2 | energy=(-26.353084071376177+0j) | time=3.2408520199969644s
# computing Neumann entropy: 0.638s
# L=64 | ZZ=0.81
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.433574 | time=0js
# iter=1 | energy=(-26.44154602102072+0j) | time=1.678209945999697s
# iter=2 | energy=(-26.441546021020653+0j) | time=3.256147960000817s
# computing Neumann entropy: 0.114s
# L=64 | ZZ=0.82
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.522313 | time=0js
# iter=1 | energy=(-26.530284470224856+0j) | time=1.490148961001978s
# iter=2 | energy=(-26.530284470224583+0j) | time=2.8363578749995213s
# computing Neumann entropy: 0.125s
# L=64 | ZZ=0.83
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.611323 | time=0js
# iter=1 | energy=(-26.61930222406266+0j) | time=1.463072563001333s
# iter=2 | energy=(-26.61930222406302+0j) | time=2.930701356002828s
# computing Neumann entropy: 0.145s
# L=64 | ZZ=0.84
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.700611 | time=0js
# iter=1 | energy=(-26.708597996903656+0j) | time=2.213169052000012s
# iter=2 | energy=(-26.708597996903805+0j) | time=3.4877837340027327s
# computing Neumann entropy: 0.204s
# L=64 | ZZ=0.85
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.790177 | time=0js
# iter=1 | energy=(-26.798171990509925+0j) | time=1.4534677259980526s
# iter=2 | energy=(-26.798171990509786+0j) | time=2.533277881997492s
# computing Neumann entropy: 0.169s
# L=64 | ZZ=0.86
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.88002 | time=0js
# iter=1 | energy=(-26.88802433732483+0j) | time=1.9406259649986168s
# iter=2 | energy=(-26.88802433732522+0j) | time=3.9100555339973653s
# computing Neumann entropy: 0.153s
# L=64 | ZZ=0.87
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.970141 | time=0js
# iter=1 | energy=(-26.978155236428748+0j) | time=2.0568921490012144s
# iter=2 | energy=(-26.978155236428663+0j) | time=3.6362047160037037s
# computing Neumann entropy: 0.146s
# L=64 | ZZ=0.88
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.06054 | time=0js
# iter=1 | energy=(-27.068564759608776+0j) | time=1.5176429240018479s
# iter=2 | energy=(-27.068564759608627+0j) | time=3.577015172002575s
# computing Neumann entropy: 0.136s
# L=64 | ZZ=0.89
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.151217 | time=0js
# iter=1 | energy=(-27.15925336348703+0j) | time=1.798835251996934s
# iter=2 | energy=(-27.159253363487345+0j) | time=2.8847611889977998s
# computing Neumann entropy: 0.127s
# L=64 | ZZ=0.9
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.242167 | time=0js
# iter=1 | energy=(-27.250223689612326+0j) | time=1.6647351319988957s
# iter=2 | energy=(-27.250223689612387+0j) | time=2.9829764499991143s
# computing Neumann entropy: 0.145s
# L=64 | ZZ=0.91
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.333401 | time=0js
# iter=1 | energy=(-27.341470956151724+0j) | time=1.6139588810001442s
# iter=2 | energy=(-27.34147095615173+0j) | time=2.7451207409976632s
# computing Neumann entropy: 0.126s
# L=64 | ZZ=0.92
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.424913 | time=0js
# iter=1 | energy=(-27.432997911320662+0j) | time=1.7813941249987693s
# iter=2 | energy=(-27.43299791132054+0j) | time=2.796852980998665s
# computing Neumann entropy: 0.342s
# L=64 | ZZ=0.93
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.516704 | time=0js
# iter=1 | energy=(-27.52480485271274+0j) | time=1.3875796439970145s
# iter=2 | energy=(-27.52480485271259+0j) | time=2.849956148998899s
# computing Neumann entropy: 0.182s
# L=64 | ZZ=0.94
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.608775 | time=0js
# iter=1 | energy=(-27.616891951184563+0j) | time=1.6517240749999473s
# iter=2 | energy=(-27.616891951184662+0j) | time=5.4992605240004195s
# computing Neumann entropy: 0.165s
# L=64 | ZZ=0.95
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.701124 | time=0js
# iter=1 | energy=(-27.7092597901608+0j) | time=2.0828433629976644s
# iter=2 | energy=(-27.7092597901611+0j) | time=3.3608235729952867s
# computing Neumann entropy: 0.5s
# L=64 | ZZ=0.96
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.793754 | time=0js
# iter=1 | energy=(-27.801908576373023+0j) | time=2.2254300759996113s
# iter=2 | energy=(-27.801908576373172+0j) | time=3.752070333001029s
# computing Neumann entropy: 0.203s
# L=64 | ZZ=0.97
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.886662 | time=0js
# iter=1 | energy=(-27.894840182248057+0j) | time=4.090095947998634s
# iter=2 | energy=(-27.894840182248082+0j) | time=7.680401412999345s
# computing Neumann entropy: 0.233s
# L=64 | ZZ=0.98
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.979851 | time=0js
# iter=1 | energy=(-27.988051958700055+0j) | time=2.766011878000427s
# iter=2 | energy=(-27.988051958699863+0j) | time=4.130581859000813s
# computing Neumann entropy: 0.136s
# L=64 | ZZ=0.99
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.073321 | time=0js
# iter=1 | energy=(-28.081545836879172+0j) | time=5.275823740001215s
# iter=2 | energy=(-28.081545836879528+0j) | time=9.160703567002201s
# computing Neumann entropy: 0.274s
# L=64 | ZZ=1.0
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.167071 | time=0js
# iter=1 | energy=(-28.175344218551423+0j) | time=1.9229792160003853s
# iter=2 | energy=(-28.175344218551203+0j) | time=4.126048748999892s
# computing Neumann entropy: 0.225s
# L=64 | ZZ=1.01
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.261101 | time=0js
# iter=1 | energy=(-28.26940357150503+0j) | time=2.378868310999678s
# iter=2 | energy=(-28.26940357150501+0j) | time=3.527781540000433s
# computing Neumann entropy: 0.246s
# L=64 | ZZ=1.02
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.355413 | time=0js
# iter=1 | energy=(-28.363746294349966+0j) | time=1.9502372959977947s
# iter=2 | energy=(-28.36374629435045+0j) | time=3.1527020149987948s
# computing Neumann entropy: 0.187s
# L=64 | ZZ=1.03
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.450007 | time=0js
# iter=1 | energy=(-28.45837291309079+0j) | time=1.4942739460020675s
# iter=2 | energy=(-28.45837291309072+0j) | time=2.769132500001433s
# computing Neumann entropy: 0.14s
# L=64 | ZZ=1.04
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.544882 | time=0js
# iter=1 | energy=(-28.553283903237393+0j) | time=1.8937751630001003s
# iter=2 | energy=(-28.553283903237737+0j) | time=3.8617066990009334s
# computing Neumann entropy: 0.234s
# L=64 | ZZ=1.05
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.64004 | time=0js
# iter=1 | energy=(-28.648479784674535+0j) | time=1.7820677980016626s
# iter=2 | energy=(-28.648479784674368+0j) | time=3.1937464920010825s
# computing Neumann entropy: 0.154s
# L=64 | ZZ=1.06
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.73548 | time=0js
# iter=1 | energy=(-28.74393943429604+0j) | time=2.055338230999041s
# iter=2 | energy=(-28.743939434296166+0j) | time=3.13070068199886s
# computing Neumann entropy: 0.247s
# L=64 | ZZ=1.07
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.831203 | time=0js
# iter=1 | energy=(-28.839706671519885+0j) | time=1.9155035360017791s
# iter=2 | energy=(-28.83970667152001+0j) | time=3.439083664001373s
# computing Neumann entropy: 0.616s
# L=64 | ZZ=1.08
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.92721 | time=0js
# iter=1 | energy=(-28.935760502092172+0j) | time=1.7137430389993824s
# iter=2 | energy=(-28.935760502092503+0j) | time=3.4793234540011326s
# computing Neumann entropy: 0.237s
# L=64 | ZZ=1.09
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.023501 | time=0js
# iter=1 | energy=(-29.032101539834365+0j) | time=2.3759543359992676s
# iter=2 | energy=(-29.032101539834233+0j) | time=3.6738580229975923s
# computing Neumann entropy: 0.145s
# L=64 | ZZ=1.1
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.120075 | time=0js
# iter=1 | energy=(-29.128730431878168+0j) | time=2.4771225410004263s
# iter=2 | energy=(-29.128730431878374+0j) | time=3.5453900979991886s
# computing Neumann entropy: 0.131s
# L=64 | ZZ=1.11
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.216935 | time=0js
# iter=1 | energy=(-29.225647837075574+0j) | time=1.6269104040002276s
# iter=2 | energy=(-29.225647837075606+0j) | time=3.146892166001635s
# computing Neumann entropy: 0.493s
# L=64 | ZZ=1.12
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.314079 | time=0js
# iter=1 | energy=(-29.322854430136314+0j) | time=1.6324404129991308s
# iter=2 | energy=(-29.322854430136474+0j) | time=3.4529885519987147s
# computing Neumann entropy: 0.192s
# L=64 | ZZ=1.13
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.411509 | time=0js
# iter=1 | energy=(-29.420350934440147+0j) | time=2.142732383999828s
# iter=2 | energy=(-29.420350934440386+0j) | time=3.294132687999081s
# computing Neumann entropy: 0.172s
# L=64 | ZZ=1.14
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.509225 | time=0js
# iter=1 | energy=(-29.518136765725618+0j) | time=1.8919219480012543s
# iter=2 | energy=(-29.518136765725693+0j) | time=3.047349122000014s
# computing Neumann entropy: 0.272s
# L=64 | ZZ=1.15
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.607227 | time=0js
# iter=1 | energy=(-29.61621605605197+0j) | time=2.226616670999647s
# iter=2 | energy=(-29.616216056052245+0j) | time=4.926175707001676s
# computing Neumann entropy: 0.255s
# L=64 | ZZ=1.16
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.705516 | time=0js
# iter=1 | energy=(-29.7145878094155+0j) | time=2.662546668001596s
# iter=2 | energy=(-29.71458780941567+0j) | time=4.993846718003624s
# computing Neumann entropy: 0.114s
# L=64 | ZZ=1.17
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.804093 | time=0js
# iter=1 | energy=(-29.813251855376116+0j) | time=2.5404570669998066s
# iter=2 | energy=(-29.81325185537628+0j) | time=4.585184933999699s
# computing Neumann entropy: 0.314s
# L=64 | ZZ=1.18
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.902957 | time=0js
# iter=1 | energy=(-29.912209654093914+0j) | time=4.147737398001482s
# iter=2 | energy=(-29.912209654093783+0j) | time=6.000199763002456s
# computing Neumann entropy: 0.258s
# L=64 | ZZ=1.19
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.002109 | time=0js
# iter=1 | energy=(-30.011462162874153+0j) | time=4.554986349998217s
# iter=2 | energy=(-30.011462162873887+0j) | time=8.378258277996792s
# computing Neumann entropy: 0.398s
# L=64 | ZZ=1.2
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.101551 | time=0js
# iter=1 | energy=(-30.111010314129896+0j) | time=3.9322069760019076s
# iter=2 | energy=(-30.111010314130297+0j) | time=6.587349886001903s
# computing Neumann entropy: 0.501s
# L=64 | ZZ=1.21
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.201281 | time=0js
# iter=1 | energy=(-30.210855027818518+0j) | time=3.025827887999185s
# iter=2 | energy=(-30.210855027818678+0j) | time=4.582044215996575s
# computing Neumann entropy: 0.655s
# L=64 | ZZ=1.22
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.301301 | time=0js
# iter=1 | energy=(-30.310997271945055+0j) | time=1.5863112629995157s
# iter=2 | energy=(-30.31099727194524+0j) | time=3.4825950310005283s
# computing Neumann entropy: 0.13s
# L=64 | ZZ=1.23
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.401611 | time=0js
# iter=1 | energy=(-30.41143804183424+0j) | time=24.661579780000466s
# iter=2 | energy=(-30.411438041834295+0j) | time=51.45755654399909s
# computing Neumann entropy: 3.607s
# L=64 | ZZ=1.24
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.502212 | time=0js
# iter=1 | energy=(-30.51217836743499+0j) | time=54.82041602599929s
# iter=2 | energy=(-30.512178367435077+0j) | time=56.02372146699781s
# computing Neumann entropy: 0.164s
# L=64 | ZZ=1.25
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.603104 | time=0js
# iter=1 | energy=(-30.613219266367484+0j) | time=2.1545180790017184s
# iter=2 | energy=(-30.613219266367476+0j) | time=3.8960573570002452s
# computing Neumann entropy: 0.497s
# L=64 | ZZ=1.26
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.704287 | time=0js
# iter=1 | energy=(-30.71456197365118+0j) | time=2.5072564410002087s
# iter=2 | energy=(-30.71456197365106+0j) | time=5.015492146001634s
# computing Neumann entropy: 0.179s
# L=64 | ZZ=1.27
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.805762 | time=0js
# iter=1 | energy=(-30.816208127993868+0j) | time=1.4872164279986464s
# iter=2 | energy=(-30.816208127994027+0j) | time=3.198721321998164s
# computing Neumann entropy: 0.306s
# L=64 | ZZ=1.28
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.907529 | time=0js
# iter=1 | energy=(-30.918157326174562+0j) | time=1.6745473520022642s
# iter=2 | energy=(-30.918157326174132+0j) | time=3.704469799002254s
# computing Neumann entropy: 0.138s
# L=64 | ZZ=1.29
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.009589 | time=0js
# iter=1 | energy=(-31.020412882853737+0j) | time=2.280114092001895s
# iter=2 | energy=(-31.02041288285394+0j) | time=3.414741196003888s
# computing Neumann entropy: 0.139s
# L=64 | ZZ=1.3
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.111941 | time=0js
# iter=1 | energy=(-31.122973289031897+0j) | time=2.231916993001505s
# iter=2 | energy=(-31.12297328903191+0j) | time=3.341288137002266s
# computing Neumann entropy: 0.16s
# L=64 | ZZ=1.31
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.214587 | time=0js
# iter=1 | energy=(-31.22584188302966+0j) | time=1.3372333269981027s
# iter=2 | energy=(-31.22584188302921+0j) | time=3.3268542279984104s
# computing Neumann entropy: 0.131s
# L=64 | ZZ=1.32
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.317527 | time=0js
# iter=1 | energy=(-31.329018484708328+0j) | time=1.8657336510004825s
# iter=2 | energy=(-31.329018484708286+0j) | time=3.5731071260015597s
# computing Neumann entropy: 0.174s
# L=64 | ZZ=1.33
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.420761 | time=0js
# iter=1 | energy=(-31.43250498830809+0j) | time=2.235173154000222s
# iter=2 | energy=(-31.43250498830814+0j) | time=3.404879744997743s
# computing Neumann entropy: 0.26s
# L=64 | ZZ=1.34
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.524288 | time=0js
# iter=1 | energy=(-31.53630289814852+0j) | time=2.203291290999914s
# iter=2 | energy=(-31.5363028981484+0j) | time=3.3271730009983003s
# computing Neumann entropy: 0.138s
# L=64 | ZZ=1.35
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.628111 | time=0js
# iter=1 | energy=(-31.640413009152528+0j) | time=1.5081816860001709s
# iter=2 | energy=(-31.640413009152503+0j) | time=2.6175625389987545s
# computing Neumann entropy: 0.787s
# L=64 | ZZ=1.36
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.732227 | time=0js
# iter=1 | energy=(-31.74494452186766+0j) | time=1.496867920999648s
# iter=2 | energy=(-31.74494452186783+0j) | time=3.4765146439967793s
# computing Neumann entropy: 0.149s
# L=64 | ZZ=1.37
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.836639 | time=0js
# iter=1 | energy=(-31.84968846172697+0j) | time=2.3967020390009566s
# iter=2 | energy=(-31.849688461727144+0j) | time=4.21454106300007s
# computing Neumann entropy: 0.146s
# L=64 | ZZ=1.38
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.941346 | time=0js
# iter=1 | energy=(-31.954748272721062+0j) | time=1.640930681998725s
# iter=2 | energy=(-31.954748272720742+0j) | time=3.0641248669999186s
# computing Neumann entropy: 0.645s
# L=64 | ZZ=1.39
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.046349 | time=0js
# iter=1 | energy=(-32.06012799938033+0j) | time=2.2966580419997626s
# iter=2 | energy=(-32.06012799938048+0j) | time=4.0655520250002155s
# computing Neumann entropy: 0.152s
# L=64 | ZZ=1.4
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.151646 | time=0js
# iter=1 | energy=(-32.165826013045134+0j) | time=1.5357803810002224s
# iter=2 | energy=(-32.1658260130452+0j) | time=2.714544892001868s
# computing Neumann entropy: 0.168s
# L=64 | ZZ=1.41
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.25724 | time=0js
# iter=1 | energy=(-32.27184480439871+0j) | time=1.5036521149995679s
# iter=2 | energy=(-32.27184480439887+0j) | time=2.93094082099924s
# computing Neumann entropy: 0.618s
# L=64 | ZZ=1.42
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.36313 | time=0js
# iter=1 | energy=(-32.37818594777744+0j) | time=1.7431076230022882s
# iter=2 | energy=(-32.378185947777325+0j) | time=3.6171427210028924s
# computing Neumann entropy: 0.171s
# L=64 | ZZ=1.43
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.469316 | time=0js
# iter=1 | energy=(-32.48485044485126+0j) | time=2.4456182190006075s
# iter=2 | energy=(-32.48485044485149+0j) | time=3.622902831000829s
# computing Neumann entropy: 0.126s
# L=64 | ZZ=1.44
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.575799 | time=0js
# iter=1 | energy=(-32.591840733803224+0j) | time=2.104629081000894s
# iter=2 | energy=(-32.59184073380319+0j) | time=3.332500254000479s
# computing Neumann entropy: 0.158s
# L=64 | ZZ=1.45
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.682578 | time=0js
# iter=1 | energy=(-32.699156826114205+0j) | time=1.4626386460004142s
# iter=2 | energy=(-32.699156826114184+0j) | time=2.627059354002995s
# computing Neumann entropy: 0.134s
# L=64 | ZZ=1.46
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.789656 | time=0js
# iter=1 | energy=(-32.80680089180712+0j) | time=1.3756144190010673s
# iter=2 | energy=(-32.806800891807114+0j) | time=3.154476056999556s
# computing Neumann entropy: 0.336s
# L=64 | ZZ=1.47
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.897031 | time=0js
# iter=1 | energy=(-32.91477269139513+0j) | time=1.5799857709971548s
# iter=2 | energy=(-32.9147726913949+0j) | time=3.334537292997993s
# computing Neumann entropy: 0.154s
# L=64 | ZZ=1.48
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.004705 | time=0js
# iter=1 | energy=(-33.023074950409836+0j) | time=2.265143985998293s
# iter=2 | energy=(-33.02307495040951+0j) | time=3.415054840999801s
# computing Neumann entropy: 0.255s
# L=64 | ZZ=1.49
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.112679 | time=0js
# iter=1 | energy=(-33.13170775869075+0j) | time=2.7709261029995105s
# iter=2 | energy=(-33.13170775869123+0j) | time=3.957147351997264s
# computing Neumann entropy: 0.263s
# L=64 | ZZ=1.5
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.220953 | time=0js
# iter=1 | energy=(-33.24067268555736+0j) | time=1.4356008149989066s
# iter=2 | energy=(-33.24067268555747+0j) | time=3.322136287999456s
# computing Neumann entropy: 0.274s
# L=64 | ZZ=1.51
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.32953 | time=0js
# iter=1 | energy=(-33.34997074096576+0j) | time=2.3013827799986757s
# iter=2 | energy=(-33.34997074096543+0j) | time=3.404113652999513s
# computing Neumann entropy: 0.35s
# L=64 | ZZ=1.52
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.43841 | time=0js
# iter=1 | energy=(-33.45960492870449+0j) | time=2.2481402909979806s
# iter=2 | energy=(-33.45960492870503+0j) | time=3.494688219998352s
# computing Neumann entropy: 0.134s
# L=64 | ZZ=1.53
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.547595 | time=0js
# iter=1 | energy=(-33.5695723621733+0j) | time=1.7679592870008491s
# iter=2 | energy=(-33.56957236217326+0j) | time=2.9860891409989563s
# computing Neumann entropy: 0.152s
# L=64 | ZZ=1.54
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.657088 | time=0js
# iter=1 | energy=(-33.67987510786949+0j) | time=1.5443831109987514s
# iter=2 | energy=(-33.67987510786969+0j) | time=2.9915362629981246s
# computing Neumann entropy: 0.712s
# L=64 | ZZ=1.55
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.766889 | time=0js
# iter=1 | energy=(-33.79051417278367+0j) | time=1.576331364998623s
# iter=2 | energy=(-33.790514172783375+0j) | time=3.669616582999879s
# computing Neumann entropy: 0.134s
# L=64 | ZZ=1.56
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.877002 | time=0js
# iter=1 | energy=(-33.90149151347567+0j) | time=1.7549084590027633s
# iter=2 | energy=(-33.901491513475804+0j) | time=2.997029233003559s
# computing Neumann entropy: 0.136s
# L=64 | ZZ=1.57
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.98743 | time=0js
# iter=1 | energy=(-34.01284616544484+0j) | time=1.662875548001466s
# iter=2 | energy=(-34.01284616544513+0j) | time=2.833269046001078s
# computing Neumann entropy: 0.143s
# L=64 | ZZ=1.58
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.098174 | time=0js
# iter=1 | energy=(-34.12449802930183+0j) | time=1.7503110399993602s
# iter=2 | energy=(-34.12449802930226+0j) | time=3.8165268510019814s
# computing Neumann entropy: 0.126s
# L=64 | ZZ=1.59
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.209239 | time=0js
# iter=1 | energy=(-34.23648495004021+0j) | time=1.6394088970009761s
# iter=2 | energy=(-34.23648495004028+0j) | time=3.556619127000886s
# computing Neumann entropy: 0.154s
# L=64 | ZZ=1.6
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.320626 | time=0js
# iter=1 | energy=(-34.34881183099098+0j) | time=2.201316880997183s
# iter=2 | energy=(-34.348811830990954+0j) | time=3.3172519679974357s
# computing Neumann entropy: 0.151s
# L=64 | ZZ=1.61
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.432339 | time=0js
# iter=1 | energy=(-34.461477258002446+0j) | time=2.820721277999837s
# iter=2 | energy=(-34.46147725800242+0j) | time=3.9749409979995107s
# computing Neumann entropy: 0.131s
# L=64 | ZZ=1.62
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.544382 | time=0js
# iter=1 | energy=(-34.574480513629496+0j) | time=2.8300322009999945s
# iter=2 | energy=(-34.57448051362954+0j) | time=4.29556472799959s
# computing Neumann entropy: 0.249s
# L=64 | ZZ=1.63
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.656757 | time=0js
# iter=1 | energy=(-34.68781903908032+0j) | time=2.2438535219989717s
# iter=2 | energy=(-34.687819039080466+0j) | time=3.4562205510010244s
# computing Neumann entropy: 0.162s
# L=64 | ZZ=1.64
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.769468 | time=0js
# iter=1 | energy=(-34.80149546831547+0j) | time=2.132439240001986s
# iter=2 | energy=(-34.80149546831541+0j) | time=3.264855899000395s
# computing Neumann entropy: 0.287s
# L=64 | ZZ=1.65
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.882518 | time=0js
# iter=1 | energy=(-34.91550610907227+0j) | time=1.6725868450012058s
# iter=2 | energy=(-34.91550610907244+0j) | time=3.66770886300219s
# computing Neumann entropy: 0.239s
# L=64 | ZZ=1.66
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.995908 | time=0js
# iter=1 | energy=(-35.02985115792006+0j) | time=2.4035484880005242s
# iter=2 | energy=(-35.029851157920106+0j) | time=3.3989048469993577s
# computing Neumann entropy: 0.259s
# L=64 | ZZ=1.67
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.109644 | time=0js
# iter=1 | energy=(-35.144532458252456+0j) | time=2.541203280001355s
# iter=2 | energy=(-35.144532458252726+0j) | time=3.8008623870009615s
# computing Neumann entropy: 0.138s
# L=64 | ZZ=1.68
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.223727 | time=0js
# iter=1 | energy=(-35.25954510027297+0j) | time=1.5728526720013178s
# iter=2 | energy=(-35.25954510027273+0j) | time=3.060484870999062s
# computing Neumann entropy: 0.801s
# L=64 | ZZ=1.69
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.338158 | time=0js
# iter=1 | energy=(-35.37488853754623+0j) | time=1.702039504001732s
# iter=2 | energy=(-35.37488853754658+0j) | time=3.589460187999066s
# computing Neumann entropy: 0.141s
# L=64 | ZZ=1.7
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.45294 | time=0js
# iter=1 | energy=(-35.49056141155974+0j) | time=2.302291684998636s
# iter=2 | energy=(-35.49056141155998+0j) | time=3.4792510489969573s
# computing Neumann entropy: 0.135s
# L=64 | ZZ=1.71
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.568074 | time=0js
# iter=1 | energy=(-35.606562472312085+0j) | time=2.1855991580014233s
# iter=2 | energy=(-35.606562472311836+0j) | time=3.3421168360036972s
# computing Neumann entropy: 0.133s
# L=64 | ZZ=1.72
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.683561 | time=0js
# iter=1 | energy=(-35.72289282589098+0j) | time=2.0241961700012325s
# iter=2 | energy=(-35.722892825890796+0j) | time=3.1563317340005597s
# computing Neumann entropy: 0.274s
# L=64 | ZZ=1.73
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.7994 | time=0js
# iter=1 | energy=(-35.83953415699693+0j) | time=1.628817845001322s
# iter=2 | energy=(-35.83953415699699+0j) | time=3.607678468000813s
# computing Neumann entropy: 0.134s
# L=64 | ZZ=1.74
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.915592 | time=0js
# iter=1 | energy=(-35.95650859871658+0j) | time=2.7290817840003s
# iter=2 | energy=(-35.95650859871661+0j) | time=4.193162933999702s
# computing Neumann entropy: 0.139s
# L=64 | ZZ=1.75
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-36.032136 | time=0js
# iter=1 | energy=(-36.07380355937718+0j) | time=2.7545466700030374s
# iter=2 | energy=(-36.07380355937735+0j) | time=5.392295266003202s
# computing Neumann entropy: 0.186s
# L=64 | ZZ=1.76
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-36.14903 | time=0js
# iter=1 | energy=(-36.191417217331164+0j) | time=2.5503732680008397s
# iter=2 | energy=(-36.19141721733114+0j) | time=3.971139351000602s
# computing Neumann entropy: 0.166s
# L=64 | ZZ=1.77
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-36.266277 | time=0js
# iter=1 | energy=(-36.30934704799769+0j) | time=2.4592143110021425s
# iter=2 | energy=(-36.30934704799745+0j) | time=3.5177298710041214s
# computing Neumann entropy: 0.128s
# L=64 | ZZ=1.78
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-36.383872 | time=0js
# iter=1 | energy=(-36.42759097776471+0j) | time=1.827869456999906s
# iter=2 | energy=(-36.42759097776505+0j) | time=4.1673544790028245s
# computing Neumann entropy: 0.133s
# L=64 | ZZ=1.79
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-36.501812 | time=0js
# iter=1 | energy=(-36.54614721056459+0j) | time=1.8520408510012203s
# iter=2 | energy=(-36.5461472105647+0j) | time=3.6700330790008593s
# computing Neumann entropy: 0.255s
# L=64 | ZZ=1.8
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-36.620099 | time=0js
# iter=1 | energy=(-36.6650132628736+0j) | time=2.364740586002881s
# iter=2 | energy=(-36.66501326287356+0j) | time=3.3829414720021305s
# computing Neumann entropy: 0.147s
# L=64 | ZZ=1.81
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-36.738726 | time=0js
# iter=1 | energy=(-36.784185287696985+0j) | time=2.2503691849997267s
# iter=2 | energy=(-36.78418528769697+0j) | time=3.2813860480018775s
# computing Neumann entropy: 0.13s
# L=64 | ZZ=1.82
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-36.857694 | time=0js
# iter=1 | energy=(-36.90366145456916+0j) | time=1.84045352099929s
# iter=2 | energy=(-36.9036614545693+0j) | time=2.9859811829992395s
# computing Neumann entropy: 0.143s
# L=64 | ZZ=1.83
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-36.976998 | time=0js
# iter=1 | energy=(-37.0234413555367+0j) | time=1.729169741000078s
# iter=2 | energy=(-37.02344135553636+0j) | time=3.6194221310033754s
# computing Neumann entropy: 0.156s
# L=64 | ZZ=1.84
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.096636 | time=0js
# iter=1 | energy=(-37.143518195916215+0j) | time=1.7314609399982146s
# iter=2 | energy=(-37.14351819591595+0j) | time=4.042243932999554s
# computing Neumann entropy: 0.137s
# L=64 | ZZ=1.85
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.216599 | time=0js
# iter=1 | energy=(-37.26389137537337+0j) | time=2.340621294999437s
# iter=2 | energy=(-37.263891375373525+0j) | time=3.374051464998047s
# computing Neumann entropy: 0.192s
# L=64 | ZZ=1.86
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.336893 | time=0js
# iter=1 | energy=(-37.38455907111044+0j) | time=1.7335611149974284s
# iter=2 | energy=(-37.384559071110345+0j) | time=2.8259136399974523s
# computing Neumann entropy: 0.914s
# L=64 | ZZ=1.87
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.457506 | time=0js
# iter=1 | energy=(-37.505517288411056+0j) | time=2.3783684429981804s
# iter=2 | energy=(-37.505517288411205+0j) | time=3.780054694998398s
# computing Neumann entropy: 0.157s
# L=64 | ZZ=1.88
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.578436 | time=0js
# iter=1 | energy=(-37.626764224688486+0j) | time=2.3812949469975138s
# iter=2 | energy=(-37.626764224688756+0j) | time=3.405897617998562s
# computing Neumann entropy: 0.132s
# L=64 | ZZ=1.89
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.699684 | time=0js
# iter=1 | energy=(-37.74829541568559+0j) | time=2.505388434001361s
# iter=2 | energy=(-37.74829541568543+0j) | time=3.6228503020029166s
# computing Neumann entropy: 0.13s
# L=64 | ZZ=1.9
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.821241 | time=0js
# iter=1 | energy=(-37.87011147985267+0j) | time=1.7255715600003896s
# iter=2 | energy=(-37.87011147985292+0j) | time=4.0663721170021745s
# computing Neumann entropy: 0.146s
# L=64 | ZZ=1.91
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.943103 | time=0js
# iter=1 | energy=(-37.99220845469199+0j) | time=3.653761558001861s
# iter=2 | energy=(-37.99220845469184+0j) | time=4.925631925001653s
# computing Neumann entropy: 0.137s
# L=64 | ZZ=1.92
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.065273 | time=0js
# iter=1 | energy=(-38.114583597236226+0j) | time=1.5614818049980386s
# iter=2 | energy=(-38.11458359723572+0j) | time=3.5519131739965815s
# computing Neumann entropy: 0.136s
# L=64 | ZZ=1.93
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.187736 | time=0js
# iter=1 | energy=(-38.23723380022423+0j) | time=2.73160573000132s
# iter=2 | energy=(-38.23723380022431+0j) | time=3.791217834001145s
# computing Neumann entropy: 0.279s
# L=64 | ZZ=1.94
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.310513 | time=0js
# iter=1 | energy=(-38.360156629792016+0j) | time=2.195611719002045s
# iter=2 | energy=(-38.36015662979217+0j) | time=3.285948238000856s
# computing Neumann entropy: 0.128s
# L=64 | ZZ=1.95
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.433583 | time=0js
# iter=1 | energy=(-38.48334977848147+0j) | time=2.0831473110010847s
# iter=2 | energy=(-38.483349778481326+0j) | time=3.223932897002669s
# computing Neumann entropy: 0.161s
# L=64 | ZZ=1.96
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.556925 | time=0js
# iter=1 | energy=(-38.60681061605506+0j) | time=1.5776414729989483s
# iter=2 | energy=(-38.606810616054766+0j) | time=3.619781907000288s
# computing Neumann entropy: 0.192s
# L=64 | ZZ=1.97
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.68055 | time=0js
# iter=1 | energy=(-38.73053558348286+0j) | time=2.3875442290009232s
# iter=2 | energy=(-38.730535583482094+0j) | time=3.4087075159986853s
# computing Neumann entropy: 0.165s
# L=64 | ZZ=1.98
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.80445 | time=0js
# iter=1 | energy=(-38.85452339434103+0j) | time=2.2947305050001887s
# iter=2 | energy=(-38.8545233943406+0j) | time=3.5772055699999328s
# computing Neumann entropy: 0.152s
# L=64 | ZZ=1.99
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.928626 | time=0js
# iter=1 | energy=(-38.97877082228694+0j) | time=2.006459754000389s
# iter=2 | energy=(-38.9787708222865+0j) | time=3.915436284001771s
# computing Neumann entropy: 0.143s
# L=64 | ZZ=2.0
# L=64 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.053084 | time=0js
# iter=1 | energy=(-39.103275671227664+0j) | time=2.0816064960017684s
# iter=2 | energy=(-39.10327567122779+0j) | time=3.6442361190020165s
# computing Neumann entropy: 0.141s
# L=128 | ZZ=0.8
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-52.87102 | time=0js
# iter=1 | energy=(-52.88141772204695+0j) | time=3.7498667770014436s
# iter=2 | energy=(-52.881417722048255+0j) | time=6.920988139001565s
# computing Neumann entropy: 0.341s
# L=128 | ZZ=0.81
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.048272 | time=0js
# iter=1 | energy=(-53.058683421281984+0j) | time=3.22027026700016s
# iter=2 | energy=(-53.05868342128135+0j) | time=5.727725609998743s
# computing Neumann entropy: 0.773s
# L=128 | ZZ=0.82
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.226099 | time=0js
# iter=1 | energy=(-53.23650658672776+0j) | time=3.323482731000695s
# iter=2 | energy=(-53.23650658672786+0j) | time=6.267894173000968s
# computing Neumann entropy: 0.697s
# L=128 | ZZ=0.83
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.404487 | time=0js
# iter=1 | energy=(-53.41490326328716+0j) | time=3.968232284998521s
# iter=2 | energy=(-53.414903263287265+0j) | time=7.794902107998496s
# computing Neumann entropy: 0.334s
# L=128 | ZZ=0.84
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.583442 | time=0js
# iter=1 | energy=(-53.59386712233651+0j) | time=2.536461187999521s
# iter=2 | energy=(-53.5938671223369+0j) | time=5.811683201998676s
# computing Neumann entropy: 0.703s
# L=128 | ZZ=0.85
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.762966 | time=0js
# iter=1 | energy=(-53.773398807134754+0j) | time=3.353701076001016s
# iter=2 | energy=(-53.77339880713549+0j) | time=5.7425798709991795s
# computing Neumann entropy: 0.436s
# L=128 | ZZ=0.86
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.943059 | time=0js
# iter=1 | energy=(-53.95350272869506+0j) | time=3.0785874630018952s
# iter=2 | energy=(-53.95350272869639+0j) | time=6.104647268999543s
# computing Neumann entropy: 0.359s
# L=128 | ZZ=0.87
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-54.123722 | time=0js
# iter=1 | energy=(-54.13417526757355+0j) | time=3.3479738239984727s
# iter=2 | energy=(-54.134175267572516+0j) | time=6.6544208170016645s
# computing Neumann entropy: 0.432s
# L=128 | ZZ=0.88
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-54.304955 | time=0js
# iter=1 | energy=(-54.31542662754677+0j) | time=2.45984154100006s
# iter=2 | energy=(-54.315426627547694+0j) | time=5.875866495000082s
# computing Neumann entropy: 0.901s
# L=128 | ZZ=0.89
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-54.486758 | time=0js
# iter=1 | energy=(-54.49724850246351+0j) | time=2.8749347750017478s
# iter=2 | energy=(-54.497248502463606+0j) | time=8.791921360003471s
# computing Neumann entropy: 2.259s
# L=128 | ZZ=0.9
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-54.669126 | time=0js
# iter=1 | energy=(-54.67963761899219+0j) | time=3.665598907999083s
# iter=2 | energy=(-54.679637618992075+0j) | time=7.126065042997652s
# computing Neumann entropy: 1.038s
# L=128 | ZZ=0.91
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-54.852072 | time=0js
# iter=1 | energy=(-54.86259980436451+0j) | time=3.574054573000467s
# iter=2 | energy=(-54.86259980436505+0j) | time=7.080516236001131s
# computing Neumann entropy: 0.695s
# L=128 | ZZ=0.92
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-55.035591 | time=0js
# iter=1 | energy=(-55.04613571599906+0j) | time=3.4654848350000975s
# iter=2 | energy=(-55.046135715998304+0j) | time=7.06407905100059s
# computing Neumann entropy: 0.394s
# L=128 | ZZ=0.93
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-55.219682 | time=0js
# iter=1 | energy=(-55.230246178671+0j) | time=2.6450566519997665s
# iter=2 | energy=(-55.230246178670114+0j) | time=5.9963812550013245s
# computing Neumann entropy: 0.384s
# L=128 | ZZ=0.94
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-55.404347 | time=0js
# iter=1 | energy=(-55.414932023374+0j) | time=3.295128558002034s
# iter=2 | energy=(-55.41493202337426+0j) | time=6.476384959001734s
# computing Neumann entropy: 0.5s
# L=128 | ZZ=0.95
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-55.589587 | time=0js
# iter=1 | energy=(-55.600194241390696+0j) | time=3.3963697250001132s
# iter=2 | energy=(-55.60019424139146+0j) | time=6.710076060000574s
# computing Neumann entropy: 0.568s
# L=128 | ZZ=0.96
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-55.775402 | time=0js
# iter=1 | energy=(-55.78605565978653+0j) | time=3.4376992840007006s
# iter=2 | energy=(-55.786055659787394+0j) | time=6.720444287002465s
# computing Neumann entropy: 0.38s
# L=128 | ZZ=0.97
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-55.961793 | time=0js
# iter=1 | energy=(-55.97247355347835+0j) | time=3.6101015099993674s
# iter=2 | energy=(-55.97247355347808+0j) | time=7.539820883001084s
# computing Neumann entropy: 0.366s
# L=128 | ZZ=0.98
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-56.148762 | time=0js
# iter=1 | energy=(-56.159607292509286+0j) | time=3.4191436900000554s
# iter=2 | energy=(-56.15960729251038+0j) | time=6.6137227850013005s
# computing Neumann entropy: 0.464s
# L=128 | ZZ=0.99
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-56.336308 | time=0js
# iter=1 | energy=(-56.34718635513627+0j) | time=3.5185415760024625s
# iter=2 | energy=(-56.34718635513664+0j) | time=6.814972236999893s
# computing Neumann entropy: 0.368s
# L=128 | ZZ=1.0
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-56.524433 | time=0js
# iter=1 | energy=(-56.53534749272603+0j) | time=3.7850342109995836s
# iter=2 | energy=(-56.5353474927268+0j) | time=7.022910732001037s
# computing Neumann entropy: 0.386s
# L=128 | ZZ=1.01
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-56.713138 | time=0js
# iter=1 | energy=(-56.72409033249219+0j) | time=3.239133568997204s
# iter=2 | energy=(-56.7240903324917+0j) | time=6.928705246995378s
# computing Neumann entropy: 0.349s
# L=128 | ZZ=1.02
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-56.902423 | time=0js
# iter=1 | energy=(-56.91342097638648+0j) | time=3.444847816001129s
# iter=2 | energy=(-56.91342097638623+0j) | time=6.630095406002511s
# computing Neumann entropy: 0.426s
# L=128 | ZZ=1.03
# L=128 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-57.092291 | time=0js
# iter=1 | energy=(-57.103333676155415+0j) | time=3.5636789329983003s
# ...
# computing Neumann entropy: 5.886s
# L=1024 | ZZ=1.26
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-494.55264 | time=0js
# iter=1 | energy=(-494.5816636460356+0j) | time=31.797844832999544s
# iter=2 | energy=(-494.58166364602437+0j) | time=64.43057315999613s
# computing Neumann entropy: 4.67s
# L=1024 | ZZ=1.27
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-496.19621 | time=0js
# iter=1 | energy=(-496.2290031278876+0j) | time=31.19476880900038s
# iter=2 | energy=(-496.22900312787056+0j) | time=60.83119072300178s
# computing Neumann entropy: 4.895s
# L=1024 | ZZ=1.28
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-497.84506 | time=0js
# iter=1 | energy=(-497.88198435601106+0j) | time=32.244983898999635s
# iter=2 | energy=(-497.8819843560216+0j) | time=62.224800549000065s
# computing Neumann entropy: 4.689s
# L=1024 | ZZ=1.29
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-499.49987 | time=0js
# iter=1 | energy=(-499.540717777595+0j) | time=29.717930275997787s
# iter=2 | energy=(-499.54071777759555+0j) | time=90.59729980499469s
# computing Neumann entropy: 29.392s
# L=1024 | ZZ=1.3
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-501.16103 | time=0js
# iter=1 | energy=(-501.2053629005827+0j) | time=36.09134971300227s
# iter=2 | energy=(-501.2053629006018+0j) | time=64.64271981500497s
# computing Neumann entropy: 4.314s
# L=1024 | ZZ=1.31
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-502.82874 | time=0js
# iter=1 | energy=(-502.87565340891575+0j) | time=41.87941857700207s
# iter=2 | energy=(-502.87565340889415+0j) | time=70.848378005001s
# computing Neumann entropy: 4.852s
# L=1024 | ZZ=1.32
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-504.50296 | time=0js
# iter=1 | energy=(-504.55177584638045+0j) | time=29.68125086699729s
# iter=2 | energy=(-504.5517758463669+0j) | time=61.132233810996695s
# computing Neumann entropy: 3.386s
# L=1024 | ZZ=1.33
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-506.18358 | time=0js
# iter=1 | energy=(-506.23372232439476+0j) | time=29.775374353004736s
# iter=2 | energy=(-506.2337223244011+0j) | time=59.2433936410016s
# computing Neumann entropy: 4.798s
# L=1024 | ZZ=1.34
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-507.87042 | time=0js
# iter=1 | energy=(-507.9215449959834+0j) | time=30.4302737370017s
# iter=2 | energy=(-507.92154499596074+0j) | time=59.89955284700409s
# computing Neumann entropy: 4.545s
# L=1024 | ZZ=1.35
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-509.5634 | time=0js
# iter=1 | energy=(-509.6152272693948+0j) | time=32.08846388699749s
# iter=2 | energy=(-509.6152272694011+0j) | time=60.43923738399462s
# computing Neumann entropy: 4.556s
# L=1024 | ZZ=1.36
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-511.26223 | time=0js
# iter=1 | energy=(-511.31524434018576+0j) | time=33.934256665997964s
# iter=2 | energy=(-511.3152443401898+0j) | time=62.73256389499875s
# computing Neumann entropy: 5.135s
# L=1024 | ZZ=1.37
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-512.9673 | time=0js
# iter=1 | energy=(-513.0206213371085+0j) | time=28.213302217998717s
# iter=2 | energy=(-513.0206213370982+0j) | time=63.04765020500054s
# computing Neumann entropy: 4.546s
# L=1024 | ZZ=1.38
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-514.67825 | time=0js
# iter=1 | energy=(-514.7318471060178+0j) | time=28.731864321998728s
# iter=2 | energy=(-514.7318471060262+0j) | time=59.29748805199779s
# computing Neumann entropy: 4.513s
# L=1024 | ZZ=1.39
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-516.39512 | time=0js
# iter=1 | energy=(-516.4489568914847+0j) | time=31.689751072000945s
# iter=2 | energy=(-516.448956891494+0j) | time=62.851504430000205s
# computing Neumann entropy: 3.737s
# L=1024 | ZZ=1.4
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-518.11791 | time=0js
# iter=1 | energy=(-518.1719695432614+0j) | time=29.750480050999613s
# iter=2 | energy=(-518.1719695432394+0j) | time=67.19699090699578s
# computing Neumann entropy: 5.126s
# L=1024 | ZZ=1.41
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-519.84658 | time=0js
# iter=1 | energy=(-519.9008749405036+0j) | time=30.556983955997566s
# iter=2 | energy=(-519.9008749404956+0j) | time=60.34465019399795s
# computing Neumann entropy: 4.53s
# L=1024 | ZZ=1.42
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-521.58116 | time=0js
# iter=1 | energy=(-521.6356258033378+0j) | time=29.032160328999453s
# iter=2 | energy=(-521.6356258033496+0j) | time=58.17194542499783s
# computing Neumann entropy: 4.2s
# L=1024 | ZZ=1.43
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-523.32162 | time=0js
# iter=1 | energy=(-523.3763282266528+0j) | time=31.05462457500107s
# iter=2 | energy=(-523.3763282266189+0j) | time=60.66193382899655s
# computing Neumann entropy: 4.736s
# L=1024 | ZZ=1.44
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-525.06816 | time=0js
# iter=1 | energy=(-525.122984670702+0j) | time=27.325808372996107s
# iter=2 | energy=(-525.1229846706976+0j) | time=57.025419812998734s
# computing Neumann entropy: 3.456s
# L=1024 | ZZ=1.45
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-526.82047 | time=0js
# iter=1 | energy=(-526.8754324109965+0j) | time=28.508459012999083s
# iter=2 | energy=(-526.8754324109779+0j) | time=57.11493818099552s
# computing Neumann entropy: 4.92s
# L=1024 | ZZ=1.46
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-528.57869 | time=0js
# iter=1 | energy=(-528.63383649497+0j) | time=37.005083213000034s
# iter=2 | energy=(-528.6338364949735+0j) | time=70.06803894699988s
# computing Neumann entropy: 5.092s
# L=1024 | ZZ=1.47
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-530.34286 | time=0js
# iter=1 | energy=(-530.3981192778822+0j) | time=32.930642191000516s
# iter=2 | energy=(-530.3981192778737+0j) | time=63.99713493200397s
# computing Neumann entropy: 4.767s
# L=1024 | ZZ=1.48
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-532.11293 | time=0js
# iter=1 | energy=(-532.1681897491867+0j) | time=28.77121699199779s
# iter=2 | energy=(-532.1681897491876+0j) | time=57.191169211997476s
# computing Neumann entropy: 4.523s
# L=1024 | ZZ=1.49
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-533.88887 | time=0js
# iter=1 | energy=(-533.9442223296948+0j) | time=27.435386063996702s
# iter=2 | energy=(-533.9442223297051+0j) | time=55.20100717899186s
# computing Neumann entropy: 3.964s
# L=1024 | ZZ=1.5
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-535.67068 | time=0js
# iter=1 | energy=(-535.7261124289637+0j) | time=25.467719863001548s
# iter=2 | energy=(-535.7261124289178+0j) | time=49.21394598399638s
# computing Neumann entropy: 2.684s
# L=1024 | ZZ=1.51
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-537.45835 | time=0js
# iter=1 | energy=(-537.5138469910045+0j) | time=24.513573115000327s
# iter=2 | energy=(-537.5138469909626+0j) | time=45.56410899099865s
# computing Neumann entropy: 3.83s
# L=1024 | ZZ=1.52
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-539.25185 | time=0js
# iter=1 | energy=(-539.3074039662752+0j) | time=22.628240614998504s
# iter=2 | energy=(-539.3074039663222+0j) | time=42.44898349399591s
# computing Neumann entropy: 1.84s
# L=1024 | ZZ=1.53
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-541.05117 | time=0js
# iter=1 | energy=(-541.1067672814463+0j) | time=23.008279248999315s
# iter=2 | energy=(-541.1067672814377+0j) | time=44.85225236399856s
# computing Neumann entropy: 1.759s
# L=1024 | ZZ=1.54
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-542.85628 | time=0js
# iter=1 | energy=(-542.9119142134069+0j) | time=20.16596052100067s
# iter=2 | energy=(-542.9119142134289+0j) | time=38.85299546200258s
# computing Neumann entropy: 2.621s
# L=1024 | ZZ=1.55
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-544.66716 | time=0js
# iter=1 | energy=(-544.7228268600081+0j) | time=19.566863546002423s
# iter=2 | energy=(-544.7228268600102+0j) | time=38.019942841005104s
# computing Neumann entropy: 2.659s
# L=1024 | ZZ=1.56
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-546.48379 | time=0js
# iter=1 | energy=(-546.5394767984213+0j) | time=22.37634723699739s
# iter=2 | energy=(-546.5394767984028+0j) | time=39.65027530199586s
# computing Neumann entropy: 3.218s
# L=1024 | ZZ=1.57
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-548.30614 | time=0js
# iter=1 | energy=(-548.3618818881446+0j) | time=19.941437161003705s
# iter=2 | energy=(-548.3618818881038+0j) | time=37.809975377997034s
# computing Neumann entropy: 4.117s
# L=1024 | ZZ=1.58
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-550.13418 | time=0js
# iter=1 | energy=(-550.1899332243956+0j) | time=21.130708173004678s
# iter=2 | energy=(-550.1899332243926+0j) | time=38.65039302200603s
# computing Neumann entropy: 2.78s
# L=1024 | ZZ=1.59
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-551.96789 | time=0js
# iter=1 | energy=(-552.023643887636+0j) | time=19.105959670996526s
# iter=2 | energy=(-552.0236438876649+0j) | time=38.356442460994s
# computing Neumann entropy: 2.491s
# L=1024 | ZZ=1.6
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-553.80724 | time=0js
# iter=1 | energy=(-553.8629854960325+0j) | time=22.86072849899938s
# iter=2 | energy=(-553.862985496033+0j) | time=41.17946736700105s
# computing Neumann entropy: 1.89s
# L=1024 | ZZ=1.61
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-555.65219 | time=0js
# iter=1 | energy=(-555.7079261392303+0j) | time=18.532538455998292s
# iter=2 | energy=(-555.7079261392096+0j) | time=39.02892191600404s
# computing Neumann entropy: 1.378s
# L=1024 | ZZ=1.62
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-557.50272 | time=0js
# iter=1 | energy=(-557.5584442951789+0j) | time=19.1194825019993s
# iter=2 | energy=(-557.5584442952045+0j) | time=36.0075367870013s
# computing Neumann entropy: 1.379s
# L=1024 | ZZ=1.63
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-559.3588 | time=0js
# iter=1 | energy=(-559.4144934585038+0j) | time=18.452650243998505s
# iter=2 | energy=(-559.4144934585102+0j) | time=33.710682748002s
# computing Neumann entropy: 3.322s
# L=1024 | ZZ=1.64
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-561.22038 | time=0js
# iter=1 | energy=(-561.2760418351106+0j) | time=18.727719403002993s
# iter=2 | energy=(-561.2760418351218+0j) | time=36.11360360800609s
# computing Neumann entropy: 1.566s
# L=1024 | ZZ=1.65
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-563.08743 | time=0js
# iter=1 | energy=(-563.143058259427+0j) | time=19.45842033000372s
# iter=2 | energy=(-563.1430582594409+0j) | time=40.51379877800355s
# computing Neumann entropy: 1.763s
# L=1024 | ZZ=1.66
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-564.95991 | time=0js
# iter=1 | energy=(-565.0155061428626+0j) | time=18.283705772002577s
# iter=2 | energy=(-565.015506142819+0j) | time=34.71748802000366s
# computing Neumann entropy: 1.051s
# L=1024 | ZZ=1.67
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-566.83781 | time=0js
# iter=1 | energy=(-566.893361102864+0j) | time=18.581622181001876s
# iter=2 | energy=(-566.8933611028156+0j) | time=33.735970571004145s
# computing Neumann entropy: 2.003s
# L=1024 | ZZ=1.68
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-568.72107 | time=0js
# iter=1 | energy=(-568.7765796667584+0j) | time=17.83408171400515s
# iter=2 | energy=(-568.7765796667502+0j) | time=33.30655931000365s
# computing Neumann entropy: 1.019s
# L=1024 | ZZ=1.69
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-570.60967 | time=0js
# iter=1 | energy=(-570.6651285751852+0j) | time=17.86570768999809s
# iter=2 | energy=(-570.6651285752031+0j) | time=32.98391820800316s
# computing Neumann entropy: 2.182s
# L=1024 | ZZ=1.7
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-572.50356 | time=0js
# iter=1 | energy=(-572.5588861285487+0j) | time=18.19795355500537s
# iter=2 | energy=(-572.5588861285468+0j) | time=33.63413954200951s
# computing Neumann entropy: 1.118s
# L=1024 | ZZ=1.71
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-574.4027 | time=0js
# iter=1 | energy=(-574.4579676778578+0j) | time=16.650447446001635s
# iter=2 | energy=(-574.4579676778244+0j) | time=33.100320819001354s
# computing Neumann entropy: 0.946s
# L=1024 | ZZ=1.72
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-576.30706 | time=0js
# iter=1 | energy=(-576.3622607149932+0j) | time=49.94447278399457s
# iter=2 | energy=(-576.3622607150155+0j) | time=79.84997378899425s
# computing Neumann entropy: 2.103s
# L=1024 | ZZ=1.73
# L=1024 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-578.21659 | time=0js
# iter=1 | energy=(-578.271716645739+0j) | time=15.696153310003865s
