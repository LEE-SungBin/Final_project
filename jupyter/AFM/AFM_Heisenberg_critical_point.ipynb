# %%
import numpy as np
import sys
import itertools as itertools
import time
sys.path.append("..")
sys.path.append("../..")

import matplotlib.pyplot as plt
from python.Heisenberg import *
from python.DMRG import DMRG
from python.Zippers import MPO_to_Hamiltonian, contract_MPS
from python.Canonical_Form import get_Neumann_entropy_from_left_isometry
from python.Backend import Backend
from python.Decomposition import EIGH

# %%
device = "numpy"
# device = "torch"

bk = Backend(device)

NSweep = 20
Krylov_bases = 5  #* 5 is usually enough
Lanczos_cutoff = 1e-2
two_site = True
verbose = True

# %%
import numpy.typing as npt
import pickle
from dataclasses import dataclass, field, asdict, replace
from copy import deepcopy
from typing import Any, Optional
from pathlib import Path


@dataclass
class Params:
    L: int
    XY: float
    ZZ: float
    h: float
    NKeep: int
    NSweep: int
    diag: bool
    Krylov: int
    cutoff: float
    two: bool
    
    def to_log(self) -> str:
        log_dict = asdict(self)
        
        log_dict['XY'] = round(self.XY, 2)
        log_dict['ZZ'] = round(self.ZZ, 2)
        log_dict['h'] = round(self.h, 2)
        log_dict['cutoff'] = round(self.cutoff, 3)
        
        # Filter out keys where the value is None
        filtered_log_dict = {key: log for key, log in log_dict.items() if log is not None}
        
        # Create log string
        return "_".join(
            f"{key}={log}" for key, log in filtered_log_dict.items()
        )

@dataclass
class Results:
    ground_MPS: list[npt.NDArray]
    ground_state_energy: float
    Neumann_entropy: float
    ground_energies: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    spin_z: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    spin_correlations: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    
    
    def to_array(self):
        return replace(
            self, **{field: np.array(getattr(self, field))
            if isinstance(getattr(self, field), list) else getattr(self, field)
            for field in asdict(self)}
        )
        
    def self_destruct(self):
        for field_name in self.__dataclass_fields__:
            field_value = getattr(self, field_name)
            if isinstance(field_value, list):
                field_value.clear()  # Clear list contents
            else:
                setattr(self, field_name, None)  # Set to None if not a list

# %%
n_sites_lists = np.array([4096, 8192])
NKeeps = np.array([128])

XY_coupling = 1
magnetic_field = 0

ZZ_coupling_start = 1.0
ZZ_coupling_end = 1.4
delta_ZZ = 0.01

ZZ_couplings = bk.arange(ZZ_coupling_start, ZZ_coupling_end+delta_ZZ, delta_ZZ)

# %%
for NKeep in NKeeps:
    for n_sites in n_sites_lists:
        for ZZ_coupling in ZZ_couplings:
            
            if verbose:
                print(f"L={n_sites} | ZZ={round(ZZ_coupling,2)}")
            
            Hamiltonian = XXZ_model(
                bk=bk, n_sites=n_sites, ZZ_coupling=ZZ_coupling,
                XY_coupling=XY_coupling, magnetic_field=magnetic_field,
            )
            
            ground_energies, ground_times, ground_MPS = DMRG(
                bk = bk,
                Hamiltonian = Hamiltonian,
                NKeep = NKeep,
                NSweep = NSweep,
                Krylov_bases = Krylov_bases,
                Lanczos_cutoff = Lanczos_cutoff,
                iterative_diag = True,
                two_site = two_site,
                verbose = verbose,
                tol = 1e-6,
            )
            
            param = Params(
                L = n_sites,
                XY = XY_coupling,
                ZZ = ZZ_coupling,
                h = magnetic_field,
                NKeep = NKeep,
                NSweep = NSweep,
                diag = True,
                Krylov = Krylov_bases,
                cutoff = Lanczos_cutoff,
                two = two_site
            )
            
            # dir_name = Path(f"data")
            dir_name = Path(f"{device}/critical_point")
            dir_name.mkdir(parents=True, exist_ok=True)
            
            filename = f"{param.to_log()}"
            ground_state_energy = ground_energies[-1]
            
            if verbose:
                print(f"computing Neumann entropy: ", end="")
                now = time.perf_counter()
            Neumann_entropy = get_Neumann_entropy_from_left_isometry(ground_MPS, bk=bk)
            if verbose:
                print(f"{round(time.perf_counter()-now,3)}s")
            
            result = Results(
                ground_MPS = [],
                ground_state_energy = ground_state_energy,
                ground_energies = ground_energies,
                Neumann_entropy = Neumann_entropy,
                spin_z = [],
                spin_correlations = [],
            )
                
            output: dict[str, Any] = {}
            output.update(asdict(param))
            output.update(asdict(result))
            
            with open(dir_name / f"{filename}.pkl", "wb") as file:
                pickle.dump(output, file)
# Out:
# L=4096 | ZZ=1.0
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1814.924 | time=0js
# iter=2 | energy=(-1814.9410268198362+0j) | time=809.0291561470076s
# computing Neumann entropy: 214.937s
# L=4096 | ZZ=1.01
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1820.9833 | time=0js
# iter=2 | energy=(-1821.000203989035+0j) | time=1661.2107011160115s
# computing Neumann entropy: 116.213s
# L=4096 | ZZ=1.02
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1827.062 | time=0js
# iter=3 | energy=(-1827.0790194894576+0j) | time=1180.381658475002s
# computing Neumann entropy: 70.037s
# L=4096 | ZZ=1.03
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1833.1599 | time=0js
# iter=2 | energy=(-1833.177089143087+0j) | time=670.0156409290212s
# computing Neumann entropy: 67.821s
# L=4096 | ZZ=1.04
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1839.2773 | time=0js
# iter=4 | energy=(-1839.2945360716963+0j) | time=1313.995185761014s
# computing Neumann entropy: 70.009s
# L=4096 | ZZ=1.05
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1845.4141 | time=0js
# iter=2 | energy=(-1845.4314446268254+0j) | time=649.9961113570025s
# computing Neumann entropy: 70.78s
# L=4096 | ZZ=1.06
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1851.5705 | time=0js
# iter=2 | energy=(-1851.5879776953566+0j) | time=657.9623131479893s
# computing Neumann entropy: 69.059s
# L=4096 | ZZ=1.07
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1857.7463 | time=0js
# iter=2 | energy=(-1857.7640236573138+0j) | time=651.0571278719872s
# computing Neumann entropy: 68.194s
# L=4096 | ZZ=1.08
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1863.942 | time=0js
# iter=3 | energy=(-1863.9595860282343+0j) | time=975.9024500779924s
# computing Neumann entropy: 68.109s
# L=4096 | ZZ=1.09
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1870.1573 | time=0js
# iter=2 | energy=(-1870.1753653068595+0j) | time=650.1268492070085s
# computing Neumann entropy: 68.607s
# L=4096 | ZZ=1.1
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1876.3926 | time=0js
# iter=2 | energy=(-1876.4108397828345+0j) | time=690.2120499869925s
# computing Neumann entropy: 67.899s
# L=4096 | ZZ=1.11
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1882.6477 | time=0js
# iter=2 | energy=(-1882.6662945580138+0j) | time=760.0071361050068s
# computing Neumann entropy: 68.674s
# L=4096 | ZZ=1.12
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1888.9228 | time=0js
# iter=4 | energy=(-1888.9417448700246+0j) | time=1305.5546477939934s
# computing Neumann entropy: 69.441s
# L=4096 | ZZ=1.13
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1895.2182 | time=0js
# iter=4 | energy=(-1895.2374721745543+0j) | time=1388.503174137004s
# computing Neumann entropy: 79.679s
# L=4096 | ZZ=1.14
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1901.5334 | time=0js
# iter=3 | energy=(-1901.5536059976725+0j) | time=1150.6039258730016s
# computing Neumann entropy: 79.751s
# L=4096 | ZZ=1.15
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1907.8691 | time=0js
# iter=3 | energy=(-1907.8898753917535+0j) | time=1157.0705296139931s
# computing Neumann entropy: 79.717s
# L=4096 | ZZ=1.16
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1914.225 | time=0js
# iter=3 | energy=(-1914.2472654254943+0j) | time=1149.151333020971s
# computing Neumann entropy: 79.583s
# L=4096 | ZZ=1.17
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1920.6008 | time=0js
# iter=2 | energy=(-1920.6253456324066+0j) | time=771.1337724869954s
# computing Neumann entropy: 79.572s
# L=4096 | ZZ=1.18
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1926.9962 | time=0js
# iter=2 | energy=(-1927.0243090736883+0j) | time=697.5841161060089s
# computing Neumann entropy: 68.684s
# L=4096 | ZZ=1.19
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1933.4101 | time=0js
# iter=2 | energy=(-1933.4437017232253+0j) | time=649.828230604995s
# computing Neumann entropy: 66.827s
# L=4096 | ZZ=1.2
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1939.8454 | time=0js
# iter=2 | energy=(-1939.885099214859+0j) | time=649.8256007419841s
# computing Neumann entropy: 68.25s
# L=4096 | ZZ=1.21
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1946.3032 | time=0js
# iter=2 | energy=(-1946.3476825889165+0j) | time=658.2501955369953s
# computing Neumann entropy: 68.599s
# L=4096 | ZZ=1.22
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1952.7865 | time=0js
# iter=2 | energy=(-1952.8327443927278+0j) | time=638.7344580380013s
# computing Neumann entropy: 67.154s
# L=4096 | ZZ=1.23
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1959.2919 | time=0js
# iter=2 | energy=(-1959.3391734903716+0j) | time=634.9109060690098s
# computing Neumann entropy: 67.287s
# L=4096 | ZZ=1.24
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1965.8198 | time=0js
# iter=2 | energy=(-1965.8675028991297+0j) | time=637.3694820759993s
# computing Neumann entropy: 65.469s
# L=4096 | ZZ=1.25
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1972.3699 | time=0js
# iter=2 | energy=(-1972.4181883410924+0j) | time=634.0970338319894s
# computing Neumann entropy: 65.833s
# L=4096 | ZZ=1.26
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1978.9423 | time=0js
# iter=2 | energy=(-1978.9912205862058+0j) | time=633.7507411260158s
# computing Neumann entropy: 66.699s
# L=4096 | ZZ=1.27
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1985.5372 | time=0js
# iter=2 | energy=(-1985.586468172689+0j) | time=635.7643899079994s
# computing Neumann entropy: 67.416s
# L=4096 | ZZ=1.28
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1992.1548 | time=0js
# iter=2 | energy=(-1992.2045829597282+0j) | time=564.6129695060081s
# computing Neumann entropy: 56.868s
# L=4096 | ZZ=1.29
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-1998.7951 | time=0js
# iter=2 | energy=(-1998.8451610848747+0j) | time=537.5188317309949s
# computing Neumann entropy: 55.604s
# L=4096 | ZZ=1.3
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-2005.4583 | time=0js
# iter=2 | energy=(-2005.5086443770122+0j) | time=518.3062570109614s
# computing Neumann entropy: 53.929s
# L=4096 | ZZ=1.31
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-2012.1445 | time=0js
# iter=2 | energy=(-2012.1953043577948+0j) | time=697.4263904029795s
# computing Neumann entropy: 71.009s
# L=4096 | ZZ=1.32
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-2018.8539 | time=0js
# iter=3 | energy=(-2018.9050803208297+0j) | time=928.4794265859819s
# computing Neumann entropy: 64.028s
# L=4096 | ZZ=1.33
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-2025.5866 | time=0js
# iter=2 | energy=(-2025.638120241515+0j) | time=421.2348190979974s
# computing Neumann entropy: 41.872s
# L=4096 | ZZ=1.34
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-2032.3426 | time=0js
# iter=2 | energy=(-2032.3943726877665+0j) | time=409.95263733901083s
# computing Neumann entropy: 40.991s
# L=4096 | ZZ=1.35
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-2039.1221 | time=0js
# iter=2 | energy=(-2039.174185525578+0j) | time=364.5687978369824s
# computing Neumann entropy: 35.014s
# L=4096 | ZZ=1.36
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-2045.9251 | time=0js
# iter=3 | energy=(-2045.97737957766+0j) | time=573.3120599829999s
# computing Neumann entropy: 38.013s
# L=4096 | ZZ=1.37
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-2052.7516 | time=0js
# iter=2 | energy=(-2052.80431367852+0j) | time=344.6019145579776s
# computing Neumann entropy: 32.718s
# L=4096 | ZZ=1.38
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-2059.6018 | time=0js
# iter=2 | energy=(-2059.65477393724+0j) | time=332.36846198598505s
# computing Neumann entropy: 31.241s
# L=4096 | ZZ=1.39
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-2066.4757 | time=0js
# iter=2 | energy=(-2066.528723688323+0j) | time=328.23635781300254s
# computing Neumann entropy: 29.061s
# L=4096 | ZZ=1.4
# L=4096 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-2073.3734 | time=0js
# iter=2 | energy=(-2073.426719874973+0j) | time=350.70459559498704s
# computing Neumann entropy: 35.416s
# L=8192 | ZZ=1.0
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3630.0537 | time=0js
# iter=4 | energy=(-3630.070272819578+0j) | time=2697.8665624729765s
# computing Neumann entropy: 141.745s
# L=8192 | ZZ=1.01
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3642.1731 | time=0js
# iter=3 | energy=(-3642.182270323542+0j) | time=2068.87811513801s
# computing Neumann entropy: 141.729s
# L=8192 | ZZ=1.02
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3654.3312 | time=0js
# iter=6 | energy=(-3654.3393038011736+0j) | time=4672.689071387984s
# computing Neumann entropy: 192.567s
# L=8192 | ZZ=1.03
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3666.5279 | time=0js
# iter=3 | energy=(-3666.5448765616784+0j) | time=2676.8652998930484s
# computing Neumann entropy: 139.286s
# L=8192 | ZZ=1.04
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3678.7634 | time=0js
# iter=5 | energy=(-3678.7701923830436+0j) | time=4425.596464901057s
# computing Neumann entropy: 168.096s
# L=8192 | ZZ=1.05
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3691.0378 | time=0js
# iter=3 | energy=(-3691.0506770736797+0j) | time=2701.0291352199856s
# computing Neumann entropy: 204.16s
# L=8192 | ZZ=1.06
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3703.3514 | time=0js
# iter=4 | energy=(-3703.362485049329+0j) | time=3858.043129086029s
# computing Neumann entropy: 194.836s
# L=8192 | ZZ=1.07
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3715.7038 | time=0js
# iter=5 | energy=(-3715.7137770447+0j) | time=4655.168249207025s
# computing Neumann entropy: 156.988s
# L=8192 | ZZ=1.08
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3728.0958 | time=0js
# iter=7 | energy=(-3728.109596009245+0j) | time=5365.946674757986s
# computing Neumann entropy: 149.887s
# L=8192 | ZZ=1.09
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3740.5275 | time=0js
# iter=3 | energy=(-3740.545661606104+0j) | time=2136.651966190024s
# computing Neumann entropy: 154.632s
# L=8192 | ZZ=1.1
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3752.9997 | time=0js
# iter=4 | energy=(-3753.0161541190582+0j) | time=3100.5227854530094s
# computing Neumann entropy: 154.794s
# L=8192 | ZZ=1.11
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3765.5112 | time=0js
# iter=3 | energy=(-3765.5290401059538+0j) | time=2267.565127665992s
# computing Neumann entropy: 165.504s
# L=8192 | ZZ=1.12
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3778.0591 | time=0js
# iter=4 | energy=(-3778.079591390277+0j) | time=3028.575186751026s
# computing Neumann entropy: 136.037s
# L=8192 | ZZ=1.13
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3790.6512 | time=0js
# iter=4 | energy=(-3790.674006837755+0j) | time=2624.4804582679644s
# computing Neumann entropy: 134.935s
# L=8192 | ZZ=1.14
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3803.2715 | time=0js
# iter=3 | energy=(-3803.3011735753357+0j) | time=1898.5963214160874s
# computing Neumann entropy: 113.383s
# L=8192 | ZZ=1.15
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3815.9428 | time=0js
# iter=6 | energy=(-3815.9778797341014+0j) | time=3460.3248604299733s
# computing Neumann entropy: 111.953s
# L=8192 | ZZ=1.16
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3828.6717 | time=0js
# iter=5 | energy=(-3828.6927655532827+0j) | time=2829.184931775031s
# computing Neumann entropy: 114.52s
# L=8192 | ZZ=1.17
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3841.4215 | time=0js
# iter=5 | energy=(-3841.4485584567974+0j) | time=2856.4413279119763s
# computing Neumann entropy: 115.169s
# L=8192 | ZZ=1.18
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3854.2093 | time=0js
# iter=5 | energy=(-3854.243345559912+0j) | time=2932.7735749560525s
# computing Neumann entropy: 115.011s
# L=8192 | ZZ=1.19
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3867.05 | time=0js
# iter=3 | energy=(-3867.089403786943+0j) | time=1927.8197275230195s
# computing Neumann entropy: 145.451s
# L=8192 | ZZ=1.2
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3879.9336 | time=0js
# iter=5 | energy=(-3879.9734324516885+0j) | time=3764.1551033419673s
# computing Neumann entropy: 155.953s
# L=8192 | ZZ=1.21
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3892.8605 | time=0js
# iter=4 | energy=(-3892.905628360384+0j) | time=1981.3696245909669s
# computing Neumann entropy: 92.629s
# L=8192 | ZZ=1.22
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3905.8306 | time=0js
# iter=5 | energy=(-3905.874345101297+0j) | time=2474.9192711129435s
# computing Neumann entropy: 94.967s
# L=8192 | ZZ=1.23
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3918.8445 | time=0js
# iter=5 | energy=(-3918.8847812460117+0j) | time=2425.0113335340284s
# computing Neumann entropy: 94.964s
# L=8192 | ZZ=1.24
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3931.9024 | time=0js
# iter=8 | energy=(-3931.9419522731723+0j) | time=3236.8381248691003s
# computing Neumann entropy: 81.561s
# L=8192 | ZZ=1.25
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3945.0046 | time=0js
# iter=5 | energy=(-3945.0416156780366+0j) | time=2092.4417510039057s
# computing Neumann entropy: 83.582s
# L=8192 | ZZ=1.26
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3958.1516 | time=0js
# iter=5 | energy=(-3958.1955132767416+0j) | time=2499.741616153042s
# computing Neumann entropy: 101.117s
# L=8192 | ZZ=1.27
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3971.3435 | time=0js
# iter=5 | energy=(-3971.3668054631116+0j) | time=1996.184402272047s
# computing Neumann entropy: 77.682s
# L=8192 | ZZ=1.28
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3984.5806 | time=0js
# iter=6 | energy=(-3984.6164372894254+0j) | time=2424.3458186370553s
# computing Neumann entropy: 77.555s
# L=8192 | ZZ=1.29
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-3997.8634 | time=0js
# iter=4 | energy=(-3997.900350830002+0j) | time=1504.3748097270145s
# computing Neumann entropy: 61.629s
# L=8192 | ZZ=1.3
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-4011.192 | time=0js
# iter=5 | energy=(-4011.2414374054233+0j) | time=2301.9926869879127s
# computing Neumann entropy: 86.862s
# L=8192 | ZZ=1.31
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-4024.5667 | time=0js
# iter=6 | energy=(-4024.6165827080054+0j) | time=3061.158030044986s
# computing Neumann entropy: 97.234s
# L=8192 | ZZ=1.32
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-4037.9877 | time=0js
# iter=5 | energy=(-4038.0216144541673+0j) | time=2485.815208935004s
# computing Neumann entropy: 96.195s
# L=8192 | ZZ=1.33
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-4051.4552 | time=0js
# iter=5 | energy=(-4051.5057787021624+0j) | time=1388.2331438529654s
# computing Neumann entropy: 62.766s
# L=8192 | ZZ=1.34
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-4064.9695 | time=0js
# iter=6 | energy=(-4065.0212434587356+0j) | time=2099.2511095230584s
# computing Neumann entropy: 68.287s
# L=8192 | ZZ=1.35
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-4078.5307 | time=0js
# iter=4 | energy=(-4078.5822466974078+0j) | time=2369.5918719979236s
# computing Neumann entropy: 115.18s
# L=8192 | ZZ=1.36
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-4092.1389 | time=0js
# iter=4 | energy=(-4092.191124926374+0j) | time=1132.229973911075s
# computing Neumann entropy: 48.23s
# L=8192 | ZZ=1.37
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-4105.7944 | time=0js
# iter=5 | energy=(-4105.846841319121+0j) | time=1324.699760788004s
# computing Neumann entropy: 47.449s
# L=8192 | ZZ=1.38
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-4119.4971 | time=0js
# iter=4 | energy=(-4119.549797055056+0j) | time=998.272474275087s
# computing Neumann entropy: 47.211s
# L=8192 | ZZ=1.39
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-4133.2472 | time=0js
# iter=10 | energy=(-4133.300324630782+0j) | time=2351.6737368950853s
# computing Neumann entropy: 47.429s
# L=8192 | ZZ=1.4
# L=8192 | NKeep=128 | NSweep=20 | iterative=True | two_site=True | Krylov_bases=5 | Lanczos_cutoff=0.01
# iter=0 | energy=-4147.0448 | time=0js
# iter=3 | energy=(-4147.097918077412+0j) | time=1030.746688333049s
# computing Neumann entropy: 65.771s
