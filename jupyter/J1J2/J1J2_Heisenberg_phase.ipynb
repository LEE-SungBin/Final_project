# %%
import numpy as np
import sys
import itertools as itertools
import time
sys.path.append("..")
sys.path.append("../..")

import matplotlib.pyplot as plt
from python.Heisenberg import *
from python.DMRG import DMRG
from python.Zippers import MPO_to_Hamiltonian, contract_MPS
from python.Canonical_Form import get_Neumann_entropy
from python.Backend import Backend

# %%
n_sites = 50

# %%
device = "numpy"
# device = "torch"

bk = Backend(device)

NKeep = 50
NSweep = 20
Krylov_bases = 5 #* 5 is usually enough
Lanczos_cutoff = 1e-2
iterative_diag = True
two_site = True
verbose = True

# %%
import numpy.typing as npt
import pickle
from dataclasses import dataclass, field, asdict, replace
from copy import deepcopy
from typing import Any, Optional
from pathlib import Path


@dataclass
class Params:
    L: int
    J1: float
    J2: float
    NKeep: int
    NSweep: int
    diag: bool
    Krylov: int
    cutoff: float
    two: bool
    
    def to_log(self) -> str:
        log_dict = asdict(self)
        
        log_dict['J1'] = round(self.J1, 2)
        log_dict['J2'] = round(self.J2, 2)
        log_dict['cutoff'] = round(self.cutoff, 3)
        
        # Filter out keys where the value is None
        filtered_log_dict = {key: log for key, log in log_dict.items() if log is not None}
        
        # Create log string
        return "_".join(
            f"{key}={log}" for key, log in filtered_log_dict.items()
        )


@dataclass
class Results:
    ground_MPS: list[npt.NDArray]
    ground_state_energy: float
    Neumann_entropy: float
    ground_energies: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    spin_z: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    spin_correlations: list[float] | npt.NDArray[np.float64] = field(default_factory=list)
    
    
    def to_array(self):
        return replace(
            self, **{field: np.array(getattr(self, field))
            if isinstance(getattr(self, field), list) else getattr(self, field)
            for field in asdict(self)}
        )
        
    def self_destruct(self):
        for field_name in self.__dataclass_fields__:
            field_value = getattr(self, field_name)
            if isinstance(field_value, list):
                field_value.clear()  # Clear list contents
            else:
                setattr(self, field_name, None)  # Set to None if not a list

# %%
J1_start = -4
J1_end = 4
delta_J1 = 0.1

J1s = bk.arange(J1_start, J1_end+delta_J1, delta_J1)

J2_start = -4
J2_end = 4
delta_J2 = 0.1

J2s = bk.arange(J2_start, J2_end+delta_J2, delta_J2)

# %%
for it1, J1 in enumerate(J1s):
    for it2, J2 in enumerate(J2s):
        
        if verbose:
            print(f"J1={round(J1,2)} | J2={round(J2,2)}")
        
        Hamiltonian = nn_Heisenberg_model(
            bk=bk, n_sites=n_sites,
            J1=J1, J2=J2,
        )
        
        ground_energies, ground_times, ground_MPS = DMRG(
            bk = bk,
            Hamiltonian = Hamiltonian,
            NKeep = NKeep,
            NSweep = NSweep,
            Krylov_bases = Krylov_bases,
            Lanczos_cutoff = Lanczos_cutoff,
            iterative_diag = True,
            two_site = two_site,
            verbose = verbose,
            tol = 1e-8,
        )
        
        param = Params(
            L = n_sites,
            J1 = J1,
            J2 = J2,
            NKeep = NKeep,
            NSweep = NSweep,
            diag = iterative_diag,
            Krylov = Krylov_bases,
            cutoff = Lanczos_cutoff,
            two = two_site
        )
        
        # dir_name = Path(f"data")
        dir_name = Path(f"{device}/data")
        dir_name.mkdir(parents=True, exist_ok=True)
        
        filename = f"{param.to_log()}"
        ground_state_energy = ground_energies[-1]
        Neumann_entropy = get_Neumann_entropy(ground_MPS, bk=bk)
        spin_z = get_spin_z(ground_MPS, bk)
        
        if verbose:
            print(f"computing spin correlations: ", end="")
            now = time.perf_counter()
        spin_correlations = get_spin_correlations(ground_MPS, bk)
        if verbose:
            print(f"{round(time.perf_counter()-now,3)}s")
        
        result = Results(
            ground_MPS = [],
            ground_state_energy = ground_state_energy,
            ground_energies = ground_energies,
            Neumann_entropy = Neumann_entropy,
            spin_z = spin_z,
            spin_correlations = spin_correlations,
        )
        
        output: dict[str, Any] = {}
        output.update(asdict(param))
        output.update(asdict(result))
        
        with open(dir_name / f"{filename}.pkl", "wb") as file:
            pickle.dump(output, file)
# Out:
# J1=-4.0 | J2=-4.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-97.0 | time=0js
# iter=1 | energy=(-97+0j) | time=0.17848289402900264s
# computing spin correlations: 2.139s
# J1=-4.0 | J2=-3.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-95.8 | time=0js
# iter=1 | energy=(-95.79999999999994+0j) | time=0.1293949949904345s
# computing spin correlations: 2.129s
# J1=-4.0 | J2=-3.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-94.6 | time=0js
# iter=1 | energy=(-94.60000000000008+0j) | time=0.12823439500061795s
# computing spin correlations: 2.117s
# J1=-4.0 | J2=-3.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-93.4 | time=0js
# iter=1 | energy=(-93.39999999999992+0j) | time=0.14770430099451914s
# computing spin correlations: 2.094s
# J1=-4.0 | J2=-3.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-92.2 | time=0js
# iter=1 | energy=(-92.20000000000005+0j) | time=0.125413600995671s
# computing spin correlations: 2.172s
# J1=-4.0 | J2=-3.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-91.0 | time=0js
# iter=1 | energy=(-91+0j) | time=0.14710130001185462s
# computing spin correlations: 2.147s
# J1=-4.0 | J2=-3.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-89.8 | time=0js
# iter=1 | energy=(-89.79999999999995+0j) | time=0.17830770002910867s
# computing spin correlations: 2.147s
# J1=-4.0 | J2=-3.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-88.6 | time=0js
# iter=1 | energy=(-88.60000000000008+0j) | time=0.12828159995842725s
# computing spin correlations: 2.128s
# J1=-4.0 | J2=-3.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-87.4 | time=0js
# iter=1 | energy=(-87.39999999999992+0j) | time=0.16994150099344552s
# computing spin correlations: 2.15s
# J1=-4.0 | J2=-3.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-86.2 | time=0js
# iter=1 | energy=(-86.20000000000003+0j) | time=0.13397719903150573s
# computing spin correlations: 2.155s
# J1=-4.0 | J2=-3.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-85.0 | time=0js
# iter=1 | energy=(-85+0j) | time=0.18388579902239144s
# computing spin correlations: 2.125s
# J1=-4.0 | J2=-2.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-83.8 | time=0js
# iter=1 | energy=(-83.79999999999997+0j) | time=0.1397624000092037s
# computing spin correlations: 2.111s
# J1=-4.0 | J2=-2.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-82.6 | time=0js
# iter=1 | energy=(-82.60000000000007+0j) | time=0.13391899998532608s
# computing spin correlations: 2.171s
# J1=-4.0 | J2=-2.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-81.4 | time=0js
# iter=1 | energy=(-81.39999999999993+0j) | time=0.12329019996104762s
# computing spin correlations: 2.147s
# J1=-4.0 | J2=-2.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-80.2 | time=0js
# iter=1 | energy=(-80.20000000000002+0j) | time=0.12796869996236637s
# computing spin correlations: 2.155s
# J1=-4.0 | J2=-2.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-79.0 | time=0js
# iter=1 | energy=(-79+0j) | time=0.14023089996771887s
# computing spin correlations: 2.116s
# J1=-4.0 | J2=-2.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-77.8 | time=0js
# iter=1 | energy=(-77.8+0j) | time=0.16994170000543818s
# computing spin correlations: 2.126s
# J1=-4.0 | J2=-2.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-76.6 | time=0js
# iter=1 | energy=(-76.60000000000007+0j) | time=0.1293004010221921s
# computing spin correlations: 2.12s
# J1=-4.0 | J2=-2.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-75.4 | time=0js
# iter=1 | energy=(-75.39999999999993+0j) | time=0.14578780200099573s
# computing spin correlations: 2.13s
# J1=-4.0 | J2=-2.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-74.2 | time=0js
# iter=1 | energy=(-74.19999999999999+0j) | time=0.12605890299892053s
# computing spin correlations: 2.113s
# J1=-4.0 | J2=-2.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-73.0 | time=0js
# iter=1 | energy=(-73+0j) | time=0.12894480302929878s
# computing spin correlations: 2.138s
# J1=-4.0 | J2=-1.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-71.8 | time=0js
# iter=1 | energy=(-71.80000000000001+0j) | time=0.1252496019587852s
# computing spin correlations: 2.134s
# J1=-4.0 | J2=-1.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-70.6 | time=0js
# iter=1 | energy=(-70.60000000000007+0j) | time=0.12353980098851025s
# computing spin correlations: 2.1s
# J1=-4.0 | J2=-1.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-69.4 | time=0js
# iter=1 | energy=(-69.39999999999993+0j) | time=0.14123540103901178s
# computing spin correlations: 2.141s
# J1=-4.0 | J2=-1.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-68.2 | time=0js
# iter=1 | energy=(-68.19999999999997+0j) | time=0.22970890102442354s
# computing spin correlations: 2.163s
# J1=-4.0 | J2=-1.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-67.0 | time=0js
# iter=1 | energy=(-67+0j) | time=0.12317540001822636s
# computing spin correlations: 2.121s
# J1=-4.0 | J2=-1.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-65.8 | time=0js
# iter=1 | energy=(-65.80000000000004+0j) | time=0.13574720098404214s
# computing spin correlations: 2.112s
# J1=-4.0 | J2=-1.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.6 | time=0js
# iter=1 | energy=(-64.60000000000005+0j) | time=0.12755200098035857s
# computing spin correlations: 2.132s
# J1=-4.0 | J2=-1.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.4 | time=0js
# iter=1 | energy=(-63.39999999999994+0j) | time=0.13441619998775423s
# computing spin correlations: 2.138s
# J1=-4.0 | J2=-1.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-62.2 | time=0js
# iter=1 | energy=(-62.19999999999995+0j) | time=0.13908530096523464s
# computing spin correlations: 2.192s
# J1=-4.0 | J2=-1.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-61.0 | time=0js
# iter=1 | energy=(-61+0j) | time=0.12523080001119524s
# computing spin correlations: 2.119s
# J1=-4.0 | J2=-0.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-59.8 | time=0js
# iter=1 | energy=(-59.80000000000005+0j) | time=0.1502195000066422s
# computing spin correlations: 2.145s
# J1=-4.0 | J2=-0.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-58.6 | time=0js
# iter=1 | energy=(-58.60000000000005+0j) | time=0.12294159998418763s
# computing spin correlations: 2.171s
# J1=-4.0 | J2=-0.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-57.4 | time=0js
# iter=1 | energy=(-57.39999999999995+0j) | time=0.13772140198852867s
# computing spin correlations: 2.106s
# J1=-4.0 | J2=-0.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-56.2 | time=0js
# iter=1 | energy=(-56.19999999999995+0j) | time=0.13152200100012124s
# computing spin correlations: 2.149s
# J1=-4.0 | J2=-0.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-55.0 | time=0js
# iter=1 | energy=(-55+0j) | time=0.13337090198183432s
# computing spin correlations: 2.206s
# J1=-4.0 | J2=-0.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.8 | time=0js
# iter=1 | energy=(-53.80000000000005+0j) | time=0.22220620198640972s
# computing spin correlations: 2.223s
# J1=-4.0 | J2=-0.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-52.6 | time=0js
# iter=1 | energy=(-52.600000000000044+0j) | time=0.17614200100069866s
# computing spin correlations: 2.158s
# J1=-4.0 | J2=-0.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-51.4 | time=0js
# iter=1 | energy=(-51.39999999999996+0j) | time=0.1455954010016285s
# computing spin correlations: 2.145s
# J1=-4.0 | J2=-0.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-50.2 | time=0js
# iter=1 | energy=(-50.19999999999996+0j) | time=0.14666780404513702s
# computing spin correlations: 2.176s
# J1=-4.0 | J2=0.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-49.0 | time=0js
# iter=1 | energy=(-49+0j) | time=0.12810370296938345s
# computing spin correlations: 2.15s
# J1=-4.0 | J2=0.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-47.8 | time=0js
# iter=1 | energy=(-47.80000000000004+0j) | time=0.1413319010171108s
# computing spin correlations: 2.158s
# J1=-4.0 | J2=0.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-46.6 | time=0js
# iter=1 | energy=(-46.60000000000003+0j) | time=0.12776960094925016s
# computing spin correlations: 2.14s
# J1=-4.0 | J2=0.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-45.4 | time=0js
# iter=1 | energy=(-45.39999999999998+0j) | time=0.13465250103035942s
# computing spin correlations: 2.129s
# J1=-4.0 | J2=0.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-44.2 | time=0js
# iter=1 | energy=(-44.19999999999996+0j) | time=0.128900601004716s
# computing spin correlations: 2.138s
# J1=-4.0 | J2=0.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-43.0 | time=0js
# iter=1 | energy=(-43+0j) | time=0.20553180103888735s
# computing spin correlations: 2.153s
# J1=-4.0 | J2=0.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.8 | time=0js
# iter=1 | energy=(-41.80000000000004+0j) | time=0.1245141010149382s
# computing spin correlations: 2.122s
# J1=-4.0 | J2=0.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.6 | time=0js
# iter=1 | energy=(-40.60000000000001+0j) | time=0.14117369998712093s
# computing spin correlations: 2.127s
# J1=-4.0 | J2=0.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.4 | time=0js
# iter=1 | energy=(-39.39999999999999+0j) | time=0.14453819999471307s
# computing spin correlations: 2.114s
# J1=-4.0 | J2=0.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.2 | time=0js
# iter=1 | energy=(-38.19999999999997+0j) | time=0.13851150003029034s
# computing spin correlations: 2.155s
# J1=-4.0 | J2=1.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.0 | time=0js
# iter=1 | energy=(-37+0j) | time=0.1299074999988079s
# computing spin correlations: 2.132s
# J1=-4.0 | J2=1.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.8 | time=0js
# iter=1 | energy=(-35.80000000000003+0j) | time=0.15899009897839278s
# computing spin correlations: 2.137s
# J1=-4.0 | J2=1.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.6 | time=0js
# iter=1 | energy=(-34.59999999999999+0j) | time=0.19691889901878312s
# computing spin correlations: 2.196s
# J1=-4.0 | J2=1.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.4 | time=0js
# iter=1 | energy=(-33.40000000000001+0j) | time=0.12934139900607988s
# computing spin correlations: 2.105s
# J1=-4.0 | J2=1.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.2 | time=0js
# iter=1 | energy=(-32.199999999999974+0j) | time=0.1667949009570293s
# computing spin correlations: 2.138s
# J1=-4.0 | J2=1.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.0 | time=0js
# iter=1 | energy=(-31+0j) | time=0.15097690001130104s
# computing spin correlations: 2.146s
# J1=-4.0 | J2=1.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.8 | time=0js
# iter=1 | energy=(-29.800000000000026+0j) | time=0.15280160104157403s
# computing spin correlations: 2.162s
# J1=-4.0 | J2=1.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.6 | time=0js
# iter=1 | energy=(-28.599999999999977+0j) | time=0.20532160199945793s
# computing spin correlations: 2.124s
# J1=-4.0 | J2=1.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.4 | time=0js
# iter=1 | energy=(-27.400000000000023+0j) | time=0.17754600197076797s
# computing spin correlations: 2.152s
# J1=-4.0 | J2=1.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.2 | time=0js
# iter=1 | energy=(-26.199999999999978+0j) | time=0.22700720402644947s
# computing spin correlations: 2.134s
# J1=-4.0 | J2=2.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-25.0 | time=0js
# iter=1 | energy=(-25+0j) | time=0.20464670401997864s
# computing spin correlations: 2.129s
# J1=-4.0 | J2=2.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-24.4 | time=0js
# iter=1 | energy=(-24.400000000000016+0j) | time=0.21361920202616602s
# computing spin correlations: 2.199s
# J1=-4.0 | J2=2.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-25.4 | time=0js
# iter=1 | energy=(-25.4+0j) | time=0.16814320196863264s
# computing spin correlations: 2.154s
# J1=-4.0 | J2=2.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.3 | time=0js
# iter=1 | energy=(-28.299999999999983+0j) | time=0.32907480298308656s
# computing spin correlations: 2.124s
# J1=-4.0 | J2=2.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.4 | time=0js
# iter=1 | energy=(-29.40000000000002+0j) | time=0.17356770200422034s
# computing spin correlations: 2.139s
# J1=-4.0 | J2=2.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.5 | time=0js
# iter=1 | energy=(-30.5+0j) | time=0.14553770096972585s
# computing spin correlations: 2.153s
# J1=-4.0 | J2=2.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.6 | time=0js
# iter=1 | energy=(-31.599999999999977+0j) | time=0.16458050103392452s
# computing spin correlations: 2.162s
# J1=-4.0 | J2=2.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.4 | time=0js
# iter=1 | energy=(-33.40000000000002+0j) | time=0.16483990103006363s
# computing spin correlations: 2.2s
# J1=-4.0 | J2=2.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.6 | time=0js
# iter=1 | energy=(-34.59999999999999+0j) | time=0.1871806010021828s
# computing spin correlations: 2.146s
# J1=-4.0 | J2=2.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.8 | time=0js
# iter=1 | energy=(-35.80000000000003+0j) | time=0.20491960103390738s
# computing spin correlations: 2.124s
# J1=-4.0 | J2=3.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.0 | time=0js
# iter=1 | energy=(-37+0j) | time=0.12813130102586s
# computing spin correlations: 2.165s
# J1=-4.0 | J2=3.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.2 | time=0js
# iter=1 | energy=(-38.19999999999997+0j) | time=0.1294905009563081s
# computing spin correlations: 2.16s
# J1=-4.0 | J2=3.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.4 | time=0js
# iter=1 | energy=(-39.4+0j) | time=0.19290140201337636s
# computing spin correlations: 2.103s
# J1=-4.0 | J2=3.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.6 | time=0js
# iter=1 | energy=(-40.600000000000016+0j) | time=0.1318189999437891s
# computing spin correlations: 2.12s
# J1=-4.0 | J2=3.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.8 | time=0js
# iter=1 | energy=(-41.80000000000004+0j) | time=0.12791300099343061s
# computing spin correlations: 2.114s
# J1=-4.0 | J2=3.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-43.0 | time=0js
# iter=1 | energy=(-43+0j) | time=0.15838940104003996s
# computing spin correlations: 2.111s
# J1=-4.0 | J2=3.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-44.2 | time=0js
# iter=1 | energy=(-44.19999999999996+0j) | time=0.2415336999692954s
# computing spin correlations: 2.133s
# J1=-4.0 | J2=3.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-45.4 | time=0js
# iter=1 | energy=(-45.39999999999998+0j) | time=0.14184429997112602s
# computing spin correlations: 2.11s
# J1=-4.0 | J2=3.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-46.6 | time=0js
# iter=1 | energy=(-46.60000000000002+0j) | time=0.1426725999917835s
# computing spin correlations: 2.175s
# J1=-4.0 | J2=3.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-47.8 | time=0js
# iter=1 | energy=(-47.80000000000004+0j) | time=0.1331293999683112s
# computing spin correlations: 2.129s
# J1=-4.0 | J2=4.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-49.0 | time=0js
# iter=1 | energy=(-49+0j) | time=0.14800180098973215s
# computing spin correlations: 2.114s
# J1=-3.9 | J2=-4.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-95.775 | time=0js
# iter=1 | energy=(-95.77499999999993+0j) | time=0.14723540103295818s
# computing spin correlations: 2.141s
# J1=-3.9 | J2=-3.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-94.575 | time=0js
# iter=1 | energy=(-94.57500000000009+0j) | time=0.27937700104666874s
# computing spin correlations: 2.129s
# J1=-3.9 | J2=-3.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-93.375 | time=0js
# iter=1 | energy=(-93.37499999999991+0j) | time=0.13627310004085302s
# computing spin correlations: 2.09s
# J1=-3.9 | J2=-3.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-92.175 | time=0js
# iter=1 | energy=(-92.17500000000005+0j) | time=0.13585120002971962s
# computing spin correlations: 2.15s
# J1=-3.9 | J2=-3.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-90.975 | time=0js
# iter=1 | energy=(-90.975+0j) | time=0.1815552999614738s
# computing spin correlations: 2.122s
# J1=-3.9 | J2=-3.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-89.775 | time=0js
# iter=1 | energy=(-89.77499999999996+0j) | time=0.17686210002284497s
# computing spin correlations: 2.163s
# J1=-3.9 | J2=-3.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-88.575 | time=0js
# iter=1 | energy=(-88.57500000000007+0j) | time=0.14322600001469254s
# computing spin correlations: 2.139s
# J1=-3.9 | J2=-3.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-87.375 | time=0js
# iter=1 | energy=(-87.37499999999993+0j) | time=0.23871619999408722s
# computing spin correlations: 2.166s
# J1=-3.9 | J2=-3.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-86.175 | time=0js
# iter=1 | energy=(-86.17500000000004+0j) | time=0.18447509704856202s
# computing spin correlations: 2.172s
# J1=-3.9 | J2=-3.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-84.975 | time=0js
# iter=1 | energy=(-84.975+0j) | time=0.12542609800584614s
# computing spin correlations: 2.128s
# J1=-3.9 | J2=-3.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-83.775 | time=0js
# iter=1 | energy=(-83.77499999999998+0j) | time=0.13373279699590057s
# computing spin correlations: 2.166s
# J1=-3.9 | J2=-2.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-82.575 | time=0js
# iter=1 | energy=(-82.57500000000007+0j) | time=0.13727409997954965s
# computing spin correlations: 2.2s
# J1=-3.9 | J2=-2.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-81.375 | time=0js
# iter=1 | energy=(-81.37499999999993+0j) | time=0.14649829996051267s
# computing spin correlations: 2.247s
# J1=-3.9 | J2=-2.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-80.175 | time=0js
# iter=1 | energy=(-80.17500000000001+0j) | time=0.17843560397159308s
# computing spin correlations: 2.182s
# J1=-3.9 | J2=-2.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-78.975 | time=0js
# iter=1 | energy=(-78.975+0j) | time=0.17954040400218219s
# computing spin correlations: 2.202s
# J1=-3.9 | J2=-2.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-77.775 | time=0js
# iter=1 | energy=(-77.77499999999999+0j) | time=0.17651200498221442s
# computing spin correlations: 2.154s
# J1=-3.9 | J2=-2.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-76.575 | time=0js
# iter=1 | energy=(-76.57500000000007+0j) | time=0.14947750401915982s
# computing spin correlations: 2.124s
# J1=-3.9 | J2=-2.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-75.375 | time=0js
# iter=1 | energy=(-75.37499999999993+0j) | time=0.16995000402675942s
# computing spin correlations: 2.22s
# J1=-3.9 | J2=-2.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-74.175 | time=0js
# iter=1 | energy=(-74.175+0j) | time=0.22680540598230436s
# computing spin correlations: 2.166s
# J1=-3.9 | J2=-2.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-72.975 | time=0js
# iter=1 | energy=(-72.975+0j) | time=0.1865435040090233s
# computing spin correlations: 2.178s
# J1=-3.9 | J2=-2.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-71.775 | time=0js
# iter=1 | energy=(-71.775+0j) | time=0.22764980501960963s
# computing spin correlations: 2.163s
# J1=-3.9 | J2=-1.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-70.575 | time=0js
# iter=1 | energy=(-70.57500000000006+0j) | time=0.18926600203849375s
# computing spin correlations: 2.206s
# J1=-3.9 | J2=-1.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-69.375 | time=0js
# iter=1 | energy=(-69.37499999999994+0j) | time=0.20489260199246928s
# computing spin correlations: 2.184s
# J1=-3.9 | J2=-1.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-68.175 | time=0js
# iter=1 | energy=(-68.17499999999997+0j) | time=0.2649338020128198s
# computing spin correlations: 2.209s
# J1=-3.9 | J2=-1.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-66.975 | time=0js
# iter=1 | energy=(-66.975+0j) | time=0.19124740199185908s
# computing spin correlations: 2.207s
# J1=-3.9 | J2=-1.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-65.775 | time=0js
# iter=1 | energy=(-65.77500000000003+0j) | time=0.2653718020301312s
# computing spin correlations: 2.173s
# J1=-3.9 | J2=-1.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.575 | time=0js
# iter=1 | energy=(-64.57500000000006+0j) | time=0.21571560099255294s
# computing spin correlations: 2.179s
# J1=-3.9 | J2=-1.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.375 | time=0js
# iter=1 | energy=(-63.37499999999994+0j) | time=0.20028070197440684s
# computing spin correlations: 2.132s
# J1=-3.9 | J2=-1.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-62.175 | time=0js
# iter=1 | energy=(-62.174999999999955+0j) | time=0.2166497019934468s
# computing spin correlations: 2.172s
# J1=-3.9 | J2=-1.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-60.975 | time=0js
# iter=1 | energy=(-60.975+0j) | time=0.1914313010056503s
# computing spin correlations: 2.166s
# J1=-3.9 | J2=-1.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-59.775 | time=0js
# iter=1 | energy=(-59.77500000000005+0j) | time=0.22043470095377415s
# computing spin correlations: 2.146s
# J1=-3.9 | J2=-0.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-58.575 | time=0js
# iter=1 | energy=(-58.57500000000005+0j) | time=0.200141099980101s
# computing spin correlations: 2.179s
# J1=-3.9 | J2=-0.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-57.375 | time=0js
# iter=1 | energy=(-57.37499999999995+0j) | time=0.1951065010507591s
# computing spin correlations: 2.186s
# J1=-3.9 | J2=-0.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-56.175 | time=0js
# iter=1 | energy=(-56.174999999999955+0j) | time=0.161074400995858s
# computing spin correlations: 2.153s
# J1=-3.9 | J2=-0.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-54.975 | time=0js
# iter=1 | energy=(-54.975+0j) | time=0.18980800098506734s
# computing spin correlations: 2.215s
# J1=-3.9 | J2=-0.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.775 | time=0js
# iter=1 | energy=(-53.77500000000004+0j) | time=0.1982561019831337s
# computing spin correlations: 2.12s
# J1=-3.9 | J2=-0.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-52.575 | time=0js
# iter=1 | energy=(-52.57500000000004+0j) | time=0.1684158009593375s
# computing spin correlations: 2.11s
# J1=-3.9 | J2=-0.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-51.375 | time=0js
# iter=1 | energy=(-51.374999999999964+0j) | time=0.25451580103253946s
# computing spin correlations: 2.149s
# J1=-3.9 | J2=-0.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-50.175 | time=0js
# iter=1 | energy=(-50.174999999999955+0j) | time=0.1822290010168217s
# computing spin correlations: 2.133s
# J1=-3.9 | J2=-0.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-48.975 | time=0js
# iter=1 | energy=(-48.974999999999994+0j) | time=0.17964010097784922s
# computing spin correlations: 2.102s
# J1=-3.9 | J2=0.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-47.775 | time=0js
# iter=1 | energy=(-47.77500000000004+0j) | time=0.17051010101567954s
# computing spin correlations: 2.086s
# J1=-3.9 | J2=0.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-46.575 | time=0js
# iter=1 | energy=(-46.575000000000024+0j) | time=0.16338860103860497s
# computing spin correlations: 2.118s
# J1=-3.9 | J2=0.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-45.375 | time=0js
# iter=1 | energy=(-45.37499999999998+0j) | time=0.17015650001121685s
# computing spin correlations: 2.178s
# J1=-3.9 | J2=0.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-44.175 | time=0js
# iter=1 | energy=(-44.17499999999996+0j) | time=0.15191489999415353s
# computing spin correlations: 2.174s
# J1=-3.9 | J2=0.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-42.975 | time=0js
# iter=1 | energy=(-42.974999999999994+0j) | time=0.16198150004493073s
# computing spin correlations: 2.12s
# J1=-3.9 | J2=0.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.775 | time=0js
# iter=1 | energy=(-41.775000000000034+0j) | time=0.12950520002050325s
# computing spin correlations: 2.114s
# J1=-3.9 | J2=0.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.575 | time=0js
# iter=1 | energy=(-40.57500000000001+0j) | time=0.1627479000017047s
# computing spin correlations: 2.081s
# J1=-3.9 | J2=0.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.375 | time=0js
# iter=1 | energy=(-39.37499999999999+0j) | time=0.20232390001183376s
# computing spin correlations: 2.139s
# J1=-3.9 | J2=0.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.175 | time=0js
# iter=1 | energy=(-38.17499999999996+0j) | time=0.1688389999908395s
# computing spin correlations: 2.105s
# J1=-3.9 | J2=0.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-36.975 | time=0js
# iter=1 | energy=(-36.974999999999994+0j) | time=0.16140069998800755s
# computing spin correlations: 2.076s
# J1=-3.9 | J2=1.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.775 | time=0js
# iter=1 | energy=(-35.775000000000034+0j) | time=0.17629699897952378s
# computing spin correlations: 2.163s
# J1=-3.9 | J2=1.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.575 | time=0js
# iter=1 | energy=(-34.57499999999999+0j) | time=0.1631714979885146s
# computing spin correlations: 2.086s
# J1=-3.9 | J2=1.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.375 | time=0js
# iter=1 | energy=(-33.375000000000014+0j) | time=0.17347639799118042s
# computing spin correlations: 2.196s
# J1=-3.9 | J2=1.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.175 | time=0js
# iter=1 | energy=(-32.17499999999997+0j) | time=0.1894440989708528s
# computing spin correlations: 2.111s
# J1=-3.9 | J2=1.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.975 | time=0js
# iter=1 | energy=(-30.974999999999998+0j) | time=0.21678519900888205s
# computing spin correlations: 2.123s
# J1=-3.9 | J2=1.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.775 | time=0js
# iter=1 | energy=(-29.775000000000027+0j) | time=0.13237219996517524s
# computing spin correlations: 2.124s
# J1=-3.9 | J2=1.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.575 | time=0js
# iter=1 | energy=(-28.574999999999974+0j) | time=0.17645439901389182s
# computing spin correlations: 2.123s
# J1=-3.9 | J2=1.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.375 | time=0js
# iter=1 | energy=(-27.37500000000002+0j) | time=0.17178239999338984s
# computing spin correlations: 2.124s
# J1=-3.9 | J2=1.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.175 | time=0js
# iter=1 | energy=(-26.174999999999972+0j) | time=0.1617097010021098s
# computing spin correlations: 2.131s
# J1=-3.9 | J2=1.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-24.975 | time=0js
# iter=1 | energy=(-24.974999999999998+0j) | time=0.1684594010002911s
# computing spin correlations: 2.148s
# J1=-3.9 | J2=2.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-23.925 | time=0js
# iter=1 | energy=(-23.925000000000015+0j) | time=0.17152720195008442s
# computing spin correlations: 2.167s
# J1=-3.9 | J2=2.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-24.225 | time=0js
# iter=1 | energy=(-24.22499999999999+0j) | time=0.18524080200586468s
# computing spin correlations: 2.176s
# J1=-3.9 | J2=2.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.625 | time=0js
# iter=1 | energy=(-26.624999999999982+0j) | time=0.2306310010026209s
# computing spin correlations: 2.182s
# J1=-3.9 | J2=2.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.225 | time=0js
# iter=1 | energy=(-28.22500000000002+0j) | time=0.17144980002194643s
# computing spin correlations: 2.141s
# J1=-3.9 | J2=2.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.325 | time=0js
# iter=1 | energy=(-29.32499999999999+0j) | time=0.20476719998987392s
# computing spin correlations: 2.156s
# J1=-3.9 | J2=2.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.425 | time=0js
# iter=1 | energy=(-30.425000000000004+0j) | time=0.1305541000328958s
# computing spin correlations: 2.181s
# J1=-3.9 | J2=2.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.525 | time=0js
# iter=1 | energy=(-31.52500000000001+0j) | time=0.16044159699231386s
# computing spin correlations: 2.165s
# J1=-3.9 | J2=2.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.375 | time=0js
# iter=1 | energy=(-33.37499999999998+0j) | time=0.1404537979979068s
# computing spin correlations: 2.159s
# J1=-3.9 | J2=2.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.575 | time=0js
# iter=1 | energy=(-34.575000000000024+0j) | time=0.16993109695613384s
# computing spin correlations: 2.118s
# J1=-3.9 | J2=2.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.775 | time=0js
# iter=1 | energy=(-35.775+0j) | time=0.14417049597250298s
# computing spin correlations: 2.158s
# J1=-3.9 | J2=3.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-36.975 | time=0js
# iter=1 | energy=(-36.975+0j) | time=0.1743935959530063s
# computing spin correlations: 2.14s
# J1=-3.9 | J2=3.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.175 | time=0js
# iter=1 | energy=(-38.175000000000004+0j) | time=0.16969859501114115s
# computing spin correlations: 2.121s
# J1=-3.9 | J2=3.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.375 | time=0js
# iter=1 | energy=(-39.374999999999986+0j) | time=0.22187599597964436s
# computing spin correlations: 2.189s
# J1=-3.9 | J2=3.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.575 | time=0js
# iter=1 | energy=(-40.57500000000001+0j) | time=0.2486546959844418s
# computing spin correlations: 2.175s
# J1=-3.9 | J2=3.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.775 | time=0js
# iter=1 | energy=(-41.775000000000006+0j) | time=0.16773678502067924s
# computing spin correlations: 2.154s
# J1=-3.9 | J2=3.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-42.975 | time=0js
# iter=1 | energy=(-42.975+0j) | time=0.2008377829915844s
# computing spin correlations: 2.118s
# J1=-3.9 | J2=3.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-44.175 | time=0js
# iter=1 | energy=(-44.175+0j) | time=0.17235599999548867s
# computing spin correlations: 2.119s
# J1=-3.9 | J2=3.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-45.375 | time=0js
# iter=1 | energy=(-45.37499999999999+0j) | time=0.17354819999309257s
# computing spin correlations: 2.179s
# J1=-3.9 | J2=3.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-46.575 | time=0js
# iter=1 | energy=(-46.57500000000001+0j) | time=0.1798821000265889s
# computing spin correlations: 2.155s
# J1=-3.9 | J2=3.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-47.775 | time=0js
# iter=1 | energy=(-47.77500000000002+0j) | time=0.14756789902457967s
# computing spin correlations: 2.124s
# J1=-3.9 | J2=4.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-48.975 | time=0js
# iter=1 | energy=(-48.975+0j) | time=0.19825239904457703s
# computing spin correlations: 2.102s
# J1=-3.8 | J2=-4.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-94.55 | time=0js
# iter=1 | energy=(-94.55000000000008+0j) | time=0.19475490000331774s
# computing spin correlations: 2.125s
# J1=-3.8 | J2=-3.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-93.35 | time=0js
# iter=1 | energy=(-93.34999999999992+0j) | time=0.2367651999811642s
# computing spin correlations: 2.132s
# J1=-3.8 | J2=-3.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-92.15 | time=0js
# iter=1 | energy=(-92.15000000000005+0j) | time=0.2135123010375537s
# computing spin correlations: 2.174s
# J1=-3.8 | J2=-3.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-90.95 | time=0js
# iter=1 | energy=(-90.95+0j) | time=0.23835020000115037s
# computing spin correlations: 2.134s
# J1=-3.8 | J2=-3.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-89.75 | time=0js
# iter=1 | energy=(-89.74999999999996+0j) | time=0.21017980098258704s
# computing spin correlations: 2.138s
# J1=-3.8 | J2=-3.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-88.55 | time=0js
# iter=1 | energy=(-88.55000000000007+0j) | time=0.19653189997188747s
# computing spin correlations: 2.137s
# J1=-3.8 | J2=-3.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-87.35 | time=0js
# iter=1 | energy=(-87.34999999999992+0j) | time=0.16951009997865185s
# computing spin correlations: 2.143s
# J1=-3.8 | J2=-3.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-86.15 | time=0js
# iter=1 | energy=(-86.15000000000003+0j) | time=0.17215189995476976s
# computing spin correlations: 2.123s
# J1=-3.8 | J2=-3.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-84.95 | time=0js
# iter=1 | energy=(-84.95+0j) | time=0.16809210000792518s
# computing spin correlations: 2.116s
# J1=-3.8 | J2=-3.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-83.75 | time=0js
# iter=1 | energy=(-83.74999999999997+0j) | time=0.20297379902331159s
# computing spin correlations: 2.151s
# J1=-3.8 | J2=-3.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-82.55 | time=0js
# iter=1 | energy=(-82.55000000000007+0j) | time=0.15958879998652264s
# computing spin correlations: 2.093s
# J1=-3.8 | J2=-2.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-81.35 | time=0js
# iter=1 | energy=(-81.34999999999992+0j) | time=0.1690974000375718s
# computing spin correlations: 2.136s
# J1=-3.8 | J2=-2.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-80.15 | time=0js
# iter=1 | energy=(-80.15000000000002+0j) | time=0.1686537000350654s
# computing spin correlations: 2.134s
# J1=-3.8 | J2=-2.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-78.95 | time=0js
# iter=1 | energy=(-78.95+0j) | time=0.17684079997707158s
# computing spin correlations: 2.178s
# J1=-3.8 | J2=-2.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-77.75 | time=0js
# iter=1 | energy=(-77.74999999999999+0j) | time=0.1736242999904789s
# computing spin correlations: 2.184s
# J1=-3.8 | J2=-2.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-76.55 | time=0js
# iter=1 | energy=(-76.55000000000007+0j) | time=0.15267999999923632s
# computing spin correlations: 2.126s
# J1=-3.8 | J2=-2.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-75.35 | time=0js
# iter=1 | energy=(-75.34999999999994+0j) | time=0.17332790000364184s
# computing spin correlations: 2.116s
# J1=-3.8 | J2=-2.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-74.15 | time=0js
# iter=1 | energy=(-74.14999999999999+0j) | time=0.21681999997235835s
# computing spin correlations: 2.129s
# J1=-3.8 | J2=-2.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-72.95 | time=0js
# iter=1 | energy=(-72.95+0j) | time=0.17618270003004s
# computing spin correlations: 2.157s
# J1=-3.8 | J2=-2.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-71.75 | time=0js
# iter=1 | energy=(-71.75000000000001+0j) | time=0.3775081989588216s
# computing spin correlations: 2.124s
# J1=-3.8 | J2=-2.0
# ...
# iter=1 | energy=(-74.19999999999999+0j) | time=0.12566799903288484s
# computing spin correlations: 2.161s
# J1=4.0 | J2=-2.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-73.0 | time=0js
# iter=1 | energy=(-73+0j) | time=0.1319512989721261s
# computing spin correlations: 2.142s
# J1=4.0 | J2=-1.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-71.8 | time=0js
# iter=1 | energy=(-71.80000000000001+0j) | time=0.15022689901525155s
# computing spin correlations: 2.151s
# J1=4.0 | J2=-1.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-70.6 | time=0js
# iter=1 | energy=(-70.60000000000007+0j) | time=0.1371433999738656s
# computing spin correlations: 2.192s
# J1=4.0 | J2=-1.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-69.4 | time=0js
# iter=1 | energy=(-69.39999999999993+0j) | time=0.12629229901358485s
# computing spin correlations: 2.125s
# J1=4.0 | J2=-1.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-68.2 | time=0js
# iter=1 | energy=(-68.19999999999997+0j) | time=0.15786009997827932s
# computing spin correlations: 2.147s
# J1=4.0 | J2=-1.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-67.0 | time=0js
# iter=1 | energy=(-67+0j) | time=0.13189930003136396s
# computing spin correlations: 2.122s
# J1=4.0 | J2=-1.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-65.8 | time=0js
# iter=1 | energy=(-65.80000000000004+0j) | time=0.16165530099533498s
# computing spin correlations: 2.126s
# J1=4.0 | J2=-1.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-64.6 | time=0js
# iter=1 | energy=(-64.60000000000005+0j) | time=0.18466300098225474s
# computing spin correlations: 2.151s
# J1=4.0 | J2=-1.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-63.4 | time=0js
# iter=1 | energy=(-63.39999999999994+0j) | time=0.14964940096251667s
# computing spin correlations: 2.157s
# J1=4.0 | J2=-1.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-62.2 | time=0js
# iter=1 | energy=(-62.19999999999995+0j) | time=0.16805539996130392s
# computing spin correlations: 2.188s
# J1=4.0 | J2=-1.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-61.0 | time=0js
# iter=1 | energy=(-61+0j) | time=0.18218090303707868s
# computing spin correlations: 2.134s
# J1=4.0 | J2=-0.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-59.8 | time=0js
# iter=1 | energy=(-59.80000000000005+0j) | time=0.25099690299248323s
# computing spin correlations: 2.17s
# J1=4.0 | J2=-0.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-58.6 | time=0js
# iter=1 | energy=(-58.60000000000005+0j) | time=0.15454810002120212s
# computing spin correlations: 2.129s
# J1=4.0 | J2=-0.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-57.4 | time=0js
# iter=1 | energy=(-57.39999999999995+0j) | time=0.13306259998353198s
# computing spin correlations: 2.125s
# J1=4.0 | J2=-0.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-56.2 | time=0js
# iter=1 | energy=(-56.19999999999995+0j) | time=0.14595450001070276s
# computing spin correlations: 2.145s
# J1=4.0 | J2=-0.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-55.0 | time=0js
# iter=1 | energy=(-55+0j) | time=0.15958439896348864s
# computing spin correlations: 2.137s
# J1=4.0 | J2=-0.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-53.8 | time=0js
# iter=1 | energy=(-53.80000000000005+0j) | time=0.18280789902200922s
# computing spin correlations: 2.15s
# J1=4.0 | J2=-0.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-52.6 | time=0js
# iter=1 | energy=(-52.600000000000044+0j) | time=0.16149729903554544s
# computing spin correlations: 2.163s
# J1=4.0 | J2=-0.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-51.4 | time=0js
# iter=1 | energy=(-51.39999999999996+0j) | time=0.12263289903057739s
# computing spin correlations: 2.138s
# J1=4.0 | J2=-0.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-50.2 | time=0js
# iter=1 | energy=(-50.19999999999996+0j) | time=0.17301739897811785s
# computing spin correlations: 2.121s
# J1=4.0 | J2=0.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-49.0 | time=0js
# iter=1 | energy=(-49+0j) | time=0.12383019999833778s
# computing spin correlations: 2.126s
# J1=4.0 | J2=0.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-47.8 | time=0js
# iter=1 | energy=(-47.80000000000004+0j) | time=0.12546819902490824s
# computing spin correlations: 2.142s
# J1=4.0 | J2=0.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-46.6 | time=0js
# iter=1 | energy=(-46.60000000000003+0j) | time=0.12367409799480811s
# computing spin correlations: 2.125s
# J1=4.0 | J2=0.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-45.4 | time=0js
# iter=1 | energy=(-45.39999999999998+0j) | time=0.1425689979805611s
# computing spin correlations: 2.146s
# J1=4.0 | J2=0.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-44.2 | time=0js
# iter=1 | energy=(-44.19999999999996+0j) | time=0.12367009895388037s
# computing spin correlations: 2.177s
# J1=4.0 | J2=0.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-43.0 | time=0js
# iter=1 | energy=(-43+0j) | time=0.12149489903822541s
# computing spin correlations: 2.152s
# J1=4.0 | J2=0.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.8 | time=0js
# iter=1 | energy=(-41.80000000000004+0j) | time=0.175116099009756s
# computing spin correlations: 2.135s
# J1=4.0 | J2=0.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.6 | time=0js
# iter=1 | energy=(-40.60000000000001+0j) | time=0.16142249898985028s
# computing spin correlations: 2.174s
# J1=4.0 | J2=0.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.4 | time=0js
# iter=1 | energy=(-39.39999999999999+0j) | time=0.1438019000343047s
# computing spin correlations: 2.146s
# J1=4.0 | J2=0.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.2 | time=0js
# iter=1 | energy=(-38.19999999999997+0j) | time=0.18890579999424517s
# computing spin correlations: 2.132s
# J1=4.0 | J2=1.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.0 | time=0js
# iter=1 | energy=(-37+0j) | time=0.12292639998486266s
# computing spin correlations: 2.107s
# J1=4.0 | J2=1.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.8 | time=0js
# iter=1 | energy=(-35.80000000000003+0j) | time=0.16455809999024495s
# computing spin correlations: 2.156s
# J1=4.0 | J2=1.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.6 | time=0js
# iter=1 | energy=(-34.59999999999999+0j) | time=0.12474070000462234s
# computing spin correlations: 2.142s
# J1=4.0 | J2=1.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.4 | time=0js
# iter=1 | energy=(-33.40000000000001+0j) | time=0.14597709698136896s
# computing spin correlations: 2.116s
# J1=4.0 | J2=1.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-32.2 | time=0js
# iter=1 | energy=(-32.199999999999974+0j) | time=0.18781749700428918s
# computing spin correlations: 2.12s
# J1=4.0 | J2=1.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.0 | time=0js
# iter=1 | energy=(-31+0j) | time=0.17508999997517094s
# computing spin correlations: 2.17s
# J1=4.0 | J2=1.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.8 | time=0js
# iter=1 | energy=(-29.800000000000026+0j) | time=0.1284569000126794s
# computing spin correlations: 2.13s
# J1=4.0 | J2=1.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.6 | time=0js
# iter=1 | energy=(-28.599999999999977+0j) | time=0.14595330000156537s
# computing spin correlations: 2.111s
# J1=4.0 | J2=1.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-27.4 | time=0js
# iter=1 | energy=(-27.400000000000023+0j) | time=0.2151383000309579s
# computing spin correlations: 2.143s
# J1=4.0 | J2=1.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-26.2 | time=0js
# iter=1 | energy=(-26.199999999999978+0j) | time=0.2440088010043837s
# computing spin correlations: 2.155s
# J1=4.0 | J2=2.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-25.0 | time=0js
# iter=1 | energy=(-25+0j) | time=0.2767200989765115s
# computing spin correlations: 2.151s
# J1=4.0 | J2=2.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-24.4 | time=0js
# iter=1 | energy=(-24.400000000000016+0j) | time=0.20172069896943867s
# computing spin correlations: 2.244s
# J1=4.0 | J2=2.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-25.4 | time=0js
# iter=1 | energy=(-25.4+0j) | time=0.2414852129877545s
# computing spin correlations: 2.167s
# J1=4.0 | J2=2.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-28.3 | time=0js
# iter=1 | energy=(-28.299999999999983+0j) | time=0.24974251398816705s
# computing spin correlations: 2.165s
# J1=4.0 | J2=2.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-29.4 | time=0js
# iter=1 | energy=(-29.40000000000002+0j) | time=0.24254141398705542s
# computing spin correlations: 2.188s
# J1=4.0 | J2=2.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-30.5 | time=0js
# iter=1 | energy=(-30.5+0j) | time=0.1611809020396322s
# computing spin correlations: 2.207s
# J1=4.0 | J2=2.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-31.6 | time=0js
# iter=1 | energy=(-31.599999999999977+0j) | time=0.20132190198637545s
# computing spin correlations: 2.153s
# J1=4.0 | J2=2.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-33.4 | time=0js
# iter=1 | energy=(-33.40000000000002+0j) | time=0.19334520195843652s
# computing spin correlations: 2.131s
# J1=4.0 | J2=2.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-34.6 | time=0js
# iter=1 | energy=(-34.59999999999999+0j) | time=0.19418370100902393s
# computing spin correlations: 2.158s
# J1=4.0 | J2=2.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-35.8 | time=0js
# iter=1 | energy=(-35.80000000000003+0j) | time=0.12700940103968605s
# computing spin correlations: 2.113s
# J1=4.0 | J2=3.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-37.0 | time=0js
# iter=1 | energy=(-37+0j) | time=0.1629086000029929s
# computing spin correlations: 2.118s
# J1=4.0 | J2=3.1
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-38.2 | time=0js
# iter=1 | energy=(-38.19999999999997+0j) | time=0.2373976000235416s
# computing spin correlations: 2.127s
# J1=4.0 | J2=3.2
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-39.4 | time=0js
# iter=1 | energy=(-39.4+0j) | time=0.12685360002797097s
# computing spin correlations: 2.118s
# J1=4.0 | J2=3.3
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-40.6 | time=0js
# iter=1 | energy=(-40.600000000000016+0j) | time=0.17140719998860732s
# computing spin correlations: 2.187s
# J1=4.0 | J2=3.4
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-41.8 | time=0js
# iter=1 | energy=(-41.80000000000004+0j) | time=0.1886538999970071s
# computing spin correlations: 2.14s
# J1=4.0 | J2=3.5
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-43.0 | time=0js
# iter=1 | energy=(-43+0j) | time=0.23687860002974048s
# computing spin correlations: 2.131s
# J1=4.0 | J2=3.6
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-44.2 | time=0js
# iter=1 | energy=(-44.19999999999996+0j) | time=0.15560019999975339s
# computing spin correlations: 2.103s
# J1=4.0 | J2=3.7
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-45.4 | time=0js
# iter=1 | energy=(-45.39999999999998+0j) | time=0.19924640201497823s
# computing spin correlations: 2.093s
# J1=4.0 | J2=3.8
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-46.6 | time=0js
# iter=1 | energy=(-46.60000000000002+0j) | time=0.15986240102211013s
# computing spin correlations: 2.117s
# J1=4.0 | J2=3.9
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-47.8 | time=0js
# iter=1 | energy=(-47.80000000000004+0j) | time=0.13221790100215003s
# computing spin correlations: 2.106s
# J1=4.0 | J2=4.0
# L=50 | NKeep=50 | NSweep=20 | diag=True | two=True | Krylov=5 | cutoff=0.01
# Iterative diagonalization complete
# iter=0 | energy=-49.0 | time=0js
# iter=1 | energy=(-49+0j) | time=0.1274317009956576s
# computing spin correlations: 2.112s
